# %%
def underline_max(series):
    """Underline the maximum value(s) in a column."""
    is_max = series == series.max()        # Boolean Series
    return ['text-decoration: underline' if v else '' for v in is_max]

def print_pivot_to_latex(pivot_table):
    vmins = pivot_table.min()
    vmaxs = pivot_table.max()

    # --- Lighten the colormap (avoid overly dark greens)
    cmap = cm.get_cmap('Greens')
    def lighten_color_map(val):
        r, g, b, _ = val
        return (0.3 + 0.7 * r, 0.3 + 0.7 * g, 0.3 + 0.7 * b, 1)  # move toward lighter shades

    # --- Find max indices per column for underlining
    max_indices = pivot_table.idxmax()

    def color_cell(val, col):
        # normalize within column
        norm = colors.Normalize(vmin=vmins[col], vmax=vmaxs[col])
        r, g, b, _ = lighten_color_map(cmap(norm(val)))
        cell = f"\\cellcolor[rgb]{{{r:.3f},{g:.3f},{b:.3f}}}{val:.3f}"
        # underline max value per column
        if pivot_table.loc[:, col].idxmax() == idx:
            cell = f"\\underline{{{cell}}}"
        return cell

    # --- Build LaTeX table manually
    rows = []
    for idx, row in pivot_table.iterrows():
        colored = [color_cell(row[col], col) for col in pivot_table.columns]
        rows.append(f"{idx} & " + " & ".join(colored) + " \\\\")

    latex_table = (
        "\\begin{tabular}{l" + "r" * len(pivot_table.columns) + "}\n"
        + "Constraint & " + " & ".join(pivot_table.columns) + " \\\\\n"
        + "\\hline\n"
        + "\n".join(rows)
        + "\n\\end{tabular}"
    )

    print(latex_table)

# %%
import pandas as pd
import numpy as np
from matplotlib import cm, colors

df = pd.read_csv('results_nap_prediction_bpi12.csv')

# df = df[df['batch_size']>16]
pivot_table = pd.pivot_table(df, 
                             values=['f1', 'precision', 'accuracy'], 
                             
                             index=['model', 'local', 'batch_size', 'max_len', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_max, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_83167/2197943291.py:8: FutureWarning: The provided callable <function mean at 0x1291ca5c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_86b2a_row0_col0, #T_86b2a_row14_col1 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_86b2a_row0_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_86b2a_row0_col2, #T_86b2a_row14_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_86b2a_row1_col0 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_86b2a_row1_col1, #T_86b2a_row1_col2 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_86b2a_row2_col0, #T_86b2a_row6_col2 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_86b2a_row2_col1, #T_86b2a_row35_col2 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_86b2a_row2_col2, #T_86b2a_row20_col1, #T_86b2a_row38_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_86b2a_row3_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_86b2a_row3_col1, #T_86b2a_row3_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_86b2a_row4_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_86b2a_row4_col1, #T_86b2a_row41_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_86b2a_row4_col2, #T_86b2a_row30_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_86b2a_row5_col0 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_86b2a_row5_col1, #T_86b2a_row23_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_86b2a_row5_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_86b2a_row6_col0, #T_86b2a_row6_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_86b2a_row7_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_86b2a_row7_col1, #T_86b2a_row8_col2, #T_86b2a_row17_col1, #T_86b2a_row20_col2 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_86b2a_row7_col2, #T_86b2a_row26_col2, #T_86b2a_row46_col0 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_86b2a_row8_col0, #T_86b2a_row15_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_86b2a_row8_col1, #T_86b2a_row35_col1 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_86b2a_row9_col0, #T_86b2a_row44_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_86b2a_row9_col1, #T_86b2a_row19_col2 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_86b2a_row9_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_86b2a_row10_col0, #T_86b2a_row37_col2 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_86b2a_row10_col1, #T_86b2a_row17_col2, #T_86b2a_row29_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-decoration: underline;
# }
# #T_86b2a_row10_col2, #T_86b2a_row19_col1, #T_86b2a_row28_col1 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_86b2a_row11_col0 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_86b2a_row11_col1 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_86b2a_row11_col2, #T_86b2a_row15_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_86b2a_row12_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_86b2a_row12_col1, #T_86b2a_row39_col0 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_86b2a_row12_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_86b2a_row13_col0 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_86b2a_row13_col1 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_86b2a_row13_col2 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_86b2a_row14_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_86b2a_row15_col2, #T_86b2a_row16_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_86b2a_row16_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_86b2a_row16_col2 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_86b2a_row17_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_86b2a_row18_col0, #T_86b2a_row18_col2 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_86b2a_row18_col1 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_86b2a_row19_col0, #T_86b2a_row38_col0 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_86b2a_row20_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_86b2a_row21_col0 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_86b2a_row21_col1 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T
col2 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_cb05c_row9_col1, #T_cb05c_row19_col0, #T_cb05c_row28_col1 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_cb05c_row9_col2, #T_cb05c_row38_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_cb05c_row10_col0, #T_cb05c_row20_col1 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_cb05c_row10_col2, #T_cb05c_row42_col1 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_cb05c_row11_col0, #T_cb05c_row15_col1, #T_cb05c_row45_col1 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_cb05c_row11_col1, #T_cb05c_row47_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_cb05c_row11_col2 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_cb05c_row12_col0, #T_cb05c_row22_col1 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_cb05c_row12_col1 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_cb05c_row12_col2 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_cb05c_row13_col1, #T_cb05c_row21_col0, #T_cb05c_row44_col1, #T_cb05c_row44_col2 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_cb05c_row13_col2, #T_cb05c_row17_col1 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_cb05c_row14_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_cb05c_row14_col2, #T_cb05c_row16_col0, #T_cb05c_row34_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_cb05c_row15_col2, #T_cb05c_row38_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_cb05c_row16_col1, #T_cb05c_row33_col2 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_cb05c_row17_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_cb05c_row17_col2 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_cb05c_row18_col0, #T_cb05c_row18_col1, #T_cb05c_row23_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-decoration: underline;
# }
# #T_cb05c_row18_col2, #T_cb05c_row42_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_cb05c_row19_col1 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_cb05c_row20_col0, #T_cb05c_row36_col2 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_cb05c_row20_col2, #T_cb05c_row38_col2 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_cb05c_row21_col1 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_cb05c_row21_col2 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_cb05c_row22_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_cb05c_row22_col2 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_cb05c_row23_col0, #T_cb05c_row32_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_cb05c_row23_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_cb05c_row24_col1 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_cb05c_row24_col2 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_cb05c_row25_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_cb05c_row25_col1, #T_cb05c_row27_col2 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_cb05c_row25_col2, #T_cb05c_row34_col2 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_cb05c_row26_col0, #T_cb05c_row39_col1 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_cb05c_row26_col1 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_cb05c_row27_col0 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_cb05c_row28_col0, #T_cb05c_row29_col2 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_cb05c_row28_col2 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_cb05c_row29_col0, #T_cb05c_row37_col0 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_cb05c_row29_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_cb05c_row30_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_cb05c_row30_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_cb05c_row30_col2 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_cb05c_row31_col1 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_cb05c_row31_col2 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_cb05c_row32_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_cb05c_row32_col2 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_cb05c_row33_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_cb05c_row35_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_cb05c_row35_col2 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_cb05c_row37_col1, #T_cb05c_row47_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_cb05c_row39_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_cb05c_row39_col2 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_cb05c_row40_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_cb05c_row40_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_cb05c_row40_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_cb05c_row41_col0, #T_cb05c_row41_col1, #T_cb05c_row41_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cb05c_row42_col2 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_cb05c_row43_col1 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_cb05c_row43_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_cb05c_row44_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_cb05c_row45_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_cb05c_row46_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_cb05c_row46_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_cb05c_row47_col2 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cb05c">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb05c_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_cb05c_level0_col1" class="

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('results_nap_prediction_BPI20RequestForPayment.csv')

# df = df[df['batch_size']>16]
pivot_table = pd.pivot_table(df, 
                             values=['f1', 'precision', 'accuracy'], 
                             
                             index=['model', 'local', 'batch_size', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_max, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_83167/4232040977.py:7: FutureWarning: The provided callable <function mean at 0x1291ca5c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_32a6c_row0_col0, #T_32a6c_row0_col1, #T_32a6c_row33_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_32a6c_row0_col2 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_32a6c_row1_col0, #T_32a6c_row2_col0, #T_32a6c_row2_col1, #T_32a6c_row18_col0, #T_32a6c_row18_col1, #T_32a6c_row24_col0, #T_32a6c_row24_col1, #T_32a6c_row33_col0, #T_32a6c_row37_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_32a6c_row1_col1, #T_32a6c_row9_col0, #T_32a6c_row10_col0, #T_32a6c_row19_col0, #T_32a6c_row27_col0, #T_32a6c_row27_col1, #T_32a6c_row33_col1, #T_32a6c_row36_col0, #T_32a6c_row37_col1, #T_32a6c_row43_col0, #T_32a6c_row43_col1, #T_32a6c_row46_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_32a6c_row1_col2, #T_32a6c_row27_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_32a6c_row2_col2, #T_32a6c_row18_col2 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_32a6c_row3_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_32a6c_row3_col1 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_32a6c_row3_col2 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_32a6c_row4_col0, #T_32a6c_row30_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_32a6c_row4_col1 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_32a6c_row4_col2 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T
col0 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_c2f9d_row5_col0, #T_c2f9d_row7_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_c2f9d_row5_col1 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_c2f9d_row5_col2 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_c2f9d_row6_col0 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_c2f9d_row6_col1 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_c2f9d_row6_col2 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_c2f9d_row7_col1 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_c2f9d_row7_col2 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_c2f9d_row8_col0, #T_c2f9d_row8_col1, #T_c2f9d_row13_col1, #T_c2f9d_row21_col2, #T_c2f9d_row25_col1 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_c2f9d_row8_col2 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_c2f9d_row9_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_c2f9d_row9_col1 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_c2f9d_row10_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_c2f9d_row10_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_c2f9d_row10_col2 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_c2f9d_row11_col0 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_c2f9d_row11_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_c2f9d_row11_col2, #T_c2f9d_row22_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_c2f9d_row12_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_c2f9d_row12_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_c2f9d_row12_col2, #T_c2f9d_row24_col0, #T_c2f9d_row24_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c2f9d_row13_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_c2f9d_row14_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_c2f9d_row14_col1 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_c2f9d_row14_col2 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_c2f9d_row15_col0 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_c2f9d_row15_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c2f9d_row15_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_c2f9d_row16_col1 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_c2f9d_row16_col2 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_c2f9d_row17_col0, #T_c2f9d_row20_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_c2f9d_row17_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c2f9d_row18_col0 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_c2f9d_row18_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_c2f9d_row18_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_c2f9d_row19_col0 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_c2f9d_row19_col2 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_c2f9d_row20_col2 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_c2f9d_row21_col0, #T_c2f9d_row21_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_c2f9d_row22_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_c2f9d_row22_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_c2f9d_row23_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_c2f9d_row23_col2 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_c2f9d_row24_col2 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_c2f9d_row25_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_c2f9d_row26_col0 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_c2f9d_row26_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_c2f9d_row26_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_c2f9d_row27_col0 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_c2f9d_row27_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_c2f9d_row27_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c2f9d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2f9d_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_c2f9d_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_c2f9d_level0_col2" class="col_heading level0 col2" >precision</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >local</th>
#       <th class="index_name level2" >max_len</th>
#       <th class="index_name level3" >batch_size</th>
#       <th class="index_name level4" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2f9d_level0_row0" class="row_heading level0 row0" rowspan="4">NAP_model</th>
#       <th id="T_c2f9d_level1_row0" class="row_heading level1 row0" rowspan="4">False</th>
#       <th id="T_c2f9d_level2_row0" class="row_heading level2 row0" rowspan="2">10</th>
#       <th id="T_c2f9d_level3_row0" class="row_heading level3 row0" >16</th>
#       <th id="T_c2f9d_level4_row0" class="row_heading level4 row0" >0.000000</th>
#       <td id="T_c2f9d_row0_col0" class="data row0 col0" >0.712327</td>
#       <td id="T_c2f9d_row0_col1" class="data row0 col1" >0.769168</td>
#       <td id="T_c2f9d_row0_col2" class="data row0 col2" >0.881634</td>
#     </tr>
#     <tr>
#       <th id="T_c2f9d_level3_row1" class="row_heading level3 row1" >32</th>
#       <th id="T_c2f9d_level4_row1" class="row_heading level4 row1" >0.000000</th>
#       <td id="T_c2f9d_row1_col0" class="data row1 col0" >0.743520</td>
#       <td id="T_c2f9d_row1_col1" class="data row1 col1" >0.792952</td>
#       <td id="T_c2f9d_row1_col2" class="data row1 col2" >0.883088</td>
#     </tr>
#     <tr>
#       <th id="T_c2f9d_level2_row2" class="row_heading level2 row2" rowspan="2">20</th>
#       <th id="T_c2f9d_level3_row2" class="row_heading level3 row2" >16</th>
#       <th id="T_c2f9d_level4_row2" class="row_heading level4 row2" >0.000000</th>
#       <td id="T_c2f9d_row2_col0" class="data row2 col0" >0.693971</td>
#       <td id="T_c2f9d_row2_col1" class="data row2 col1" >0.756904</td>
#       <td id="T_c2f9d_row2_col2" class="data row2 col2" >0.876476</td>
#     </tr>
#     <tr>
#       <th id="T_c2f9d_level3_row3" class="row_heading level3 row3" >32</th>
#       <th id="T_c2f9d_level4_row3" class="row_heading level4 row3" >0.000000</th>
#       <td id="T_c2f9d_row3_col0" class="data row3 col0" >0.706420</td>
#       <td id="T_c2f9d_row3_col1" class="data row3 col1" >0.765204</td>
#       <td id="T_c2f9d_row3_col2" class="data row3 col2" >0.871556</td>
#     </tr>
#     <tr>
#       <th id="T_c2f9d_level0_row4" class="row_heading level0 row4" rowspan="24">SDFA_NAP_model</th>
#       <th id="T_c2f9d_level1_
