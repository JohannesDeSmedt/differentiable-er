# %%
import pandas as pd
from scipy.stats import friedmanchisquare
import scikit_posthocs as sp
import numpy as np
from matplotlib import cm, colors
import scipy.stats as ss
import pandas as pd


def underline_max(series):
    """Underline the maximum value(s) in a column."""
    is_max = series == series.max()        # Boolean Series
    return ['text-decoration: underline' if v else '' for v in is_max]

def print_pivot_to_latex(pivot_table):
    vmins = pivot_table.min()
    vmaxs = pivot_table.max()

    # --- Lighten the colormap (avoid overly dark greens)
    cmap = cm.get_cmap('Greens')
    def lighten_color_map(val):
        r, g, b, _ = val
        return (0.3 + 0.7 * r, 0.3 + 0.7 * g, 0.3 + 0.7 * b, 1)  # move toward lighter shades

    # --- Find max indices per column for underlining
    max_indices = pivot_table.idxmax()

    def color_cell(val, col):
        # normalize within column
        norm = colors.Normalize(vmin=vmins[col], vmax=vmaxs[col])
        r, g, b, _ = lighten_color_map(cmap(norm(val)))
        cell = f"\\cellcolor[rgb]{{{r:.3f},{g:.3f},{b:.3f}}}{val:.3f}"
        # underline max value per column
        if pivot_table.loc[:, col].idxmax() == idx:
            cell = f"\\underline{{{cell}}}"
        return cell

    # --- Build LaTeX table manually
    rows = []
    for idx, row in pivot_table.iterrows():
        colored = [color_cell(row[col], col) for col in pivot_table.columns]
        rows.append(f"{idx} & " + " & ".join(colored) + " \\\\")

    latex_table = (
        "\\begin{tabular}{l" + "r" * len(pivot_table.columns) + "}\n"
        + "Constraint & " + " & ".join(pivot_table.columns) + " \\\\\n"
        + "\\hline\n"
        + "\n".join(rows)
        + "\n\\end{tabular}"
    )

    print(latex_table)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/johannes/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/johannes/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/johannes/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_68650/4161446509.py", line 1, in <module>
#     import pandas as pd
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 53, in <module>
#     from pandas.core import (
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/johannes/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 711, in start
#     self.io_loop.start()
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/johannes/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/johannes/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/johannes/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 411, in do_execute
#     res = shell.run_cell(
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 531, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_68650/4161446509.py", line 1, in <module>
#     import pandas as pd
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 67, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 61, in <module>
#     from pandas.core import (
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/Users/johannes/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/johannes/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %% [markdown]
# ## Analyze local models

# %%
import glob
import os
import numpy as np
import pandas as pd
import scipy.stats as ss
from pathlib import Path

# -------------------------------------------------------
# 1. Load all CSVs into one big DataFrame
# -------------------------------------------------------
data_dir = Path(".")          # <-- change this
csv_paths = sorted(data_dir.glob("*.csv"))

dfs = []
for p in csv_paths:
    if 'nap' in str(p) and 'ns' not in str(p):
        df = pd.read_csv(p)
        # Keep the source dataset name (file stem)
        df["dataset"] = p.stem
        dfs.append(df)

df_all = pd.concat(dfs, ignore_index=True)
df_all
# Out:
#       seed  local  quantile           model  lambda  d_model  er_loss  \
# 0       56  False      0.95       NAP_model     0.0       16    False
# 1       56  False      0.95       NAP_model     0.0       32    False
# 2       56  False      0.95       NAP_model     0.0       64    False
# 3       56  False      0.95  SDFA_NAP_model     0.1       16     True
# 4       56  False      0.95  SDFA_NAP_model     0.2       16     True
# ...    ...    ...       ...             ...     ...      ...      ...
# 2875  1089   True      0.95  SDFA_NAP_model     0.2       32     True
# 2876  1089   True      0.95  SDFA_NAP_model     0.5       32     True
# 2877  1089   True      0.95  SDFA_NAP_model     0.1       64     True
# 2878  1089   True      0.95  SDFA_NAP_model     0.2       64     True
# 2879  1089   True      0.95  SDFA_NAP_model     0.5       64     True
#
#       batch_size  no_epochs  max_len    recall  precision        f1  accuracy  \
# 0             32         10       34  0.550141   0.796170  0.600495  0.550141
# 1             32         10       34  0.708017   0.812485  0.731738  0.708017
# 2             32         10       34  0.765547   0.886525  0.780957  0.765547
# 3             32         10       34  0.684701   0.830194  0.723855  0.684701
# 4             32         10       34  0.634415   0.816976  0.678915  0.634415
# ...          ...        ...      ...       ...        ...       ...       ...
# 2875         128         10       22  0.714036   0.908689  0.781750  0.714036
# 2876         128         10       22  0.765540   0.921098  0.823019  0.765540
# 2877         128         10       22  0.823512   0.924344  0.864780  0.823512
# 2878         128         10       22  0.821466   0.925267  0.862125  0.821466
# 2879         128         10       22  0.800944   0.903280  0.843077  0.800944
#
#            time                                       dataset
# 0     19.329225                  results_nap_prediction_BPI12
# 1     19.795509                  results_nap_prediction_BPI12
# 2     21.377124                  results_nap_prediction_BPI12
# 3     19.704939                  results_nap_prediction_BPI12
# 4     19.668417                  results_nap_prediction_BPI12
# ...         ...                                           ...
# 2875  11.305612  results_nap_prediction_BPI20TravelPermitData
# 2876  11.311359  results_nap_prediction_BPI20TravelPermitData
# 2877  11.339356  results_nap_prediction_BPI20TravelPermitData
# 2878  11.322628  results_nap_prediction_BPI20TravelPermitData
# 2879  11.313689  results_nap_prediction_BPI20TravelPermitData
#
# [2880 rows x 16 columns]

# %%
# df_local = df_all[df_all['local'] == True]
df_local = df_all
df_local['dataset'] = df_local['dataset'].apply(lambda x: x.replace('results_nap_prediction_', ''))
df_local = df_local[df_local['d_model'] > 16]
pivot_table = pd.pivot_table(df_local, 
                             values=['f1'], 
                             columns = ['dataset'],
                             index=[ 'local', 'batch_size',  'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_max, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_71003/2169881718.py:5: FutureWarning: The provided callable <function mean at 0x104bd6200> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df_local,
# <style type="text/css">
# #T_9c1da_row0_col0, #T_9c1da_row2_col1 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_9c1da_row0_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_9c1da_row0_col2 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_9c1da_row0_col3, #T_9c1da_row7_col4 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_9c1da_row0_col4, #T_9c1da_row2_col5, #T_9c1da_row4_col3 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_9c1da_row0_col5, #T_9c1da_row4_col1, #T_9c1da_row6_col3, #T_9c1da_row6_col4, #T_9c1da_row10_col0, #T_9c1da_row14_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9c1da_row1_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_9c1da_row1_col1 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_9c1da_row1_col2 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_9c1da_row1_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_9c1da_row1_col4, #T_9c1da_row3_col1 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_9c1da_row1_col5 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_9c1da_row2_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_9c1da_row2_col2 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_9c1da_row2_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_9c1da_row2_col4, #T_9c1da_row8_col4, #T_9c1da_row13_col0 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_9c1da_row3_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_9c1da_row3_col2, #T_9c1da_row9_col1 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_9c1da_row3_col3 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_9c1da_row3_col4 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_9c1da_row3_col5 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_9c1da_row4_col0 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_9c1da_row4_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_9c1da_row4_col4 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_9c1da_row4_col5 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_9c1da_row5_col0, #T_9c1da_row6_col1 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_9c1da_row5_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_9c1da_row5_col2, #T_9c1da_row8_col1, #T_9c1da_row10_col3, #T_9c1da_row10_col4, #T_9c1da_row12_col0, #T_9c1da_row15_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-decoration: underline;
# }
# #T_9c1da_row5_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_9c1da_row5_col4 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_9c1da_row5_col5, #T_9c1da_row15_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_9c1da_row6_col0 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_9c1da_row6_col2 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_9c1da_row6_col5, #T_9c1da_row12_col2 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_9c1da_row7_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_9c1da_row7_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_9c1da_row7_col2, #T_9c1da_row10_col1 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_9c1da_row7_col3 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_9c1da_row7_col5 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_9c1da_row8_col0 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_9c1da_row8_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_9c1da_row8_col3 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_9c1da_row8_col5 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_9c1da_row9_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_9c1da_row9_col2 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_9c1da_row9_col3 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_9c1da_row9_col4 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_9c1da_row9_col5 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_9c1da_row10_col2 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_9c1da_row10_col5 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_9c1da_row11_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_9c1da_row11_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_9c1da_row11_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_9c1da_row11_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_9c1da_row11_col4, #T_9c1da_row14_col5 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_9c1da_row11_col5 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_9c1da_row12_col1 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_9c1da_row12_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_9c1da_row12_col4 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_9c1da_row12_col5 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_9c1da_row13_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_9c1da_row13_col2 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_9c1da_row13_col3 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_9c1da_row13_col4 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_9c1da_row13_col5 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_9c1da_row14_col0 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_9c1da_row14_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_9c1da_row14_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_9c1da_row14_col4 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_9c1da_row15_col1 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_9c1da_row15_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_9c1da_row15_col3, #T_9c1da_row15_col4 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# </style>
# <table id="T_9c1da">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c1da_level0_col0" class="col_heading level0 col0" colspan="6">f1</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >dataset</th>
#       <th id="T_9c1da_level1_col0" class="col_heading level1 col0" >BPI12</th>
#       <th id="T_9c1da_level1_col1" class="col_heading level1 col1" >BPI17</th>
#       <th id="T_9c1da_level1_col2" class="col_heading level1 col2" >BPI19</th>
#       <th id="T_9c1da_level1_col3" class="col_heading level1 col3" >BPI20PrepaidTravelCosts</th>
#       <th id="T_9c1da_level1_col4" class="col_heading level1 col4" >BPI20RequestForPayment</th>
#       <th id="T_9c1da_level1_col5" class="col_heading level1 col5" >BPI20TravelPermitData</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >local</th>
#       <th class="index_name level1" >batch_size</th>
#       <th class="index_name level2" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c1da_level0_row0" class="row_heading level0 row0" rowspan="4">False</th>
#       <th id="T_9c1da_level1_row0" class="row_heading level1 row0" rowspan="4">32</th>
#       <th id="T_9c1da_level2_row0" class="row_heading level2 row0" >0.000000</th>
#       <td id="T_9c1da_row0_col0" class="data row0 col0" >0.768738</td>
#       <td id="T_9c1da_row0_col1" class="data row0 col1" >0.799747</td>
#       <td id="T_9c1da_row0_col2" class="data row0 col2" >0.690019</td>
#       <td id="T_9c1da_row0_col3" class="data row0 col3" >0.811932</td>
#       <td id="T_9c1da_row0_col4" class="data row0 col4" >0.947542</td>
#       <td id="T_9c1da_row0_col5" class="data row0 col5" >0.778951</td>
#     </tr>
#     <tr>
#       <th id="T_9c1da_level2_row1" class="row_heading level2 row1" >0.100000</th>
#       <td id="T_9c1da_row1_col0" class="data row1 col0" >0.777645</td>
#       <td id="T_9c1da_row1_col1" class="data row1 col1" >0.801459</td>
#       <td id="T_9c1da_row1_col2" class="data row1 col2" >0.684693</td>
#       <t

# %%
import glob
import os
import pandas as pd
import scipy.stats as ss
from pathlib import Path

# -------------------------------------------------------
# 1. Load all CSVs into one big DataFrame
# -------------------------------------------------------
data_dir = Path(".")          # <-- change this
csv_paths = sorted(data_dir.glob("*.csv"))

dfs = []
for p in csv_paths:
    if 'nap' in str(p) and 'ns' not in str(p):
        df = pd.read_csv(p)
        # Keep the source dataset name (file stem)
        df["dataset"] = p.stem
        dfs.append(df)

df_all = pd.concat(dfs, ignore_index=True)

# -------------------------------------------------------
# 2. Basic filtering
# -------------------------------------------------------
df_all = df_all[df_all["lambda"] < 0.5]
df_all = df_all[df_all['local'] == False]

# -------------------------------------------------------
# 3. Keep only the metrics we care about
# -------------------------------------------------------
cols_needed = ["dataset", "seed", "model", "d_model", "lambda", "f1", "precision"]
df_all = df_all[cols_needed]

# -------------------------------------------------------
# 4. Find the best parameter setting per seed–model–dataset
# -------------------------------------------------------
best = (
    df_all
    .sort_values("f1", ascending=False)          # highest f1 first
    .drop_duplicates(subset=["dataset", "seed", "model"], keep="first")
    .reset_index(drop=True)
)

# -------------------------------------------------------
# 5. Average metrics over seeds, grouped by dataset & model
# -------------------------------------------------------
summary = (
    best
    .groupby(["dataset", "model"], as_index=False)
    .agg(
        f1_mean=("f1", "mean"),
        precision_mean=("precision", "mean")
    )
)

# -------------------------------------------------------
# 6. Pivot so that each model becomes a column
# -------------------------------------------------------
pivot_f1 = summary.pivot(index="dataset", columns="model", values="f1_mean")
pivot_prec = summary.pivot(index="dataset", columns="model", values="precision_mean")

print(pivot_f1)

# -------------------------------------------------------
# 7. Statistical test per dataset
# -------------------------------------------------------
# 7a. Build a DataFrame with the two model columns side‑by‑side
model_a, model_b = sorted(df_all["model"].unique())  # ensure consistent order
tests = []

for ds in df_all["dataset"].unique():
    sub = best[best["dataset"] == ds]
#     if len(shared_seeds) < 3:   # Wilcoxon needs at least 3 pairs
#         continue
    vals_a = sub[sub["model"] == model_a].sort_values("seed")["f1"].values
    vals_b = sub[sub["model"] == model_b].sort_values("seed")["f1"].values
    stat, p = ss.wilcoxon(vals_a - vals_b)   # difference a – b
    tests.append({"dataset": ds,
                  "stat": stat,
                  "p": p,
                  f"{model_a}_mean": vals_a.mean(),
                  f"{model_b}_mean": vals_b.mean()})

tests_df = pd.DataFrame(tests)
pd.set_option("display.precision", 3)

# a) Merge the metric pivots with the test results
final_table = pivot_f1.copy()
print(final_table)
final_table.columns = [f"{c}_f1" for c in final_table.columns]
final_table = final_table.merge(
    pivot_prec.rename(columns={c: f"{c}_prec" for c in pivot_prec.columns}),
    left_index=True, right_index=True
)
print(final_table)
# final_table = final_table.merge(tests_df[["dataset", "p"]], left_index=True, right_index=True)
final_table
# print(final_table)
# Out:
# model                                           NAP_model  SDFA_NAP_model
# dataset
# results_nap_prediction_BPI12                        0.786           0.810
# results_nap_prediction_BPI17                        0.823           0.841
# results_nap_prediction_BPI19                        0.722           0.755
# results_nap_prediction_BPI20PrepaidTravelCosts      0.855           0.851
# results_nap_prediction_BPI20RequestForPayment       0.948           0.948
# results_nap_prediction_BPI20TravelPermitData        0.808           0.845
# model                                           NAP_model  SDFA_NAP_model
# dataset
# results_nap_prediction_BPI12                        0.786           0.810
# results_nap_prediction_BPI17                        0.823           0.841
# results_nap_prediction_BPI19                        0.722           0.755
# results_nap_prediction_BPI20PrepaidTravelCosts      0.855           0.851
# results_nap_prediction_BPI20RequestForPayment       0.948           0.948
# results_nap_prediction_BPI20TravelPermitData        0.808           0.845
#                                                 NAP_model_f1  \
# dataset
# results_nap_prediction_BPI12                           0.786
# results_nap_prediction_BPI17                           0.823
# results_nap_prediction_BPI19                           0.722
# results_nap_prediction_BPI20PrepaidTravelCosts         0.855
# results_nap_prediction_BPI20RequestForPayment          0.948
# results_nap_prediction_BPI20TravelPermitData           0.808
#
#                                                 SDFA_NAP_model_f1  \
# dataset
# results_nap_prediction_BPI12                                0.810
# results_nap_prediction_BPI17                                0.841
# results_nap_prediction_BPI19                                0.755
# results_nap_prediction_BPI20PrepaidTravelCosts              0.851
# results_nap_prediction_BPI20RequestForPayment               0.948
# results_nap_prediction_BPI20TravelPermitData                0.845
#
#                                                 NAP_model_prec  \
# dataset
# results_nap_prediction_BPI12                             0.878
# results_nap_prediction_BPI17                             0.895
# results_nap_prediction_BPI19                             0.918
# results_nap_prediction_BPI20PrepaidTravelCosts           0.939
# results_nap_prediction_BPI20RequestForPayment            0.990
# results_nap_prediction_BPI20TravelPermitData             0.906
#
#                                                 SDFA_NAP_model_prec
# dataset
# results_nap_prediction_BPI12                                  0.882
# results_nap_prediction_BPI17                                  0.895
# results_nap_prediction_BPI19                                  0.913
# results_nap_prediction_BPI20PrepaidTravelCosts                0.944
# results_nap_prediction_BPI20RequestForPayment                 0.989
# results_nap_prediction_BPI20TravelPermitData                  0.921
#                                                 NAP_model_f1  \
# dataset
# results_nap_prediction_BPI12                           0.786
# results_nap_prediction_BPI17                           0.823
# results_nap_prediction_BPI19                           0.722
# results_nap_prediction_BPI20PrepaidTravelCosts         0.855
# results_nap_prediction_BPI20RequestForPayment          0.948
# results_nap_prediction_BPI20TravelPermitData           0.808
#
#                                                 SDFA_NAP_model_f1  \
# dataset
# results_nap_prediction_BPI12                                0.810
# results_nap_prediction_BPI17                                0.841
# results_nap_prediction_BPI19                                0.755
# results_nap_prediction_BPI20PrepaidTravelCosts              0.851
# results_nap_prediction_BPI20RequestForPayment               0.948
# results_nap_prediction_BPI20TravelPermitData                0.845
#
#                                                 NAP_model_prec  \
# dataset
# results_nap_prediction_BPI12                             0.878
# results_nap_prediction_BPI17                             0.895
# results_nap_prediction_BPI19                             0.918
# results_nap_prediction_BPI20PrepaidTravelCosts           0.939
# results_nap_prediction_BPI20RequestForPayment            0.990
# results_nap_prediction_BPI20TravelPermitData             0.906
#
#                                                 SDFA_NAP_model_prec
# dataset
# results_nap_prediction_BPI12                                  0.882
# results_nap_prediction_BPI17                                  0.895
# results_nap_prediction_BPI19                                  0.913
# results_nap_prediction_BPI20PrepaidTravelCosts                0.944
# results_nap_prediction_BPI20RequestForPayment                 0.989
# results_nap_prediction_BPI20TravelPermitData                  0.921

# %%
df = pd.read_csv('results_nap_prediction_BPI12.csv')
df = df[df['lambda']<0.5]
# df = df[df['local']== False]

df_test = df[['seed', 'model', 'd_model', 'f1']]

df_test = (
    df_test
    .groupby(['seed', 'model'])
    .agg(f1_mean=('f1', 'max'))        # <‑‑ column name is arbitrary
    .reset_index()
)

print(df_test.head(50))

sub = df_test

pivot = sub.pivot(index='seed', columns='model', values='f1_mean')
print(pivot)

stat, p = ss.wilcoxon(pivot['SDFA_NAP_model']-pivot['NAP_model'])
print(stat)
print(p)


if p < 0.05:
    nemenyi = sp.posthoc_nemenyi_friedman(pivot)
    print(f"\n=== d_model = ===")
    print("Friedman χ² =", stat, ", p =", p)
    print("Nemenyi p‑values:")
    print(nemenyi)


# for d in df_test['d_model'].unique():
#     sub = df_test[df_test['d_model'] == d]
    
#     # pivot → rows: seed, cols: model, values: f1
#     pivot = sub.pivot(index='seed', columns='model', values='f1_mean')
    
#     # Some `d_model`s may have only one model – skip those
#     if pivot.shape[1] < 2:
#         continue
    
#     # 1) Friedman test
#     stat, p = friedmanchisquare(*pivot.T)
#     print(stat)
#     print(p)
    
   
#     # 3) If significant, run Nemenyi
#     if p < 0.05:
#         nemenyi = sp.posthoc_nemenyi_friedman(pivot)
#         print(f"\n=== d_model = {d} ===")
#         print("Friedman χ² =", stat, ", p =", p)
#         print("Nemenyi p‑values:")
#         print(nemenyi)
# Out:
#     seed           model  f1_mean
# 0      4       NAP_model    0.706
# 1      4  SDFA_NAP_model    0.821
# 2      8       NAP_model    0.784
# 3      8  SDFA_NAP_model    0.813
# 4     15       NAP_model    0.781
# 5     15  SDFA_NAP_model    0.820
# 6     16       NAP_model    0.766
# 7     16  SDFA_NAP_model    0.820
# 8     23       NAP_model    0.778
# 9     23  SDFA_NAP_model    0.814
# 10    42       NAP_model    0.811
# 11    42  SDFA_NAP_model    0.823
# 12    56       NAP_model    0.781
# 13    56  SDFA_NAP_model    0.817
# 14    76       NAP_model    0.815
# 15    76  SDFA_NAP_model    0.825
# 16   108       NAP_model    0.821
# 17   108  SDFA_NAP_model    0.832
# 18  1089       NAP_model    0.814
# 19  1089  SDFA_NAP_model    0.820
# model  NAP_model  SDFA_NAP_model
# seed
# 4          0.706           0.821
# 8          0.784           0.813
# 15         0.781           0.820
# 16         0.766           0.820
# 23         0.778           0.814
# 42         0.811           0.823
# 56         0.781           0.817
# 76         0.815           0.825
# 108        0.821           0.832
# 1089       0.814           0.820
# 0.0
# 0.001953125
#
# === d_model = ===
# Friedman χ² = 0.0 , p = 0.001953125
# Nemenyi p‑values:
#                 NAP_model  SDFA_NAP_model
# NAP_model           1.000           0.002
# SDFA_NAP_model      0.002           1.000

# %%
df = pd.read_csv('results_nap_prediction_BPI20TravelPermitData.csv')
m2 = df[df['model'] == 'SDFA_NAP_model'].copy()

# one string per combination of λ, local, batch_size
m2['combo'] = m2.apply(
    lambda r: f"lam{r['lambda']}_loc{r['local']}_dmod{r['d_model']}_bs{r['batch_size']}",
    axis=1
)
print(m2.head())
pivot = m2.pivot(index='seed', columns='combo', values='f1')
# Drop rows/columns that have missing values (so every seed has every combo)
pivot = pivot.dropna(axis=0, how='any').dropna(axis=1, how='any')

stat, p = friedmanchisquare(*pivot.T)

print("\n=== Model 2 Hyper‑parameter Settings ===")
print(f"Friedman χ² = {stat:.3f},  p = {p:.4f}")

nemenyi = sp.posthoc_nemenyi_friedman(pivot)
print("\nNemenyi pairwise p‑values:")
print(nemenyi)
# Out:
#    seed  local  quantile           model  lambda  d_model  er_loss  \
# 3    56  False      0.95  SDFA_NAP_model     0.1       16     True
# 4    56  False      0.95  SDFA_NAP_model     0.2       16     True
# 5    56  False      0.95  SDFA_NAP_model     0.5       16     True
# 6    56  False      0.95  SDFA_NAP_model     0.1       32     True
# 7    56  False      0.95  SDFA_NAP_model     0.2       32     True
#
#    batch_size  no_epochs  max_len    recall  precision        f1  accuracy  \
# 3          32         10       22  0.736241   0.889420  0.794542  0.736241
# 4          32         10       22  0.534149   0.821498  0.623816  0.534149
# 5          32         10       22  0.464036   0.840158  0.571541  0.464036
# 6          32         10       22  0.793553   0.909111  0.836942  0.793553
# 7          32         10       22  0.796258   0.914585  0.840226  0.796258
#
#         time                        combo
# 3  12.096259  lam0.1_locFalse_dmod16_bs32
# 4  12.100751  lam0.2_locFalse_dmod16_bs32
# 5  12.108279  lam0.5_locFalse_dmod16_bs32
# 6  12.263937  lam0.1_locFalse_dmod32_bs32
# 7  12.265967  lam0.2_locFalse_dmod32_bs32
#
# === Model 2 Hyper‑parameter Settings ===
# Friedman χ² = 4.000,  p = 0.4060
#
# Nemenyi pairwise p‑values:
#                              lam0.1_locFalse_dmod16_bs32  \
# lam0.1_locFalse_dmod16_bs32                     1.000000
# lam0.1_locFalse_dmod32_bs32                     0.999964
# lam0.1_locFalse_dmod64_bs32                     0.994004
# lam0.1_locTrue_dmod16_bs128                     1.000000
# lam0.1_locTrue_dmod16_bs16                      1.000000
# lam0.1_locTrue_dmod16_bs32                      1.000000
# lam0.1_locTrue_dmod16_bs64                      1.000000
# lam0.1_locTrue_dmod32_bs128                     0.992626
# lam0.1_locTrue_dmod32_bs16                      0.999123
# lam0.1_locTrue_dmod32_bs32                      1.000000
# lam0.1_locTrue_dmod32_bs64                      1.000000
# lam0.1_locTrue_dmod64_bs128                     1.000000
# lam0.1_locTrue_dmod64_bs16                      0.981204
# lam0.1_locTrue_dmod64_bs32                      0.999964
# lam0.1_locTrue_dmod64_bs64                      0.981204
# lam0.2_locFalse_dmod16_bs32                     1.000000
# lam0.2_locFalse_dmod32_bs32                     0.999964
# lam0.2_locFalse_dmod64_bs32                     0.547833
# lam0.2_locTrue_dmod16_bs128                     1.000000
# lam0.2_locTrue_dmod16_bs16                      1.000000
# lam0.2_locTrue_dmod16_bs32                      1.000000
# lam0.2_locTrue_dmod16_bs64                      1.000000
# lam0.2_locTrue_dmod32_bs128                     1.000000
# lam0.2_locTrue_dmod32_bs16                      1.000000
# lam0.2_locTrue_dmod32_bs32                      0.999335
# lam0.2_locTrue_dmod32_bs64                      1.000000
# lam0.2_locTrue_dmod64_bs128                     0.768605
# lam0.2_locTrue_dmod64_bs16                      0.997560
# lam0.2_locTrue_dmod64_bs32                      0.984215
# lam0.2_locTrue_dmod64_bs64                      0.443724
# lam0.5_locFalse_dmod16_bs32                     1.000000
# lam0.5_locFalse_dmod32_bs32                     0.999995
# lam0.5_locFalse_dmod64_bs32                     0.958721
# lam0.5_locTrue_dmod16_bs128                     1.000000
# lam0.5_locTrue_dmod16_bs16                      1.000000
# lam0.5_locTrue_dmod16_bs32                      1.000000
# lam0.5_locTrue_dmod16_bs64                      1.000000
# lam0.5_locTrue_dmod32_bs128                     1.000000
# lam0.5_locTrue_dmod32_bs16                      1.000000
# lam0.5_locTrue_dmod32_bs32                      0.998853
# lam0.5_locTrue_dmod32_bs64                      0.999628
# lam0.5_locTrue_dmod64_bs128                     0.232415
# lam0.5_locTrue_dmod64_bs16                      0.996911
# lam0.5_locTrue_dmod64_bs32                      0.998853
# lam0.5_locTrue_dmod64_bs64                      0.802906
#
#                              lam0.1_locFalse_dmod32_bs32  \
# lam0.1_locFalse_dmod16_bs32                     0.999964
# lam0.1_locFalse_dmod32_bs32                     1.000000
# lam0.1_locFalse_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod16_bs128                     1.000000
# lam0.1_locTrue_dmod16_bs16                      1.000000
# lam0.1_locTrue_dmod16_bs32                      0.999335
# lam0.1_locTrue_dmod16_bs64                      0.999999
# lam0.1_locTrue_dmod32_bs128                     1.000000
# lam0.1_locTrue_dmod32_bs16                      1.000000
# lam0.1_locTrue_dmod32_bs32                      1.000000
# lam0.1_locTrue_dmod32_bs64                      1.000000
# lam0.1_locTrue_dmod64_bs128                     1.000000
# lam0.1_locTrue_dmod64_bs16                      1.000000
# lam0.1_locTrue_dmod64_bs32                      1.000000
# lam0.1_locTrue_dmod64_bs64                      1.000000
# lam0.2_locFalse_dmod16_bs32                     0.952463
# lam0.2_locFalse_dmod32_bs32                     1.000000
# lam0.2_locFalse_dmod64_bs32                     1.000000
# lam0.2_locTrue_dmod16_bs128                     0.998853
# lam0.2_locTrue_dmod16_bs16                      1.000000
# lam0.2_locTrue_dmod16_bs32                      0.999964
# lam0.2_locTrue_dmod16_bs64                      1.000000
# lam0.2_locTrue_dmod32_bs128                     1.000000
# lam0.2_locTrue_dmod32_bs16                      1.000000
# lam0.2_locTrue_dmod32_bs32                      1.000000
# lam0.2_locTrue_dmod32_bs64                      1.000000
# lam0.2_locTrue_dmod64_bs128                     1.000000
# lam0.2_locTrue_dmod64_bs16                      1.000000
# lam0.2_locTrue_dmod64_bs32                      1.000000
# lam0.2_locTrue_dmod64_bs64                      0.999999
# lam0.5_locFalse_dmod16_bs32                     0.590097
# lam0.5_locFalse_dmod32_bs32                     1.000000
# lam0.5_locFalse_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod16_bs128                     0.652649
# lam0.5_locTrue_dmod16_bs16                      0.631995
# lam0.5_locTrue_dmod16_bs32                      0.693055
# lam0.5_locTrue_dmod16_bs64                      0.611123
# lam0.5_locTrue_dmod32_bs128                     1.000000
# lam0.5_locTrue_dmod32_bs16                      1.000000
# lam0.5_locTrue_dmod32_bs32                      1.000000
# lam0.5_locTrue_dmod32_bs64                      1.000000
# lam0.5_locTrue_dmod64_bs128                     0.999896
# lam0.5_locTrue_dmod64_bs16                      1.000000
# lam0.5_locTrue_dmod64_bs32                      1.000000
# lam0.5_locTrue_dmod64_bs64                      1.000000
#
#                              lam0.1_locFalse_dmod64_bs32  \
# lam0.1_locFalse_dmod16_bs32                     0.994004
# lam0.1_locFalse_dmod32_bs32                     1.000000
# lam0.1_locFalse_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod16_bs128                     0.999896
# lam0.1_locTrue_dmod16_bs16                      0.999993
# lam0.1_locTrue_dmod16_bs32                      0.969360
# lam0.1_locTrue_dmod16_bs64                      0.999123
# lam0.1_locTrue_dmod32_bs128                     1.000000
# lam0.1_locTrue_dmod32_bs16                      1.000000
# lam0.1_locTrue_dmod32_bs32                      1.000000
# lam0.1_locTrue_dmod32_bs64                      0.999964
# lam0.1_locTrue_dmod64_bs128                     1.000000
# lam0.1_locTrue_dmod64_bs16                      1.000000
# lam0.1_locTrue_dmod64_bs32                      1.000000
# lam0.1_locTrue_dmod64_bs64                      1.000000
# lam0.2_locFalse_dmod16_bs32                     0.712685
# lam0.2_locFalse_dmod32_bs32                     1.000000
# lam0.2_locFalse_dmod64_bs32                     1.000000
# lam0.2_locTrue_dmod16_bs128                     0.958721
# lam0.2_locTrue_dmod16_bs16                      0.999628
# lam0.2_locTrue_dmod16_bs32                      0.994004
# lam0.2_locTrue_dmod16_bs64                      0.999975
# lam0.2_locTrue_dmod32_bs128                     1.000000
# lam0.2_locTrue_dmod32_bs16                      1.000000
# lam0.2_locTrue_dmod32_bs32                      1.000000
# lam0.2_locTrue_dmod32_bs64                      0.999995
# lam0.2_locTrue_dmod64_bs128                     1.000000
# lam0.2_locTrue_dmod64_bs16                      1.000000
# lam0.2_locTrue_dmod64_bs32                      1.000000
# lam0.2_locTrue_dmod64_bs64                      1.000000
# lam0.5_locFalse_dmod16_bs32                     0.247074
# lam0.5_locFalse_dmod32_bs32                     1.000000
# lam0.5_locFalse_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod16_bs128                     0.294550
# lam0.5_locTrue_dmod16_bs16                      0.278151
# lam0.5_locTrue_dmod16_bs32                      0.328996
# lam0.5_locTrue_dmod16_bs64                      0.262322
# lam0.5_locTrue_dmod32_bs128                     1.000000
# lam0.5_locTrue_dmod32_bs16                      1.000000
# lam0.5_locTrue_dmod32_bs32                      1.000000
# lam0.5_locTrue_dmod32_bs64                      1.000000
# lam0.5_locTrue_dmod64_bs128                     1.000000
# lam0.5_locTrue_dmod64_bs16                      1.000000
# lam0.5_locTrue_dmod64_bs32                      1.000000
# lam0.5_locTrue_dmod64_bs64                      1.000000
#
#                              lam0.1_locTrue_dmod16_bs128  \
# lam0.1_locFalse_dmod16_bs32                     1.000000
# lam0.1_locFalse_dmod32_bs32                     1.000000
# lam0.1_locFalse_dmod64_bs32                     0.999896
# lam0.1_locTrue_dmod16_bs128                     1.000000
# lam0.1_locTrue_dmod16_bs16                      1.000000
# lam0.1_locTrue_dmod16_bs32                      1.000000
# lam0.1_locTrue_dmod16_bs64                      1.000000
# lam0.1_locTrue_dmod32_bs128                     0.999855
# lam0.1_locTrue_dmod32_bs16                      0.999995
# lam0.1_locTrue_dmod32_bs32                      1.000000
# lam0.1_locTrue_dmod32_bs64                      1.000000
# lam0.1_locTrue_dmod64_bs128                     1.000000
# lam0.1_locTrue_dmod64_bs16                      0.999335
# lam0.1_locTrue_dmod64_bs32                      1.000000
# lam0.1_locTrue_dmod64_bs64                      0.999335
# lam0.2_locFalse_dmod16_bs32                     1.000000
# lam0.2_locFalse_dmod32_bs32                     1.000000
# lam0.2_locFalse_dmod64_bs32                     0.834438
# lam0.2_locTrue_dmod16_bs128                     1.000000
# lam0.2_locTrue_dmod16_bs16                      1.000000
# lam0.2_locTrue_dmod16_bs32                      1.000000
# lam0.2_locTrue_dmod16_bs64                      1.000000
# lam0.2_locTrue_dmod32_bs128                     1.000000
# lam0.2_locTrue_dmod32_bs16                      1.000000
# lam0.2_locTrue_dmod32_bs32                      0.999997
# lam0.2_locTrue_dmod32_bs64                      1.000000
# lam0.2_locTrue_dmod64_bs128                     0.952463
# lam0.2_locTrue_dmod64_bs16                      0.999975
# lam0.2_locTrue_dmod64_bs32                      0.999500
# lam0.2_locTrue_dmod64_bs64                      0.750514
# lam0.5_locFalse_dmod16_bs32                     0.999975
# lam0.5_locFalse_dmod32_bs32                     1.000000
# lam0.5_locFalse_dmod64_bs32                     0.997560
# lam0.5_locTrue_dmod16_bs128                     0.999993
# lam0.5_locTrue_dmod16_bs16                      0.999989
# lam0.5_locTrue_dmod16_bs32                      0.999997
# lam0.5_locTrue_dmod16_bs64                      0.999983
# lam0.5_locTrue_dmod32_bs128                     1.000000
# lam0.5_locTrue_dmod32_bs16                      1.000000
# lam0.5_locTrue_dmod32_bs32                      0.999993
# lam0.5_locTrue_dmod32_bs64                      0.999999
# lam0.5_locTrue_dmod64_bs128                     0.505694
# lam0.5_locTrue_dmod64_bs16                      0.999964
# lam0.5_locTrue_dmod64_bs32                      0.999993
# lam0.5_locTrue_dmod64_bs64                      0.964341
#
#                              lam0.1_locTrue_dmod16_bs16  \
# lam0.1_locFalse_dmod16_bs32                    1.000000
# lam0.1_locFalse_dmod32_bs32                    1.000000
# lam0.1_locFalse_dmod64_bs32                    0.999993
# lam0.1_locTrue_dmod16_bs128                    1.000000
# lam0.1_locTrue_dmod16_bs16                     1.000000
# lam0.1_locTrue_dmod16_bs32                     1.000000
# lam0.1_locTrue_dmod16_bs64                     1.000000
# lam0.1_locTrue_dmod32_bs128                    0.999989
# lam0.1_locTrue_dmod32_bs16                     1.000000
# lam0.1_locTrue_dmod32_bs32                     1.000000
# lam0.1_locTrue_dmod32_bs64                     1.000000
# lam0.1_locTrue_dmod64_bs128                    1.000000
# lam0.1_locTrue_dmod64_bs16                     0.999926
# lam0.1_locTrue_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod64_bs64                     0.999926
# lam0.2_locFalse_dmod16_bs32                    1.000000
# lam0.2_locFalse_dmod32_bs32                    1.000000
# lam0.2_locFalse_dmod64_bs32                    0.920407
# lam0.2_locTrue_dmod16_bs128                    1.000000
# lam0.2_locTrue_dmod16_bs16                     1.000000
# lam0.2_locTrue_dmod16_bs32                     1.000000
# lam0.2_locTrue_dmod16_bs64                     1.000000
# lam0.2_locTrue_dmod32_bs128                    1.000000
# lam0.2_locTrue_dmod32_bs16                     1.000000
# lam0.2_locTrue_dmod32_bs32                     1.000000
# lam0.2_locTrue_dmod32_bs64                     1.000000
# lam0.2_locTrue_dmod64_bs128                    0.984215
# lam0.2_locTrue_dmod64_bs16                     0.999999
# lam0.2_locTrue_dmod64_bs32                     0.999948
# lam0.2_locTrue_dmod64_bs64                     0.862963
# lam0.5_locFalse_dmod16_bs32                    0.999725
# lam0.5_locFalse_dmod32_bs32                    1.000000
# lam0.5_locFalse_dmod64_bs32                    0.999628
# lam0.5_locTrue_dmod16_bs128                    0.999896
# lam0.5_locTrue_dmod16_bs16                     0.999855
# lam0.5_locTrue_dmod16_bs32                     0.999948
# lam0.5_locTrue_dmod16_bs64                     0.999799
# lam0.5_locTrue_dmod32_bs128                    1.000000
# lam0.5_locTrue_dmod32_bs16                     1.000000
# lam0.5_locTrue_dmod32_bs32                     1.000000
# lam0.5_locTrue_dmod32_bs64                     1.000000
# lam0.5_locTrue_dmod64_bs128                    0.652649
# lam0.5_locTrue_dmod64_bs16                     0.999998
# lam0.5_locTrue_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod64_bs64                     0.989072
#
#                              lam0.1_locTrue_dmod16_bs32  \
# lam0.1_locFalse_dmod16_bs32                    1.000000
# lam0.1_locFalse_dmod32_bs32                    0.999335
# lam0.1_locFalse_dmod64_bs32                    0.969360
# lam0.1_locTrue_dmod16_bs128                    1.000000
# lam0.1_locTrue_dmod16_bs16                     1.000000
# lam0.1_locTrue_dmod16_bs32                     1.000000
# lam0.1_locTrue_dmod16_bs64                     1.000000
# lam0.1_locTrue_dmod32_bs128                    0.964341
# lam0.1_locTrue_dmod32_bs16                     0.992626
# lam0.1_locTrue_dmod32_bs32                     1.000000
# lam0.1_locTrue_dmod32_bs64                     1.000000
# lam0.1_locTrue_dmod64_bs128                    0.999975
# lam0.1_locTrue_dmod64_bs16                     0.929530
# lam0.1_locTrue_dmod64_bs32                     0.999335
# lam0.1_locTrue_dmod64_bs64                     0.929530
# lam0.2_locFalse_dmod16_bs32                    1.000000
# lam0.2_locFalse_dmod32_bs32                    0.999335
# lam0.2_locFalse_dmod64_bs32                    0.365499
# lam0.2_locTrue_dmod16_bs128                    1.000000
# lam0.2_locTrue_dmod16_bs16                     1.000000
# lam0.2_locTrue_dmod16_bs32                     1.000000
# lam0.2_locTrue_dmod16_bs64                     1.000000
# lam0.2_locTrue_dmod32_bs128                    1.000000
# lam0.2_locTrue_dmod32_bs16                     0.999995
# lam0.2_locTrue_dmod32_bs32                     0.994004
# lam0.2_locTrue_dmod32_bs64                     1.000000
# lam0.2_locTrue_dmod64_bs128                    0.590097
# lam0.2_locTrue_dmod64_bs16                     0.984215
# lam0.2_locTrue_dmod64_bs32                     0.937897
# lam0.2_locTrue_dmod64_bs64                     0.278151
# lam0.5_locFalse_dmod16_bs32                    1.000000
# lam0.5_locFalse_dmod32_bs32                    0.999855
# lam0.5_locFalse_dmod64_bs32                    0.876048
# lam0.5_locTrue_dmod16_bs128                    1.000000
# lam0.5_locTrue_dmod16_bs16                     1.000000
# lam0.5_locTrue_dmod16_bs32                     1.000000
# lam0.5_locTrue_dmod16_bs64                     1.000000
# lam0.5_locTrue_dmod32_bs128                    1.000000
# lam0.5_locTrue_dmod32_bs16                     1.000000
# lam0.5_locTrue_dmod32_bs32                     0.990994
# lam0.5_locTrue_dmod32_bs64                     0.996118
# lam0.5_locTrue_dmod64_bs128                    0.126817
# lam0.5_locTrue_dmod64_bs16                     0.981204
# lam0.5_locTrue_dmod64_bs32                     0.990994
# lam0.5_locTrue_dmod64_bs64                     0.631995
#
#                              lam0.1_locTrue_dmod16_bs64  \
# lam0.1_locFalse_dmod16_bs32                    1.000000
# lam0.1_locFalse_dmod32_bs32                    0.999999
# lam0.1_locFalse_dmod64_bs32                    0.999123
# lam0.1_locTrue_dmod16_bs128                    1.000000
# lam0.1_locTrue_dmod16_bs16                     1.000000
# lam0.1_locTrue_dmod16_bs32                     1.000000
# lam0.1_locTrue_dmod16_bs64                     1.000000
# lam0.1_locTrue_dmod32_bs128                    0.998853
# lam0.1_locTrue_dmod32_bs16                     0.999926
# lam0.1_locTrue_dmod32_bs32                     1.000000
# lam0.1_locTrue_dmod32_bs64                     1.000000
# lam0.1_locTrue_dmod64_bs128                    1.000000
# lam0.1_locTrue_dmod64_bs16                     0.996118
# lam0.1_locTrue_dmod64_bs32                     0.999999
# lam0.1_locTrue_dmod64_bs64                     0.996118
# lam0.2_locFalse_dmod16_bs32                    1.000000
# lam0.2_locFalse_dmod32_bs32                    0.999999
# lam0.2_locFalse_dmod64_bs32                    0.712685
# lam0.2_locTrue_dmod16_bs128                    1.000000
# lam0.2_locTrue_dmod16_bs16                     1.000000
# lam0.2_locTrue_dmod16_bs32                     1.000000
# lam0.2_locTrue_dmod16_bs64                     1.000000
# lam0.2_locTrue_dmod32_bs128                    1.000000
# lam0.2_locTrue_dmod32_bs16                     1.000000
# lam0.2_locTrue_dmod32_bs32                     0.999948
# lam0.2_locTrue_dmod32_bs64                     1.000000
# lam0.2_locTrue_dmod64_bs128                    0.888335
# lam0.2_locTrue_dmod64_bs16                     0.999725
# lam0.2_locTrue_dmod64_bs32                     0.996911
# lam0.2_locTrue_dmod64_bs64                     0.611123
# lam0.5_locFalse_dmod16_bs32                    0.999999
# lam0.5_locFalse_dmod32_bs32                    1.000000
# lam0.5_locFalse_dmod64_bs32                    0.989072
# lam0.5_locTrue_dmod16_bs128                    1.000000
# lam0.5_locTrue_dmod16_bs16                     1.000000
# lam0.5_locTrue_dmod16_bs32                     1.000000
# lam0.5_locTrue_dmod16_bs64                     0.999999
# lam0.5_locTrue_dmod32_bs128                    1.000000
# lam0.5_locTrue_dmod32_bs16                     1.000000
# lam0.5_locTrue_dmod32_bs32                     0.999896
# lam0.5_locTrue_dmod32_bs64                     0.999975
# lam0.5_locTrue_dmod64_bs128                    0.365499
# lam0.5_locTrue_dmod64_bs16                     0.999628
# lam0.5_locTrue_dmod64_bs32                     0.999896
# lam0.5_locTrue_dmod64_bs64                     0.910509
#
#                              lam0.1_locTrue_dmod32_bs128  \
# lam0.1_locFalse_dmod16_bs32                     0.992626
# lam0.1_locFalse_dmod32_bs32                     1.000000
# lam0.1_locFalse_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod16_bs128                     0.999855
# lam0.1_locTrue_dmod16_bs16                      0.999989
# lam0.1_locTrue_dmod16_bs32                      0.964341
# lam0.1_locTrue_dmod16_bs64                      0.998853
# lam0.1_locTrue_dmod32_bs128                     1.000000
# lam0.1_locTrue_dmod32_bs16                      1.000000
# lam0.1_locTrue_dmod32_bs32                      1.000000
# lam0.1_locTrue_dmod32_bs64                      0.999948
# lam0.1_locTrue_dmod64_bs128                     1.000000
# lam0.1_locTrue_dmod64_bs16                      1.000000
# lam0.1_locTrue_dmod64_bs32                      1.000000
# lam0.1_locTrue_dmod64_bs64                      1.000000
# lam0.2_locFalse_dmod16_bs32                     0.693055
# lam0.2_locFalse_dmod32_bs32                     1.000000
# lam0.2_locFalse_dmod64_bs32                     1.000000
# lam0.2_locTrue_dmod16_bs128                     0.952463
# lam0.2_locTrue_dmod16_bs16                      0.999500
# lam0.2_locTrue_dmod16_bs32                      0.992626
# lam0.2_locTrue_dmod16_bs64                      0.999964
# lam0.2_locTrue_dmod32_bs128                     1.000000
# lam0.2_locTrue_dmod32_bs16                      1.000000
# lam0.2_locTrue_dmod32_bs32                      1.000000
# lam0.2_locTrue_dmod32_bs64                      0.999993
# lam0.2_locTrue_dmod64_bs128                     1.000000
# lam0.2_locTrue_dmod64_bs16                      1.000000
# lam0.2_locTrue_dmod64_bs32                      1.000000
# lam0.2_locTrue_dmod64_bs64                      1.000000
# lam0.5_locFalse_dmod16_bs32                     0.232415
# lam0.5_locFalse_dmod32_bs32                     1.000000
# lam0.5_locFalse_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod16_bs128                     0.278151
# lam0.5_locTrue_dmod16_bs16                      0.262322
# lam0.5_locTrue_dmod16_bs32                      0.311504
# lam0.5_locTrue_dmod16_bs64                      0.247074
# lam0.5_locTrue_dmod32_bs128                     1.000000
# lam0.5_locTrue_dmod32_bs16                      1.000000
# lam0.5_locTrue_dmod32_bs32                      1.000000
# lam0.5_locTrue_dmod32_bs64                      1.000000
# lam0.5_locTrue_dmod64_bs128                     1.000000
# lam0.5_locTrue_dmod64_bs16                      1.000000
# lam0.5_locTrue_dmod64_bs32                      1.000000
# lam0.5_locTrue_dmod64_bs64                      1.000000
#
#                              lam0.1_locTrue_dmod32_bs16  \
# lam0.1_locFalse_dmod16_bs32                    0.999123
# lam0.1_locFalse_dmod32_bs32                    1.000000
# lam0.1_locFalse_dmod64_bs32                    1.000000
# lam0.1_locTrue_dmod16_bs128                    0.999995
# lam0.1_locTrue_dmod16_bs16                     1.000000
# lam0.1_locTrue_dmod16_bs32                     0.992626
# lam0.1_locTrue_dmod16_bs64                     0.999926
# lam0.1_locTrue_dmod32_bs128                    1.000000
# lam0.1_locTrue_dmod32_bs16                     1.000000
# lam0.1_locTrue_dmod32_bs32                     1.000000
# lam0.1_locTrue_dmod32_bs64                     0.999999
# lam0.1_locTrue_dmod64_bs128                    1.000000
# lam0.1_locTrue_dmod64_bs16                     1.000000
# lam0.1_locTrue_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod64_bs64                     1.000000
# lam0.2_locFalse_dmod16_bs32                    0.849088
# lam0.2_locFalse_dmod32_bs32                    1.000000
# lam0.2_locFalse_dmod64_bs32                    1.000000
# lam0.2_locTrue_dmod16_bs128                    0.989072
# lam0.2_locTrue_dmod16_bs16                     0.999975
# lam0.2_locTrue_dmod16_bs32                     0.999123
# lam0.2_locTrue_dmod16_bs64                     0.999999
# lam0.2_locTrue_dmod32_bs128                    1.000000
# lam0.2_locTrue_dmod32_bs16                     1.000000
# lam0.2_locTrue_dmod32_bs32                     1.000000
# lam0.2_locTrue_dmod32_bs64                     1.000000
# lam0.2_locTrue_dmod64_bs128                    1.000000
# lam0.2_locTrue_dmod64_bs16                     1.000000
# lam0.2_locTrue_dmod64_bs32                     1.000000
# lam0.2_locTrue_dmod64_bs64                     1.000000
# lam0.5_locFalse_dmod16_bs32                    0.384455
# lam0.5_locFalse_dmod32_bs32                    1.000000
# lam0.5_locFalse_dmod64_bs32                    1.000000
# lam0.5_locTrue_dmod16_bs128                    0.443724
# lam0.5_locTrue_dmod16_bs16                     0.423607
# lam0.5_locTrue_dmod16_bs32                     0.484818
# lam0.5_locTrue_dmod16_bs64                     0.403837
# lam0.5_locTrue_dmod32_bs128                    1.000000
# lam0.5_locTrue_dmod32_bs16                     1.000000
# lam0.5_locTrue_dmod32_bs32                     1.000000
# lam0.5_locTrue_dmod32_bs64                     1.000000
# lam0.5_locTrue_dmod64_bs128                    0.999998
# lam0.5_locTrue_dmod64_bs16                     1.000000
# lam0.5_locTrue_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod64_bs64                     1.000000
#
#                              lam0.1_locTrue_dmod32_bs32  ...  \
# lam0.1_locFalse_dmod16_bs32                    1.000000  ...
# lam0.1_locFalse_dmod32_bs32                    1.000000  ...
# lam0.1_locFalse_dmod64_bs32                    1.000000  ...
# lam0.1_locTrue_dmod16_bs128                    1.000000  ...
# lam0.1_locTrue_dmod16_bs16                     1.000000  ...
# lam0.1_locTrue_dmod16_bs32                     1.000000  ...
# lam0.1_locTrue_dmod16_bs64                     1.000000  ...
# lam0.1_locTrue_dmod32_bs128                    1.000000  ...
# lam0.1_locTrue_dmod32_bs16                     1.000000  ...
# lam0.1_locTrue_dmod32_bs32                     1.000000  ...
# lam0.1_locTrue_dmod32_bs64                     1.000000  ...
# lam0.1_locTrue_dmod64_bs128                    1.000000  ...
# lam0.1_locTrue_dmod64_bs16                     1.000000  ...
# lam0.1_locTrue_dmod64_bs32                     1.000000  ...
# lam0.1_locTrue_dmod64_bs64                     1.000000  ...
# lam0.2_locFalse_dmod16_bs32                    0.999725  ...
# lam0.2_locFalse_dmod32_bs32                    1.000000  ...
# lam0.2_locFalse_dmod64_bs32                    0.999123  ...
# lam0.2_locTrue_dmod16_bs128                    1.000000  ...
# lam0.2_locTrue_dmod16_bs16                     1.000000  ...
# lam0.2_locTrue_dmod16_bs32                     1.000000  ...
# lam0.2_locTrue_dmod16_bs64                     1.000000  ...
# lam0.2_locTrue_dmod32_bs128                    1.000000  ...
# lam0.2_locTrue_dmod32_bs16                     1.000000  ...
# lam0.2_locTrue_dmod32_bs32                     1.000000  ...
# lam0.2_locTrue_dmod32_bs64                     1.000000  ...
# lam0.2_locTrue_dmod64_bs128                    0.999975  ...
# lam0.2_locTrue_dmod64_bs16                     1.000000  ...
# lam0.2_locTrue_dmod64_bs32                     1.000000  ...
# lam0.2_locTrue_dmod64_bs64                     0.996911  ...
# lam0.5_locFalse_dmod16_bs32                    0.952463  ...
# lam0.5_locFalse_dmod32_bs32                    1.000000  ...
# lam0.5_locFalse_dmod64_bs32                    1.000000  ...
# lam0.5_locTrue_dmod16_bs128                    0.969360  ...
# lam0.5_locTrue_dmod16_bs16                     0.964341  ...
# lam0.5_locTrue_dmod16_bs32                     0.977752  ...
# lam0.5_locTrue_dmod16_bs64                     0.958721  ...
# lam0.5_locTrue_dmod32_bs128                    1.000000  ...
# lam0.5_locTrue_dmod32_bs16                     1.000000  ...
# lam0.5_locTrue_dmod32_bs32                     1.000000  ...
# lam0.5_locTrue_dmod32_bs64                     1.000000  ...
# lam0.5_locTrue_dmod64_bs128                    0.969360  ...
# lam0.5_locTrue_dmod64_bs16                     1.000000  ...
# lam0.5_locTrue_dmod64_bs32                     1.000000  ...
# lam0.5_locTrue_dmod64_bs64                     0.999989  ...
#
#                              lam0.5_locTrue_dmod16_bs32  \
# lam0.1_locFalse_dmod16_bs32                    1.000000
# lam0.1_locFalse_dmod32_bs32                    0.693055
# lam0.1_locFalse_dmod64_bs32                    0.328996
# lam0.1_locTrue_dmod16_bs128                    0.999997
# lam0.1_locTrue_dmod16_bs16                     0.999948
# lam0.1_locTrue_dmod16_bs32                     1.000000
# lam0.1_locTrue_dmod16_bs64                     1.000000
# lam0.1_locTrue_dmod32_bs128                    0.311504
# lam0.1_locTrue_dmod32_bs16                     0.484818
# lam0.1_locTrue_dmod32_bs32                     0.977752
# lam0.1_locTrue_dmod32_bs64                     0.999989
# lam0.1_locTrue_dmod64_bs128                    0.862963
# lam0.1_locTrue_dmod64_bs16                     0.232415
# lam0.1_locTrue_dmod64_bs32                     0.693055
# lam0.1_locTrue_dmod64_bs64                     0.232415
# lam0.2_locFalse_dmod16_bs32                    1.000000
# lam0.2_locFalse_dmod32_bs32                    0.693055
# lam0.2_locFalse_dmod64_bs32                    0.018095
# lam0.2_locTrue_dmod16_bs128                    1.000000
# lam0.2_locTrue_dmod16_bs16                     1.000000
# lam0.2_locTrue_dmod16_bs32                     1.000000
# lam0.2_locTrue_dmod16_bs64                     0.999983
# lam0.2_locTrue_dmod32_bs128                    0.999123
# lam0.2_locTrue_dmod32_bs16                     0.910509
# lam0.2_locTrue_dmod32_bs32                     0.505694
# lam0.2_locTrue_dmod32_bs64                     0.999926
# lam0.2_locTrue_dmod64_bs128                    0.049047
# lam0.2_locTrue_dmod64_bs16                     0.403837
# lam0.2_locTrue_dmod64_bs32                     0.247074
# lam0.2_locTrue_dmod64_bs64                     0.011093
# lam0.5_locFalse_dmod16_bs32                    1.000000
# lam0.5_locFalse_dmod32_bs32                    0.786084
# lam0.5_locFalse_dmod64_bs32                    0.168004
# lam0.5_locTrue_dmod16_bs128                    1.000000
# lam0.5_locTrue_dmod16_bs16                     1.000000
# lam0.5_locTrue_dmod16_bs32                     1.000000
# lam0.5_locTrue_dmod16_bs64                     1.000000
# lam0.5_locTrue_dmod32_bs128                    0.969360
# lam0.5_locTrue_dmod32_bs16                     0.992626
# lam0.5_locTrue_dmod32_bs32                     0.464144
# lam0.5_locTrue_dmod32_bs64                     0.547833
# lam0.5_locTrue_dmod64_bs128                    0.003149
# lam0.5_locTrue_dmod64_bs16                     0.384455
# lam0.5_locTrue_dmod64_bs32                     0.464144
# lam0.5_locTrue_dmod64_bs64                     0.058066
#
#                              lam0.5_locTrue_dmod16_bs64  \
# lam0.1_locFalse_dmod16_bs32                    1.000000
# lam0.1_locFalse_dmod32_bs32                    0.611123
# lam0.1_locFalse_dmod64_bs32                    0.262322
# lam0.1_locTrue_dmod16_bs128                    0.999983
# lam0.1_locTrue_dmod16_bs16                     0.999799
# lam0.1_locTrue_dmod16_bs32                     1.000000
# lam0.1_locTrue_dmod16_bs64                     0.999999
# lam0.1_locTrue_dmod32_bs128                    0.247074
# lam0.1_locTrue_dmod32_bs16                     0.403837
# lam0.1_locTrue_dmod32_bs32                     0.958721
# lam0.1_locTrue_dmod32_bs64                     0.999948
# lam0.1_locTrue_dmod64_bs128                    0.802906
# lam0.1_locTrue_dmod64_bs16                     0.179710
# lam0.1_locTrue_dmod64_bs32                     0.611123
# lam0.1_locTrue_dmod64_bs64                     0.179710
# lam0.2_locFalse_dmod16_bs32                    1.000000
# lam0.2_locFalse_dmod32_bs32                    0.611123
# lam0.2_locFalse_dmod64_bs32                    0.012254
# lam0.2_locTrue_dmod16_bs128                    1.000000
# lam0.2_locTrue_dmod16_bs16                     0.999997
# lam0.2_locTrue_dmod16_bs32                     1.000000
# lam0.2_locTrue_dmod16_bs64                     0.999926
# lam0.2_locTrue_dmod32_bs128                    0.997560
# lam0.2_locTrue_dmod32_bs16                     0.862963
# lam0.2_locTrue_dmod32_bs32                     0.423607
# lam0.2_locTrue_dmod32_bs64                     0.999725
# lam0.2_locTrue_dmod64_bs128                    0.034583
# lam0.2_locTrue_dmod64_bs16                     0.328996
# lam0.2_locTrue_dmod64_bs32                     0.191999
# lam0.2_locTrue_dmod64_bs64                     0.007385
# lam0.5_locFalse_dmod16_bs32                    1.000000
# lam0.5_locFalse_dmod32_bs32                    0.712685
# lam0.5_locFalse_dmod64_bs32                    0.126817
# lam0.5_locTrue_dmod16_bs128                    1.000000
# lam0.5_locTrue_dmod16_bs16                     1.000000
# lam0.5_locTrue_dmod16_bs32                     1.000000
# lam0.5_locTrue_dmod16_bs64                     1.000000
# lam0.5_locTrue_dmod32_bs128                    0.945532
# lam0.5_locTrue_dmod32_bs16                     0.984215
# lam0.5_locTrue_dmod32_bs32                     0.384455
# lam0.5_locTrue_dmod32_bs64                     0.464144
# lam0.5_locTrue_dmod64_bs128                    0.002019
# lam0.5_locTrue_dmod64_bs16                     0.311504
# lam0.5_locTrue_dmod64_bs32                     0.384455
# lam0.5_locTrue_dmod64_bs64                     0.041265
#
#                              lam0.5_locTrue_dmod32_bs128  \
# lam0.1_locFalse_dmod16_bs32                     1.000000
# lam0.1_locFalse_dmod32_bs32                     1.000000
# lam0.1_locFalse_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod16_bs128                     1.000000
# lam0.1_locTrue_dmod16_bs16                      1.000000
# lam0.1_locTrue_dmod16_bs32                      1.000000
# lam0.1_locTrue_dmod16_bs64                      1.000000
# lam0.1_locTrue_dmod32_bs128                     1.000000
# lam0.1_locTrue_dmod32_bs16                      1.000000
# lam0.1_locTrue_dmod32_bs32                      1.000000
# lam0.1_locTrue_dmod32_bs64                      1.000000
# lam0.1_locTrue_dmod64_bs128                     1.000000
# lam0.1_locTrue_dmod64_bs16                      1.000000
# lam0.1_locTrue_dmod64_bs32                      1.000000
# lam0.1_locTrue_dmod64_bs64                      1.000000
# lam0.2_locFalse_dmod16_bs32                     0.999500
# lam0.2_locFalse_dmod32_bs32                     1.000000
# lam0.2_locFalse_dmod64_bs32                     0.999500
# lam0.2_locTrue_dmod16_bs128                     1.000000
# lam0.2_locTrue_dmod16_bs16                      1.000000
# lam0.2_locTrue_dmod16_bs32                      1.000000
# lam0.2_locTrue_dmod16_bs64                      1.000000
# lam0.2_locTrue_dmod32_bs128                     1.000000
# lam0.2_locTrue_dmod32_bs16                      1.000000
# lam0.2_locTrue_dmod32_bs32                      1.000000
# lam0.2_locTrue_dmod32_bs64                      1.000000
# lam0.2_locTrue_dmod64_bs128                     0.999989
# lam0.2_locTrue_dmod64_bs16                      1.000000
# lam0.2_locTrue_dmod64_bs32                      1.000000
# lam0.2_locTrue_dmod64_bs64                      0.998088
# lam0.5_locFalse_dmod16_bs32                     0.937897
# lam0.5_locFalse_dmod32_bs32                     1.000000
# lam0.5_locFalse_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod16_bs128                     0.958721
# lam0.5_locTrue_dmod16_bs16                      0.952463
# lam0.5_locTrue_dmod16_bs32                      0.969360
# lam0.5_locTrue_dmod16_bs64                      0.945532
# lam0.5_locTrue_dmod32_bs128                     1.000000
# lam0.5_locTrue_dmod32_bs16                      1.000000
# lam0.5_locTrue_dmod32_bs32                      1.000000
# lam0.5_locTrue_dmod32_bs64                      1.000000
# lam0.5_locTrue_dmod64_bs128                     0.977752
# lam0.5_locTrue_dmod64_bs16                      1.000000
# lam0.5_locTrue_dmod64_bs32                      1.000000
# lam0.5_locTrue_dmod64_bs64                      0.999995
#
#                              lam0.5_locTrue_dmod32_bs16  \
# lam0.1_locFalse_dmod16_bs32                    1.000000
# lam0.1_locFalse_dmod32_bs32                    1.000000
# lam0.1_locFalse_dmod64_bs32                    1.000000
# lam0.1_locTrue_dmod16_bs128                    1.000000
# lam0.1_locTrue_dmod16_bs16                     1.000000
# lam0.1_locTrue_dmod16_bs32                     1.000000
# lam0.1_locTrue_dmod16_bs64                     1.000000
# lam0.1_locTrue_dmod32_bs128                    1.000000
# lam0.1_locTrue_dmod32_bs16                     1.000000
# lam0.1_locTrue_dmod32_bs32                     1.000000
# lam0.1_locTrue_dmod32_bs64                     1.000000
# lam0.1_locTrue_dmod64_bs128                    1.000000
# lam0.1_locTrue_dmod64_bs16                     1.000000
# lam0.1_locTrue_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod64_bs64                     1.000000
# lam0.2_locFalse_dmod16_bs32                    0.999964
# lam0.2_locFalse_dmod32_bs32                    1.000000
# lam0.2_locFalse_dmod64_bs32                    0.996118
# lam0.2_locTrue_dmod16_bs128                    1.000000
# lam0.2_locTrue_dmod16_bs16                     1.000000
# lam0.2_locTrue_dmod16_bs32                     1.000000
# lam0.2_locTrue_dmod16_bs64                     1.000000
# lam0.2_locTrue_dmod32_bs128                    1.000000
# lam0.2_locTrue_dmod32_bs16                     1.000000
# lam0.2_locTrue_dmod32_bs32                     1.000000
# lam0.2_locTrue_dmod32_bs64                     1.000000
# lam0.2_locTrue_dmod64_bs128                    0.999799
# lam0.2_locTrue_dmod64_bs16                     1.000000
# lam0.2_locTrue_dmod64_bs32                     1.000000
# lam0.2_locTrue_dmod64_bs64                     0.989072
# lam0.5_locFalse_dmod16_bs32                    0.981204
# lam0.5_locFalse_dmod32_bs32                    1.000000
# lam0.5_locFalse_dmod64_bs32                    1.000000
# lam0.5_locTrue_dmod16_bs128                    0.989072
# lam0.5_locTrue_dmod16_bs16                     0.986825
# lam0.5_locTrue_dmod16_bs32                     0.992626
# lam0.5_locTrue_dmod16_bs64                     0.984215
# lam0.5_locTrue_dmod32_bs128                    1.000000
# lam0.5_locTrue_dmod32_bs16                     1.000000
# lam0.5_locTrue_dmod32_bs32                     1.000000
# lam0.5_locTrue_dmod32_bs64                     1.000000
# lam0.5_locTrue_dmod64_bs128                    0.929530
# lam0.5_locTrue_dmod64_bs16                     1.000000
# lam0.5_locTrue_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod64_bs64                     0.999896
#
#                              lam0.5_locTrue_dmod32_bs32  \
# lam0.1_locFalse_dmod16_bs32                    0.998853
# lam0.1_locFalse_dmod32_bs32                    1.000000
# lam0.1_locFalse_dmod64_bs32                    1.000000
# lam0.1_locTrue_dmod16_bs128                    0.999993
# lam0.1_locTrue_dmod16_bs16                     1.000000
# lam0.1_locTrue_dmod16_bs32                     0.990994
# lam0.1_locTrue_dmod16_bs64                     0.999896
# lam0.1_locTrue_dmod32_bs128                    1.000000
# lam0.1_locTrue_dmod32_bs16                     1.000000
# lam0.1_locTrue_dmod32_bs32                     1.000000
# lam0.1_locTrue_dmod32_bs64                     0.999998
# lam0.1_locTrue_dmod64_bs128                    1.000000
# lam0.1_locTrue_dmod64_bs16                     1.000000
# lam0.1_locTrue_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod64_bs64                     1.000000
# lam0.2_locFalse_dmod16_bs32                    0.834438
# lam0.2_locFalse_dmod32_bs32                    1.000000
# lam0.2_locFalse_dmod64_bs32                    1.000000
# lam0.2_locTrue_dmod16_bs128                    0.986825
# lam0.2_locTrue_dmod16_bs16                     0.999964
# lam0.2_locTrue_dmod16_bs32                     0.998853
# lam0.2_locTrue_dmod16_bs64                     0.999999
# lam0.2_locTrue_dmod32_bs128                    1.000000
# lam0.2_locTrue_dmod32_bs16                     1.000000
# lam0.2_locTrue_dmod32_bs32                     1.000000
# lam0.2_locTrue_dmod32_bs64                     1.000000
# lam0.2_locTrue_dmod64_bs128                    1.000000
# lam0.2_locTrue_dmod64_bs16                     1.000000
# lam0.2_locTrue_dmod64_bs32                     1.000000
# lam0.2_locTrue_dmod64_bs64                     1.000000
# lam0.5_locFalse_dmod16_bs32                    0.365499
# lam0.5_locFalse_dmod32_bs32                    1.000000
# lam0.5_locFalse_dmod64_bs32                    1.000000
# lam0.5_locTrue_dmod16_bs128                    0.423607
# lam0.5_locTrue_dmod16_bs16                     0.403837
# lam0.5_locTrue_dmod16_bs32                     0.464144
# lam0.5_locTrue_dmod16_bs64                     0.384455
# lam0.5_locTrue_dmod32_bs128                    1.000000
# lam0.5_locTrue_dmod32_bs16                     1.000000
# lam0.5_locTrue_dmod32_bs32                     1.000000
# lam0.5_locTrue_dmod32_bs64                     1.000000
# lam0.5_locTrue_dmod64_bs128                    0.999999
# lam0.5_locTrue_dmod64_bs16                     1.000000
# lam0.5_locTrue_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod64_bs64                     1.000000
#
#                              lam0.5_locTrue_dmod32_bs64  \
# lam0.1_locFalse_dmod16_bs32                    0.999628
# lam0.1_locFalse_dmod32_bs32                    1.000000
# lam0.1_locFalse_dmod64_bs32                    1.000000
# lam0.1_locTrue_dmod16_bs128                    0.999999
# lam0.1_locTrue_dmod16_bs16                     1.000000
# lam0.1_locTrue_dmod16_bs32                     0.996118
# lam0.1_locTrue_dmod16_bs64                     0.999975
# lam0.1_locTrue_dmod32_bs128                    1.000000
# lam0.1_locTrue_dmod32_bs16                     1.000000
# lam0.1_locTrue_dmod32_bs32                     1.000000
# lam0.1_locTrue_dmod32_bs64                     1.000000
# lam0.1_locTrue_dmod64_bs128                    1.000000
# lam0.1_locTrue_dmod64_bs16                     1.000000
# lam0.1_locTrue_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod64_bs64                     1.000000
# lam0.2_locFalse_dmod16_bs32                    0.888335
# lam0.2_locFalse_dmod32_bs32                    1.000000
# lam0.2_locFalse_dmod64_bs32                    1.000000
# lam0.2_locTrue_dmod16_bs128                    0.994004
# lam0.2_locTrue_dmod16_bs16                     0.999993
# lam0.2_locTrue_dmod16_bs32                     0.999628
# lam0.2_locTrue_dmod16_bs64                     1.000000
# lam0.2_locTrue_dmod32_bs128                    1.000000
# lam0.2_locTrue_dmod32_bs16                     1.000000
# lam0.2_locTrue_dmod32_bs32                     1.000000
# lam0.2_locTrue_dmod32_bs64                     1.000000
# lam0.2_locTrue_dmod64_bs128                    1.000000
# lam0.2_locTrue_dmod64_bs16                     1.000000
# lam0.2_locTrue_dmod64_bs32                     1.000000
# lam0.2_locTrue_dmod64_bs64                     1.000000
# lam0.5_locFalse_dmod16_bs32                    0.443724
# lam0.5_locFalse_dmod32_bs32                    1.000000
# lam0.5_locFalse_dmod64_bs32                    1.000000
# lam0.5_locTrue_dmod16_bs128                    0.505694
# lam0.5_locTrue_dmod16_bs16                     0.484818
# lam0.5_locTrue_dmod16_bs32                     0.547833
# lam0.5_locTrue_dmod16_bs64                     0.464144
# lam0.5_locTrue_dmod32_bs128                    1.000000
# lam0.5_locTrue_dmod32_bs16                     1.000000
# lam0.5_locTrue_dmod32_bs32                     1.000000
# lam0.5_locTrue_dmod32_bs64                     1.000000
# lam0.5_locTrue_dmod64_bs128                    0.999993
# lam0.5_locTrue_dmod64_bs16                     1.000000
# lam0.5_locTrue_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod64_bs64                     1.000000
#
#                              lam0.5_locTrue_dmod64_bs128  \
# lam0.1_locFalse_dmod16_bs32                     0.232415
# lam0.1_locFalse_dmod32_bs32                     0.999896
# lam0.1_locFalse_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod16_bs128                     0.505694
# lam0.1_locTrue_dmod16_bs16                      0.652649
# lam0.1_locTrue_dmod16_bs32                      0.126817
# lam0.1_locTrue_dmod16_bs64                      0.365499
# lam0.1_locTrue_dmod32_bs128                     1.000000
# lam0.1_locTrue_dmod32_bs16                      0.999998
# lam0.1_locTrue_dmod32_bs32                      0.969360
# lam0.1_locTrue_dmod32_bs64                      0.568980
# lam0.1_locTrue_dmod64_bs128                     0.998088
# lam0.1_locTrue_dmod64_bs16                      1.000000
# lam0.1_locTrue_dmod64_bs32                      0.999896
# lam0.1_locTrue_dmod64_bs64                      1.000000
# lam0.2_locFalse_dmod16_bs32                     0.021873
# lam0.2_locFalse_dmod32_bs32                     0.999896
# lam0.2_locFalse_dmod64_bs32                     1.000000
# lam0.2_locTrue_dmod16_bs128                     0.109423
# lam0.2_locTrue_dmod16_bs16                      0.423607
# lam0.2_locTrue_dmod16_bs32                      0.232415
# lam0.2_locTrue_dmod16_bs64                      0.590097
# lam0.2_locTrue_dmod32_bs128                     0.819036
# lam0.2_locTrue_dmod32_bs16                      0.995158
# lam0.2_locTrue_dmod32_bs32                      0.999997
# lam0.2_locTrue_dmod32_bs64                      0.673022
# lam0.2_locTrue_dmod64_bs128                     1.000000
# lam0.2_locTrue_dmod64_bs16                      1.000000
# lam0.2_locTrue_dmod64_bs32                      1.000000
# lam0.2_locTrue_dmod64_bs64                      1.000000
# lam0.5_locFalse_dmod16_bs32                     0.001803
# lam0.5_locFalse_dmod32_bs32                     0.999500
# lam0.5_locFalse_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod16_bs128                     0.002525
# lam0.5_locTrue_dmod16_bs16                      0.002259
# lam0.5_locTrue_dmod16_bs32                      0.003149
# lam0.5_locTrue_dmod16_bs64                      0.002019
# lam0.5_locTrue_dmod32_bs128                     0.977752
# lam0.5_locTrue_dmod32_bs16                      0.929530
# lam0.5_locTrue_dmod32_bs32                      0.999999
# lam0.5_locTrue_dmod32_bs64                      0.999993
# lam0.5_locTrue_dmod64_bs128                     1.000000
# lam0.5_locTrue_dmod64_bs16                      1.000000
# lam0.5_locTrue_dmod64_bs32                      0.999999
# lam0.5_locTrue_dmod64_bs64                      1.000000
#
#                              lam0.5_locTrue_dmod64_bs16  \
# lam0.1_locFalse_dmod16_bs32                    0.996911
# lam0.1_locFalse_dmod32_bs32                    1.000000
# lam0.1_locFalse_dmod64_bs32                    1.000000
# lam0.1_locTrue_dmod16_bs128                    0.999964
# lam0.1_locTrue_dmod16_bs16                     0.999998
# lam0.1_locTrue_dmod16_bs32                     0.981204
# lam0.1_locTrue_dmod16_bs64                     0.999628
# lam0.1_locTrue_dmod32_bs128                    1.000000
# lam0.1_locTrue_dmod32_bs16                     1.000000
# lam0.1_locTrue_dmod32_bs32                     1.000000
# lam0.1_locTrue_dmod32_bs64                     0.999989
# lam0.1_locTrue_dmod64_bs128                    1.000000
# lam0.1_locTrue_dmod64_bs16                     1.000000
# lam0.1_locTrue_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod64_bs64                     1.000000
# lam0.2_locFalse_dmod16_bs32                    0.768605
# lam0.2_locFalse_dmod32_bs32                    1.000000
# lam0.2_locFalse_dmod64_bs32                    1.000000
# lam0.2_locTrue_dmod16_bs128                    0.973817
# lam0.2_locTrue_dmod16_bs16                     0.999855
# lam0.2_locTrue_dmod16_bs32                     0.996911
# lam0.2_locTrue_dmod16_bs64                     0.999993
# lam0.2_locTrue_dmod32_bs128                    1.000000
# lam0.2_locTrue_dmod32_bs16                     1.000000
# lam0.2_locTrue_dmod32_bs32                     1.000000
# lam0.2_locTrue_dmod32_bs64                     0.999999
# lam0.2_locTrue_dmod64_bs128                    1.000000
# lam0.2_locTrue_dmod64_bs16                     1.000000
# lam0.2_locTrue_dmod64_bs32                     1.000000
# lam0.2_locTrue_dmod64_bs64                     1.000000
# lam0.5_locFalse_dmod16_bs32                    0.294550
# lam0.5_locFalse_dmod32_bs32                    1.000000
# lam0.5_locFalse_dmod64_bs32                    1.000000
# lam0.5_locTrue_dmod16_bs128                    0.347003
# lam0.5_locTrue_dmod16_bs16                     0.328996
# lam0.5_locTrue_dmod16_bs32                     0.384455
# lam0.5_locTrue_dmod16_bs64                     0.311504
# lam0.5_locTrue_dmod32_bs128                    1.000000
# lam0.5_locTrue_dmod32_bs16                     1.000000
# lam0.5_locTrue_dmod32_bs32                     1.000000
# lam0.5_locTrue_dmod32_bs64                     1.000000
# lam0.5_locTrue_dmod64_bs128                    1.000000
# lam0.5_locTrue_dmod64_bs16                     1.000000
# lam0.5_locTrue_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod64_bs64                     1.000000
#
#                              lam0.5_locTrue_dmod64_bs32  \
# lam0.1_locFalse_dmod16_bs32                    0.998853
# lam0.1_locFalse_dmod32_bs32                    1.000000
# lam0.1_locFalse_dmod64_bs32                    1.000000
# lam0.1_locTrue_dmod16_bs128                    0.999993
# lam0.1_locTrue_dmod16_bs16                     1.000000
# lam0.1_locTrue_dmod16_bs32                     0.990994
# lam0.1_locTrue_dmod16_bs64                     0.999896
# lam0.1_locTrue_dmod32_bs128                    1.000000
# lam0.1_locTrue_dmod32_bs16                     1.000000
# lam0.1_locTrue_dmod32_bs32                     1.000000
# lam0.1_locTrue_dmod32_bs64                     0.999998
# lam0.1_locTrue_dmod64_bs128                    1.000000
# lam0.1_locTrue_dmod64_bs16                     1.000000
# lam0.1_locTrue_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod64_bs64                     1.000000
# lam0.2_locFalse_dmod16_bs32                    0.834438
# lam0.2_locFalse_dmod32_bs32                    1.000000
# lam0.2_locFalse_dmod64_bs32                    1.000000
# lam0.2_locTrue_dmod16_bs128                    0.986825
# lam0.2_locTrue_dmod16_bs16                     0.999964
# lam0.2_locTrue_dmod16_bs32                     0.998853
# lam0.2_locTrue_dmod16_bs64                     0.999999
# lam0.2_locTrue_dmod32_bs128                    1.000000
# lam0.2_locTrue_dmod32_bs16                     1.000000
# lam0.2_locTrue_dmod32_bs32                     1.000000
# lam0.2_locTrue_dmod32_bs64                     1.000000
# lam0.2_locTrue_dmod64_bs128                    1.000000
# lam0.2_locTrue_dmod64_bs16                     1.000000
# lam0.2_locTrue_dmod64_bs32                     1.000000
# lam0.2_locTrue_dmod64_bs64                     1.000000
# lam0.5_locFalse_dmod16_bs32                    0.365499
# lam0.5_locFalse_dmod32_bs32                    1.000000
# lam0.5_locFalse_dmod64_bs32                    1.000000
# lam0.5_locTrue_dmod16_bs128                    0.423607
# lam0.5_locTrue_dmod16_bs16                     0.403837
# lam0.5_locTrue_dmod16_bs32                     0.464144
# lam0.5_locTrue_dmod16_bs64                     0.384455
# lam0.5_locTrue_dmod32_bs128                    1.000000
# lam0.5_locTrue_dmod32_bs16                     1.000000
# lam0.5_locTrue_dmod32_bs32                     1.000000
# lam0.5_locTrue_dmod32_bs64                     1.000000
# lam0.5_locTrue_dmod64_bs128                    0.999999
# lam0.5_locTrue_dmod64_bs16                     1.000000
# lam0.5_locTrue_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod64_bs64                     1.000000
#
#                              lam0.5_locTrue_dmod64_bs64
# lam0.1_locFalse_dmod16_bs32                    0.802906
# lam0.1_locFalse_dmod32_bs32                    1.000000
# lam0.1_locFalse_dmod64_bs32                    1.000000
# lam0.1_locTrue_dmod16_bs128                    0.964341
# lam0.1_locTrue_dmod16_bs16                     0.989072
# lam0.1_locTrue_dmod16_bs32                     0.631995
# lam0.1_locTrue_dmod16_bs64                     0.910509
# lam0.1_locTrue_dmod32_bs128                    1.000000
# lam0.1_locTrue_dmod32_bs16                     1.000000
# lam0.1_locTrue_dmod32_bs32                     0.999989
# lam0.1_locTrue_dmod32_bs64                     0.977752
# lam0.1_locTrue_dmod64_bs128                    1.000000
# lam0.1_locTrue_dmod64_bs16                     1.000000
# lam0.1_locTrue_dmod64_bs32                     1.000000
# lam0.1_locTrue_dmod64_bs64                     1.000000
# lam0.2_locFalse_dmod16_bs32                    0.232415
# lam0.2_locFalse_dmod32_bs32                    1.000000
# lam0.2_locFalse_dmod64_bs32                    1.000000
# lam0.2_locTrue_dmod16_bs128                    0.590097
# lam0.2_locTrue_dmod16_bs16                     0.937897
# lam0.2_locTrue_dmod16_bs32                     0.802906
# lam0.2_locTrue_dmod16_bs64                     0.981204
# lam0.2_locTrue_dmod32_bs128                    0.998513
# lam0.2_locTrue_dmod32_bs16                     1.000000
# lam0.2_locTrue_dmod32_bs32                     1.000000
# lam0.2_locTrue_dmod32_bs64                     0.990994
# lam0.2_locTrue_dmod64_bs128                    1.000000
# lam0.2_locTrue_dmod64_bs16                     1.000000
# lam0.2_locTrue_dmod64_bs32                     1.000000
# lam0.2_locTrue_dmod64_bs64                     1.000000
# lam0.5_locFalse_dmod16_bs32                    0.037795
# lam0.5_locFalse_dmod32_bs32                    1.000000
# lam0.5_locFalse_dmod64_bs32                    1.000000
# lam0.5_locTrue_dmod16_bs128                    0.049047
# lam0.5_locTrue_dmod16_bs16                     0.045010
# lam0.5_locTrue_dmod16_bs32                     0.058066
# lam0.5_locTrue_dmod16_bs64                     0.041265
# lam0.5_locTrue_dmod32_bs128                    0.999995
# lam0.5_locTrue_dmod32_bs16                     0.999896
# lam0.5_locTrue_dmod32_bs32                     1.000000
# lam0.5_locTrue_dmod32_bs64                     1.000000
# lam0.5_locTrue_dmod64_bs128                    1.000000
# lam0.5_locTrue_dmod64_bs16                     1.000000
# lam0.5_locTrue_dmod64_bs32                     1.000000
# lam0.5_locTrue_dmod64_bs64                     1.000000
#
# [45 rows x 45 columns]

# %%
df = pd.read_csv('results_ns_nap_prediction_bpi20RequestForPayment.csv')

pivot_table = pd.pivot_table(df, 
                             values=['f1', 'precision', 'accuracy'], 
                             
                             index=['trans_model', 'local', 'batch_size', 'max_len', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_max, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_68650/3172815308.py:3: FutureWarning: The provided callable <function mean at 0x1064d6200> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_87aab_row0_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_87aab_row0_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_87aab_row0_col2 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_87aab_row1_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_87aab_row1_col1 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_87aab_row1_col2 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_87aab_row2_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_87aab_row2_col1, #T_87aab_row2_col2 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_87aab_row3_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_87aab_row3_col1 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_87aab_row3_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_87aab_row4_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_87aab_row4_col1 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_87aab_row4_col2 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_87aab_row5_col0, #T_87aab_row5_col1, #T_87aab_row5_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-decoration: underline;
# }
# #T_87aab_row6_col0, #T_87aab_row6_col1, #T_87aab_row6_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_87aab_row7_col0 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_87aab_row7_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_87aab_row7_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_87aab_row8_col0 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_87aab_row8_col1 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_87aab_row8_col2 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_87aab">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87aab_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_87aab_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_87aab_level0_col2" class="col_heading level0 col2" >precision</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >trans_model</th>
#       <th class="index_name level1" >local</th>
#       <th class="index_name level2" >batch_size</th>
#       <th class="index_name level3" >max_len</th>
#       <th class="index_name level4" >d_model</th>
#       <th class="index_name level5" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87aab_level0_row0" class="row_heading level0 row0" rowspan="3">AutomatonAwareTransformer</th>
#       <th id="T_87aab_level1_row0" class="row_heading level1 row0" rowspan="3">False</th>
#       <th id="T_87aab_level2_row0" class="row_heading level2 row0" rowspan="3">32</th>
#       <th id="T_87aab_level3_row0" class="row_heading level3 row0" rowspan="3">9</th>
#       <th id="T_87aab_level4_row0" class="row_heading level4 row0" >16</th>
#       <th id="T_87aab_level5_row0" class="row_heading level5 row0" >0</th>
#       <td id="T_87aab_row0_col0" class="data row0 col0" >0.916274</td>
#       <td id="T_87aab_row0_col1" class="data row0 col1" >0.948140</td>
#       <td id="T_87aab_row0_col2" class="data row0 col2" >0.989455</td>
#     </tr>
#     <tr>
#       <th id="T_87aab_level4_row1" class="row_heading level4 row1" >32</th>
#       <th id="T_87aab_level5_row1" class="row_heading level5 row1" >0</th>
#       <td id="T_87aab_row1_col0" class="data row1 col0" >0.916825</td>
#       <td id="T_87aab_row1_col1" class="data row1 col1" >0.948645</td>
#       <td id="T_87aab_row1_col2" class="data row1 col2" >0.989903</td>
#     </tr>
#     <tr>
#       <th id="T_87aab_level4_row2" class="row_heading level4 row2" >64</th>
#       <th id="T_87aab_level5_row2" class="row_heading level5 row2" >0</th>
#       <td id="T_87aab_row2_col0" class="data row2 col0" >0.917702</td>
#       <td id="T_87aab_row2_col1" class="data row2 col1" >0.949272</td>
#       <td id="T_87aab_row2_col2" class="data row2 col2" >0.990352</td>
#     </tr>
#     <tr>
#       <th id="T_87aab_level0_row3" class="row_heading level0 row3" rowspan="3">DFGAwareTransformer</th>
#       <th id="T_87aab_level1_row3" class="row_heading level1 row3" rowspan="3">False</th>
#       <th id="T_87aab_level2_row3" class="row_heading level2 row3" rowspan="3">32</th>
#       <th id="T_87aab_level3_row3" class="row_heading level3 row3" rowspan="3">9</th>
#       <th id="T_87aab_level4_row3" class="row_heading level4 row3" >16</th>
#       <th id="T_87aab_level5_row3" class="row_heading level5 row3" >0</th>
#       <td id="T_87aab_row3_col0" class="data row3 col0" >0.916249</td>
#       <td id="T_87aab_row3_col1" class="data row3 col1" >0.948107</td>
#       <td id="T_87aab_row3_col2" class="data row3 col2" >0.989422</td>
#     </tr>
#     <tr>
#       <th id="T_87aab_level4_row4" class="row_heading level4 row4" >32</th>
#       <th id="T_87aab_level5_row4" class="row_heading level5 row4" >0</th>
#       <td id="T_87aab_row4_col0" class="data row4 col0" >0.917151</td>
#       <td id="T_87aab_row4_col1" class="data row4 col1" >0.948781</td>
#       <td id="T_87aab_row4_col2" class="data row4 col2" >0.989843</td>
#     </tr>
#     <tr>
#       <th id="T_87aab_level4_row5" class="row_heading level4 row5" >64</th>
#       <th id="T_87aab_level5_row5" class="row_heading level5 row5" >0</th>
#       <td id="T_87aab_row5_col0" class="data row5 col0" >0.917727</td>
#       <td id="T_87aab_row5_col1" class="data row5 col1" >0.949302</td>
#       <td id="T_87aab_row5_col2" class="data row5 col2" >0.990378</td>
#     </tr>
#     <tr>
#       <th id="T_87aab_level0_row6" class="row_heading level0 row6" rowspan="3">EventTransformer</th>
#       <th id="T_87aab_level1_row6" class="row_heading level1 row6" rowspan="3">False</th>
#       <th id="T_87aab_level2_row6" class="row_heading level2 row6" rowspan="3">32</th>
#       <th id="T_87aab_level3_row6" class="row_heading level3 row6" rowspan="3">9</th>
#       <th id="T_87aab_level4_row6" class="row_heading level4 row6" >16</th>
#       <th id="T_87aab_level5_row6" class="row_heading level5 row6" >0</th>
#       <td id="T_87aab_row6_col0" class="data row6 col0" >0.915648</td>
#       <td id="T_87aab_row6_col1" class="data row6 col1" >0.947500</td>
#       <td id="T_87aab_row6_col2" class="data row6 col2" >0.988811</td>
#     </tr>
#     <tr>
#       <th id="T_87aab_level4_row7" class="row_heading level4 row7" >32</th>
#       <th id="T_87aab_level5_row7" class="row_heading level5 row7" >0</th>
#       <td id="T_87aab_row7_col0" class="data row7 col0" >0.916400</td>
#       <td id="T_87aab_row7_col1" class="data row7 col1" >0.948192</td>
#       <td id="T_87aab_row7_col2" class="data row7 col2" >0.989439</td>
#     </tr>
#     <tr>
#       <th id="T_87aab_level4_row8" class="row_heading level4 row8" >64</th>
#       <th id="T_87aab_level5_row8" class="row_heading level5 row8" >0</th>
#       <td id="T_87aab_row8_col0" class="data row8 col0" >0.917401</td>
#       <td id="T_87aab_row8_col1" class="data row8 col1" >0.949026</td>
#       <td id="T_87aab_row8_col2" class="data row8 col2" >0.990163</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
import numpy as np
from matplotlib import cm, colors

df = pd.read_csv('results_nap_prediction_bpi17.csv')

# df = df[df['batch_size']>16]
pivot_table = pd.pivot_table(df, 
                             values=['f1', 'precision', 'accuracy'], 
                             
                             index=['model', 'local', 'batch_size', 'max_len', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_max, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_85849/3586447409.py:8: FutureWarning: The provided callable <function mean at 0x104bca660> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_48ed8_row0_col0 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_48ed8_row0_col1 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_48ed8_row0_col2 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_48ed8_row1_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_48ed8_row1_col1, #T_48ed8_row8_col0, #T_48ed8_row8_col1, #T_48ed8_row25_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_48ed8_row1_col2, #T_48ed8_row34_col1, #T_48ed8_row35_col0, #T_48ed8_row37_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_48ed8_row2_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_48ed8_row2_col1, #T_48ed8_row16_col2, #T_48ed8_row18_col0, #T_48ed8_row33_col2 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_48ed8_row2_col2, #T_48ed8_row15_col2 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_48ed8_row3_col0, #T_48ed8_row6_col2, #T_48ed8_row13_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_48ed8_row3_col1, #T_48ed8_row41_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_48ed8_row3_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_48ed8_row4_col0, #T_48ed8_row4_col1, #T_48ed8_row39_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_48ed8_row4_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_48ed8_row5_col0, #T_48ed8_row5_col1 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_48ed8_row5_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_48ed8_row6_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_48ed8_row6_col1 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_48ed8_row7_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_48ed8_row7_col1, #T_48ed8_row30_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_48ed8_row7_col2 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_48ed8_row8_col2 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_48ed8_row9_col0 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_48ed8_row9_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_48ed8_row9_col2, #T_48ed8_row38_col2 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_48ed8_row10_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_48ed8_row10_col1, #T_48ed8_row34_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_48ed8_row10_col2 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_48ed8_row11_col0, #T_48ed8_row11_col1, #T_48ed8_row11_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-decoration: underline;
# }
# #T_48ed8_row12_col0, #T_48ed8_row33_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_48ed8_row12_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_48ed8_row12_col2 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_48ed8_row13_col1, #T_48ed8_row16_col0 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_48ed8_row13_col2 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_48ed8_row14_col0, #T_48ed8_row22_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_48ed8_row14_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_48ed8_row14_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_48ed8_row15_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_48ed8_row15_col1 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_48ed8_row16_col1, #T_48ed8_row42_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_48ed8_row17_col0, #T_48ed8_row21_col1 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_48ed8_row17_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_48ed8_row17_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_48ed8_row18_col1, #T_48ed8_row27_col1 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_48ed8_row18_col2, #T_48ed8_row45_col2 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_48ed8_row19_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_48ed8_row19_col1, #T_48ed8_row28_col2 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_48ed8_row19_col2, #T_48ed8_row43_col2, #T_48ed8_row46_col2 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_48ed8_row20_col0 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_48ed8_row20_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_48ed8_row20_col2, #T_48ed8_row28_col0, #T_48ed8_row36_col0 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_48ed8_row21_col0 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_48ed8_row21_col2, #T_48ed8_row29_col2 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_48ed8_row22_col0 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_48ed8_row22_col2 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_48ed8_row23_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_48ed8_row23_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_48ed8_row23_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_48ed8_row24_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_48ed8_row24_col1, #T_48ed8_row47_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_48ed8_row24_col2, #T_48ed8_row46_col1 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_48ed8_row25_col1, #T_48ed8_row42_col1 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_48ed8_row25_col2 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_48ed8_row26_col0, #T_48ed8_row26_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_48ed8_row26_col2 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_48ed8_row27_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_48ed8_row27_col2 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_48ed8_row28_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_48ed8_row29_col0 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_48ed8_row29_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_48ed8_row30_col0, #T_48ed8_row36_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_48ed8_row30_col1, #T_48ed8_row40_col2 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_48ed8_row31_col0 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_48ed8_row31_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_48ed8_row31_col2, #T_48ed8_row39_col0 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_48ed8_row32_col0 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_48ed8_row32_col1, #T_48ed8_row40_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_48ed8_row32_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_48ed8_row33_col1 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_48ed8_row34_col2, #T_48ed8_row36_col2, #T_48ed8_row47_col2 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_48ed8_row35_col1, #T_48ed8_row44_col1 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_48ed8_row35_col2 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_48ed8_row37_col0 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_48ed8_row37_col2, #T_48ed8_row47_col1 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_48ed8_row38_col0 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_48ed8_row38_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_48ed8_row39_col1 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_48ed8_row40_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_48ed8_row41_col0 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_48ed8_row41_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_48ed8_row42_col2 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_48ed8_row43_col0, #T_48ed8_row45_col0, #T_48ed8_row45_col1 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_48ed8_row43_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_48ed8_row44_col0 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_48ed8_row44_col2 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_48ed8_row46_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_48ed8">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbs

# %%
import pandas as pd
import numpy as np
from matplotlib import cm, colors

df = pd.read_csv('results_nap_prediction_bpi19.csv')

# df = df[df['batch_size']>16]
pivot_table = pd.pivot_table(df, 
                             values=['f1', 'precision', 'accuracy'], 
                             
                             index=['model', 'local', 'batch_size', 'max_len', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_max, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_85849/483172717.py:8: FutureWarning: The provided callable <function mean at 0x104bca660> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_a9609_row0_col0 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_a9609_row0_col1, #T_a9609_row2_col0, #T_a9609_row14_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_a9609_row0_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_a9609_row1_col0, #T_a9609_row4_col1, #T_a9609_row30_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-decoration: underline;
# }
# #T_a9609_row1_col1 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_a9609_row1_col2, #T_a9609_row4_col2, #T_a9609_row10_col1, #T_a9609_row17_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_a9609_row2_col1 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_a9609_row2_col2, #T_a9609_row23_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_a9609_row3_col0, #T_a9609_row45_col1, #T_a9609_row47_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_a9609_row3_col1 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_a9609_row3_col2, #T_a9609_row44_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_a9609_row4_col0, #T_a9609_row6_col0, #T_a9609_row42_col0 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_a9609_row5_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_a9609_row5_col1, #T_a9609_row37_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_a9609_row5_col2 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_a9609_row6_col1, #T_a9609_row7_col0, #T_a9609_row33_col1 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_a9609_row6_col2 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_a9609_row7_col1 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_a9609_row7_col2, #T_a9609_row24_col2 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_a9609_row8_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_a9609_row8_col1 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_a9609_row8_col2 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_a9609_row9_col0, #T_a9609_row19_col1, #T_a9609_row28_col0, #T_a9609_row45_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_a9609_row9_col1, #T_a9609_row39_col2 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_a9609_row9_col2 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_a9609_row10_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_a9609_row10_col2, #T_a9609_row27_col0, #T_a9609_row47_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_a9609_row11_col0, #T_a9609_row29_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_a9609_row11_col1, #T_a9609_row15_col1, #T_a9609_row29_col2 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_a9609_row11_col2 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_a9609_row12_col0 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_a9609_row12_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_a9609_row12_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_a9609_row13_col0, #T_a9609_row13_col1, #T_a9609_row43_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a9609_row13_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_a9609_row14_col1, #T_a9609_row33_col0, #T_a9609_row42_col2 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_a9609_row14_col2 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_a9609_row15_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_a9609_row15_col2, #T_a9609_row25_col2 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_a9609_row16_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_a9609_row16_col1 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_a9609_row16_col2, #T_a9609_row35_col0 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_a9609_row17_col1, #T_a9609_row18_col1, #T_a9609_row35_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_a9609_row17_col2, #T_a9609_row36_col2 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_a9609_row18_col0, #T_a9609_row30_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_a9609_row18_col2 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_a9609_row19_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_a9609_row19_col2, #T_a9609_row20_col1, #T_a9609_row29_col1, #T_a9609_row38_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_a9609_row20_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_a9609_row20_col2, #T_a9609_row46_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_a9609_row21_col0 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_a9609_row21_col1, #T_a9609_row42_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_a9609_row21_col2, #T_a9609_row25_col1 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_a9609_row22_col0 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_a9609_row22_col1, #T_a9609_row39_col0, #T_a9609_row46_col2 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_a9609_row22_col2 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_a9609_row23_col1 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_a9609_row23_col2, #T_a9609_row27_col2 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_a9609_row24_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_a9609_row24_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_a9609_row25_col0 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_a9609_row26_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_a9609_row26_col1, #T_a9609_row40_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_a9609_row26_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_a9609_row27_col1, #T_a9609_row28_col1 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_a9609_row28_col2 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_a9609_row30_col0, #T_a9609_row31_col1 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_a9609_row31_col0 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_a9609_row31_col2 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_a9609_row32_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_a9609_row32_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_a9609_row32_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_a9609_row33_col2 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_a9609_row34_col0 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_a9609_row34_col1, #T_a9609_row44_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_a9609_row34_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_a9609_row35_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_a9609_row36_col0, #T_a9609_row38_col2 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_a9609_row36_col1 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_a9609_row37_col0 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_a9609_row37_col2 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_a9609_row38_col0, #T_a9609_row46_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_a9609_row39_col1 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_a9609_row40_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_a9609_row40_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_a9609_row41_col0 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_a9609_row41_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_a9609_row41_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_a9609_row43_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_a9609_row43_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_a9609_row44_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_a9609_row45_col2 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_a9609_row47_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a9609">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9609_le

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('results_nap_prediction_BPI20PrepaidTravelCosts.csv')

# df = df[df['batch_size']>16]
pivot_table = pd.pivot_table(df, 
                             values=['f1', 'precision', 'accuracy'], 
                             
                             index=['model', 'local', 'batch_size', 'max_len', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_max, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_85849/3815714939.py:7: FutureWarning: The provided callable <function mean at 0x104bca660> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_b9ff4_row0_col0, #T_b9ff4_row40_col2 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_b9ff4_row0_col1 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_b9ff4_row0_col2 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_b9ff4_row1_col0, #T_b9ff4_row5_col2 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_b9ff4_row1_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_b9ff4_row1_col2, #T_b9ff4_row37_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_b9ff4_row2_col0, #T_b9ff4_row38_col1, #T_b9ff4_row38_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-decoration: underline;
# }
# #T_b9ff4_row2_col1, #T_b9ff4_row27_col0, #T_b9ff4_row27_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_b9ff4_row2_col2, #T_b9ff4_row6_col2 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_b9ff4_row3_col0 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_b9ff4_row3_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_b9ff4_row3_col2 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_b9ff4_row4_col0 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_b9ff4_row4_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_b9ff4_row4_col2, #T_b9ff4_row37_col2, #T_b9ff4_row47_col1 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_b9ff4_row5_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_b9ff4_row5_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_b9ff4_row6_col0, #T_b9ff4_row12_col2 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_b9ff4_row6_col1 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_b9ff4_row7_col0 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_b9ff4_row7_col1, #T_b9ff4_row15_col1, #T_b9ff4_row33_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_b9ff4_row7_col2, #T_b9ff4_row9_col2, #T_b9ff4_row11_col1, #T_b9ff4_row13_col2, #T_b9ff4_row21_col2, #T_b9ff4_row33_col1 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_b9ff4_row8_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_b9ff4_row8_col1, #T_b9ff4_row21_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_b9ff4_row8_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_b9ff4_row9_col0, #T_b9ff4_row19_col0, #T_b9ff4_row43_col2 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_b9ff4_row9_col1, #T_b9ff4_row16_col2, #T_b9ff4_row37_col1, #T_b9ff4_row45_col1, #T_b9ff4_row47_col0 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_b9ff4_row10_col0, #T_b9ff4_row25_col2, #T_b9ff4_row28_col1, #T_b9ff4_row36_col2 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_b9ff4_row10_col1, #T_b9ff4_row10_col2, #T_b9ff4_row33_col2 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_b9ff4_row11_col0, #T_b9ff4_row15_col2, #T_b9ff4_row35_col2, #T_b9ff4_row44_col2 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_b9ff4_row11_col2, #T_b9ff4_row19_col1, #T_b9ff4_row19_col2, #T_b9ff4_row34_col0 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_b9ff4_row12_col0, #T_b9ff4_row17_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_b9ff4_row12_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_b9ff4_row13_col0 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_b9ff4_row13_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_b9ff4_row14_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_b9ff4_row14_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_b9ff4_row14_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_b9ff4_row15_col0, #T_b9ff4_row24_col1, #T_b9ff4_row42_col0, #T_b9ff4_row43_col1 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_b9ff4_row16_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_b9ff4_row16_col1, #T_b9ff4_row39_col2 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_b9ff4_row17_col0, #T_b9ff4_row40_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_b9ff4_row17_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_b9ff4_row18_col0, #T_b9ff4_row20_col0, #T_b9ff4_row45_col2 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_b9ff4_row18_col1, #T_b9ff4_row46_col2 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_b9ff4_row18_col2, #T_b9ff4_row46_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_b9ff4_row20_col1, #T_b9ff4_row38_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_b9ff4_row20_col2, #T_b9ff4_row27_col2, #T_b9ff4_row34_col1, #T_b9ff4_row46_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_b9ff4_row21_col1 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_b9ff4_row22_col0, #T_b9ff4_row40_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_b9ff4_row22_col1 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_b9ff4_row22_col2, #T_b9ff4_row25_col0 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_b9ff4_row23_col0, #T_b9ff4_row23_col1, #T_b9ff4_row23_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b9ff4_row24_col0, #T_b9ff4_row29_col0, #T_b9ff4_row43_col0 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_b9ff4_row24_col2, #T_b9ff4_row28_col2, #T_b9ff4_row34_col2, #T_b9ff4_row42_col2 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_b9ff4_row25_col1 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_b9ff4_row26_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_b9ff4_row26_col1 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_b9ff4_row26_col2, #T_b9ff4_row36_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_b9ff4_row28_col0, #T_b9ff4_row29_col2, #T_b9ff4_row47_col2 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_b9ff4_row29_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_b9ff4_row30_col0 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_b9ff4_row30_col1, #T_b9ff4_row35_col1 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_b9ff4_row30_col2, #T_b9ff4_row45_col0 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_b9ff4_row31_col0 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_b9ff4_row31_col1 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_b9ff4_row31_col2 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_b9ff4_row32_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_b9ff4_row32_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_b9ff4_row32_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_b9ff4_row35_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_b9ff4_row36_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_b9ff4_row39_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_b9ff4_row39_col1 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_b9ff4_row41_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_b9ff4_row41_col1 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_b9ff4_row41_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_b9ff4_row42_col1 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_b9ff4_row44_col0 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_b9ff4_row44_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b9ff4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9ff4_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_b9ff4_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_b9ff4_level0_col2" class="col_heading level0 col2" >precision</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >local</th>
#       <th class="index_name level2" >batch_size</th>
#       <th class="index_name level3" >max_len</th>
#       <th class="index_name level4" >d_model</th>
#       <th class="index_name level5" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&n

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('results_nap_prediction_BPI20RequestForPayment.csv')

pivot_table = pd.pivot_table(df, 
                             values=['f1', 'precision', 'accuracy'], 
                             
                             index=['model', 'local', 'batch_size', 'max_len', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_max, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_16656/31039308.py:6: FutureWarning: The provided callable <function mean at 0x105aca5c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_9c539_row0_col0 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_9c539_row0_col1, #T_9c539_row17_col1 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_9c539_row0_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_9c539_row1_col0, #T_9c539_row1_col1, #T_9c539_row6_col0, #T_9c539_row7_col0, #T_9c539_row11_col0, #T_9c539_row11_col1, #T_9c539_row19_col2, #T_9c539_row25_col1, #T_9c539_row28_col0, #T_9c539_row28_col1, #T_9c539_row33_col0, #T_9c539_row33_col1, #T_9c539_row42_col0, #T_9c539_row47_col0, #T_9c539_row47_col1 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_9c539_row1_col2, #T_9c539_row11_col2 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_9c539_row2_col0, #T_9c539_row2_col1, #T_9c539_row18_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-decoration: underline;
# }
# #T_9c539_row2_col2, #T_9c539_row9_col0, #T_9c539_row9_col1, #T_9c539_row18_col0, #T_9c539_row19_col0, #T_9c539_row19_col1, #T_9c539_row36_col0, #T_9c539_row36_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_9c539_row3_col0, #T_9c539_row3_col1, #T_9c539_row40_col1 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_9c539_row3_col2 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_9c539_row4_col0, #T_9c539_row26_col1 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_9c539_row4_col1, #T_9c539_row12_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_9c539_row4_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_9c539_row5_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_9c539_row5_col1 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_9c539_row5_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_9c539_row6_col1, #T_9c539_row7_col1, #T_9c539_row29_col0, #T_9c539_row42_col1 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_9c539_row6_col2, #T_9c539_row42_col2 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_9c539_row7_col2, #T_9c539_row26_col0, #T_9c539_row35_col0, #T_9c539_row39_col0 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_9c539_row8_col0 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_9c539_row8_col1, #T_9c539_row13_col0, #T_9c539_row21_col0, #T_9c539_row30_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_9c539_row8_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_9c539_row9_col2, #T_9c539_row10_col0, #T_9c539_row10_col1, #T_9c539_row25_col0, #T_9c539_row27_col0, #T_9c539_row27_col1, #T_9c539_row36_col2, #T_9c539_row37_col0, #T_9c539_row37_col1, #T_9c539_row45_col0, #T_9c539_row45_col1, #T_9c539_row46_col0, #T_9c539_row46_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_9c539_row10_col2, #T_9c539_row16_col0, #T_9c539_row27_col2, #T_9c539_row43_col0, #T_9c539_row45_col2 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_9c539_row12_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_9c539_row12_col2 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_9c539_row13_col1, #T_9c539_row15_col2, #T_9c539_row21_col1, #T_9c539_row22_col0, #T_9c539_row31_col1, #T_9c539_row38_col2 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_9c539_row13_col2, #T_9c539_row23_col0, #T_9c539_row23_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9c539_row14_col0, #T_9c539_row41_col1 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_9c539_row14_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_9c539_row14_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_9c539_row15_col0, #T_9c539_row20_col0, #T_9c539_row24_col0, #T_9c539_row38_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_9c539_row15_col1, #T_9c539_row20_col1, #T_9c539_row38_col1 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_9c539_row16_col1, #T_9c539_row43_col1, #T_9c539_row46_col2 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_9c539_row16_col2, #T_9c539_row22_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_9c539_row17_col0, #T_9c539_row29_col2 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_9c539_row17_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_9c539_row18_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9c539_row20_col2 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_9c539_row21_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_9c539_row22_col2 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_9c539_row23_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_9c539_row24_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_9c539_row24_col2 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_9c539_row25_col2, #T_9c539_row34_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_9c539_row26_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_9c539_row28_col2, #T_9c539_row33_col2 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_9c539_row29_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_9c539_row30_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_9c539_row30_col2 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_9c539_row31_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_9c539_row31_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_9c539_row32_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_9c539_row32_col1, #T_9c539_row32_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_9c539_row34_col1 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_9c539_row34_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_9c539_row35_col1, #T_9c539_row39_col1 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_9c539_row35_col2 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_9c539_row37_col2 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_9c539_row39_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_9c539_row40_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_9c539_row40_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_9c539_row41_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_9c539_row41_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_9c539_row43_col2 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_9c539_row44_col0 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_9c539_row44_col1 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_9c539_row44_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_9c539_row47_col2 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9c539">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c539_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_9c539_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_9c539_level0_col2" class="col_heading level0 col2" >precision</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >local</th>
#       <th class="index_name level2" >batch_size</th>
#       <th class="index_name level3" >max_len</th>
#       <th class="index_name level4" >d_model</th>
#       <th class="index_name level5" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c539_level0_row0" class="row_heading level0 row0" rowspan="3">NAP_model</th>
#       <th id="T_9c539_level1_row0" class="row_heading level1 row0" rowspan="3">False</th>
#       <th id="T_9c539_level2_row0" class="row_heading level2 row0" rowspan="3">32</th>
#       <th id="T_9c539_level3_row0" class="row_heading level3 row0" rowspan="3">9</th>
#       <th id="T_9c539_level4_row0" class="row_heading level4 row0" >16</th>
#       <th id="T_9c539_level5_row0" class="row_heading level5 row0" >0.000000</th>
#       <td id="T_9c539_row0_col0" cl

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('results_nap_prediction_BPI20TravelPermitData.csv')

pivot_table = pd.pivot_table(df, 
                             values=['f1', 'precision', 'accuracy'], 
                             
                             index=['model', 'local', 'batch_size', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_max, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_16656/3160779264.py:6: FutureWarning: The provided callable <function mean at 0x105aca5c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_f042e_row0_col0, #T_f042e_row31_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_f042e_row0_col1 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_f042e_row0_col2, #T_f042e_row17_col2 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_f042e_row1_col0, #T_f042e_row7_col2 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_f042e_row1_col1, #T_f042e_row8_col1, #T_f042e_row28_col2 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_f042e_row1_col2, #T_f042e_row11_col1, #T_f042e_row28_col0, #T_f042e_row28_col1, #T_f042e_row42_col0 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_f042e_row2_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_f042e_row2_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_f042e_row2_col2 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_f042e_row3_col0 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_f042e_row3_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_f042e_row3_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_f042e_row4_col0 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_f042e_row4_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_f042e_row4_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_f042e_row5_col0, #T_f042e_row5_col1, #T_f042e_row23_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f042e_row5_col2, #T_f042e_row32_col2 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_f042e_row6_col0, #T_f042e_row6_col1, #T_f042e_row8_col2, #T_f042e_row19_col2 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_f042e_row6_col2 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_f042e_row7_col0, #T_f042e_row7_col1 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_f042e_row8_col0 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_f042e_row9_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_f042e_row9_col1, #T_f042e_row15_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_f042e_row9_col2, #T_f042e_row45_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_f042e_row10_col0, #T_f042e_row46_col0 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_f042e_row10_col1 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_f042e_row10_col2, #T_f042e_row47_col0, #T_f042e_row47_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-decoration: underline;
# }
# #T_f042e_row11_col0, #T_f042e_row20_col1 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_f042e_row11_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_f042e_row12_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_f042e_row12_col1, #T_f042e_row33_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_f042e_row12_col2 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_f042e_row13_col0, #T_f042e_row13_col2 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_f042e_row13_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_f042e_row14_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_f042e_row14_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_f042e_row14_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_f042e_row15_col0, #T_f042e_row35_col1, #T_f042e_row44_col2, #T_f042e_row46_col2 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_f042e_row15_col2, #T_f042e_row44_col1 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_f042e_row16_col0 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_f042e_row16_col1, #T_f042e_row35_col2 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_f042e_row16_col2, #T_f042e_row21_col1, #T_f042e_row30_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_f042e_row17_col0, #T_f042e_row33_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_f042e_row17_col1, #T_f042e_row39_col2, #T_f042e_row43_col0 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_f042e_row18_col0 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_f042e_row18_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_f042e_row18_col2, #T_f042e_row22_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_f042e_row19_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_f042e_row19_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_f042e_row20_col0, #T_f042e_row36_col1 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_f042e_row20_col2, #T_f042e_row27_col1 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_f042e_row21_col0 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_f042e_row21_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_f042e_row22_col1 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_f042e_row22_col2, #T_f042e_row34_col2 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_f042e_row23_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_f042e_row23_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_f042e_row24_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_f042e_row24_col1, #T_f042e_row26_col2, #T_f042e_row43_col1 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_f042e_row24_col2 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_f042e_row25_col0 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_f042e_row25_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_f042e_row25_col2, #T_f042e_row38_col2 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_f042e_row26_col0, #T_f042e_row29_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_f042e_row26_col1, #T_f042e_row29_col1 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_f042e_row27_col0, #T_f042e_row35_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_f042e_row27_col2 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_f042e_row29_col2, #T_f042e_row42_col2 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_f042e_row30_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_f042e_row30_col2 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_f042e_row31_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_f042e_row31_col1 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_f042e_row32_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_f042e_row32_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_f042e_row33_col2 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_f042e_row34_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_f042e_row34_col1 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_f042e_row36_col0, #T_f042e_row37_col2 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_f042e_row36_col2 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_f042e_row37_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_f042e_row37_col1 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_f042e_row38_col0 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_f042e_row38_col1 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_f042e_row39_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_f042e_row39_col1 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_f042e_row40_col0 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_f042e_row40_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_f042e_row40_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_f042e_row41_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_f042e_row41_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_f042e_row41_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_f042e_row42_col1 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_f042e_row43_col2 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_f042e_row44_col0 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_f042e_row45_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_f042e_row45_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_f042e_row46_col1 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_f042e_row47_col2 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f042e">
#   <thead>
#     <tr>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('results_nap_prediction_BPI20TravelPermitData.csv')

# df = df[df['lambda']<0.5]
pivot_table = pd.pivot_table(df, 
                             values=['f1', 'precision', 'accuracy'], 
                             
                             index=['d_model', 'seed', 'model'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_max, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_16656/2873691937.py:7: FutureWarning: The provided callable <function mean at 0x105aca5c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_370b2_row0_col0, #T_370b2_row3_col0, #T_370b2_row3_col1, #T_370b2_row22_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_370b2_row0_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_370b2_row0_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_370b2_row1_col0 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_370b2_row1_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_370b2_row1_col2 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_370b2_row2_col0 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_370b2_row2_col1 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_370b2_row2_col2 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_370b2_row3_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_370b2_row4_col0 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_370b2_row4_col1, #T_370b2_row18_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_370b2_row4_col2 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_370b2_row5_col0 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_370b2_row5_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_370b2_row5_col2 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_370b2_row6_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_370b2_row6_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_370b2_row6_col2 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_370b2_row7_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_370b2_row7_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_370b2_row7_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_370b2_row8_col0, #T_370b2_row21_col2 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_370b2_row8_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_370b2_row8_col2, #T_370b2_row14_col1 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_370b2_row9_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_370b2_row9_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_370b2_row9_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_370b2_row10_col0, #T_370b2_row16_col1, #T_370b2_row26_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-decoration: underline;
# }
# #T_370b2_row10_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_370b2_row10_col2, #T_370b2_row20_col0, #T_370b2_row29_col2 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_370b2_row11_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_370b2_row11_col1 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_370b2_row11_col2 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_370b2_row12_col0, #T_370b2_row15_col0 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_370b2_row12_col1 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_370b2_row12_col2 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_370b2_row13_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_370b2_row13_col1 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_370b2_row13_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_370b2_row14_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_370b2_row14_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_370b2_row15_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_370b2_row15_col2 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_370b2_row16_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_370b2_row16_col2, #T_370b2_row28_col2 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_370b2_row17_col0, #T_370b2_row23_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_370b2_row17_col1 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_370b2_row17_col2 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_370b2_row18_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_370b2_row18_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_370b2_row19_col0 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_370b2_row19_col1, #T_370b2_row20_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_370b2_row19_col2 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_370b2_row20_col2, #T_370b2_row23_col1 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_370b2_row21_col0, #T_370b2_row29_col0, #T_370b2_row29_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_370b2_row21_col1, #T_370b2_row27_col1 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_370b2_row22_col0 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_370b2_row22_col1 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_370b2_row23_col0 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_370b2_row24_col0, #T_370b2_row28_col0 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_370b2_row24_col1 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_370b2_row24_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_370b2_row25_col0, #T_370b2_row25_col1 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_370b2_row25_col2 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_370b2_row26_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_370b2_row26_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_370b2_row27_col0 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_370b2_row27_col2 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_370b2_row28_col1 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# </style>
# <table id="T_370b2">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_370b2_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_370b2_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_370b2_level0_col2" class="col_heading level0 col2" >precision</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >d_model</th>
#       <th class="index_name level1" >seed</th>
#       <th class="index_name level2" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_370b2_level0_row0" class="row_heading level0 row0" rowspan="10">16</th>
#       <th id="T_370b2_level1_row0" class="row_heading level1 row0" rowspan="2">8</th>
#       <th id="T_370b2_level2_row0" class="row_heading level2 row0" >NAP_model</th>
#       <td id="T_370b2_row0_col0" class="data row0 col0" >0.571862</td>
#       <td id="T_370b2_row0_col1" class="data row0 col1" >0.658546</td>
#       <td id="T_370b2_row0_col2" class="data row0 col2" >0.876000</td>
#     </tr>
#     <tr>
#       <th id="T_370b2_level2_row1" class="row_heading level2 row1" >SDFA_NAP_model</th>
#       <td id="T_370b2_row1_col0" class="data row1 col0" >0.611570</td>
#       <td id="T_370b2_row1_col1" class="data row1 col1" >0.685790</td>
#       <td id="T_370b2_row1_col2" class="data row1 col2" >0.868719</td>
#     </tr>
#     <tr>
#       <th id="T_370b2_level1_row2" class="row_heading level1 row2" rowspan="2">15</th>
#       <th id="T_370b2_level2_row2" class="row_heading level2 row2" >NAP_model</th>
#       <td id="T_370b2_row2_col0" class="data row2 col0" >0.731919</td>
#       <td id="T_370b2_row2_col1" class="data row2 col1" >0.787797</td>
#       <td id="T_370b2_row2_col2" class="data row2 col2" >0.889854</td>
#     </tr>
#     <tr>
#       <th id="T_370b2_level2_row3" class="row_heading level2 row3" >SDFA_NAP_model</th>
#       <td id="T_370b2_row3_col0" class="data row3 col0" >0.572619</td>
#       <td id="T_370b2_row3_col1" class="data row3 col1" >0.650497</td>
#       <td id="T_370b2_row3_col2" class="data row3 col2" >0.868514</td>
#     </tr>
#     <tr>
#       <th id="T_370b2_level1_row4" class="row_heading level1 row4" rowspan="2">23</th>
#       <th id="T_370b2_level2_row4" class="row_heading level2 row4" >NAP_model</th>
#       <td id="T_370b2_row4_col0" class="data row4 col0" >0.643065</td>
#       <td id="T_370b2_row4_col1" class="data row4 col1" >0.716620</td>
