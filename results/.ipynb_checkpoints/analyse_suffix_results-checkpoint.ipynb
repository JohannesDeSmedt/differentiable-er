# %%
import pandas as pd
from scipy.stats import friedmanchisquare
import scikit_posthocs as sp
import numpy as np
from matplotlib import cm, colors
import scipy.stats as ss
import pandas as pd

def underline_max(series):
    """Underline the maximum value(s) in a column."""
    is_max = series == series.max()        # Boolean Series
    return ['text-decoration: underline' if v else '' for v in is_max]

def underline_min(series):
    """Underline the maximum value(s) in a column."""
    is_min = series == series.min()        # Boolean Series
    return ['text-decoration: underline' if v else '' for v in is_min]

def print_pivot_to_latex(pivot_table):
    vmins = pivot_table.min()
    vmaxs = pivot_table.max()

    # --- Lighten the colormap (avoid overly dark greens)
    cmap = cm.get_cmap('Greens')
    def lighten_color_map(val):
        r, g, b, _ = val
        return (0.3 + 0.7 * r, 0.3 + 0.7 * g, 0.3 + 0.7 * b, 1)  # move toward lighter shades

    # --- Find max indices per column for underlining
    max_indices = pivot_table.idxmax()

    def color_cell(val, col):
        # normalize within column
        norm = colors.Normalize(vmin=vmins[col], vmax=vmaxs[col])
        r, g, b, _ = lighten_color_map(cmap(norm(val)))
        cell = f"\\cellcolor[rgb]{{{r:.3f},{g:.3f},{b:.3f}}}{val:.3f}"
        # underline max value per column
        if pivot_table.loc[:, col].idxmax() == idx:
            cell = f"\\underline{{{cell}}}"
        return cell

    # --- Build LaTeX table manually
    rows = []
    for idx, row in pivot_table.iterrows():
        colored = [color_cell(row[col], col) for col in pivot_table.columns]
        rows.append(f"{idx} & " + " & ".join(colored) + " \\\\")

    latex_table = (
        "\\begin{tabular}{l" + "r" * len(pivot_table.columns) + "}\n"
        + "Constraint & " + " & ".join(pivot_table.columns) + " \\\\\n"
        + "\\hline\n"
        + "\n".join(rows)
        + "\n\\end{tabular}"
    )

    print(latex_table)

# %%
import glob
import os
import pandas as pd
import scipy.stats as ss
from pathlib import Path

# -------------------------------------------------------
# 1. Load all CSVs into one big DataFrame
# -------------------------------------------------------
data_dir = Path(".")          # <-- change this
csv_paths = sorted(data_dir.glob("*.csv"))

dfs = []
for p in csv_paths:
    if 'suffix' in str(p) :#and 'ND' in str(p):
        print(p)
        df = pd.read_csv(p)
#         print(df.head())
        # Keep the source dataset name (file stem)
        df["dataset"] = p.stem
#         df = df[df.local == False]
        dfs.append(df)
        print(df['seed'].unique())
        
        for seed in df['seed'].unique():
            print(len(df[df['seed']==seed]))

df_all = pd.concat(dfs, ignore_index=True)
# Out:
# results_differo_suffix_BPI12.csv
# [  56    8   15   76   23   42    4  108   16 1089]
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# results_differo_suffix_BPI20PrepaidTravelCosts.csv
# [  56    8   15   76   23   42    4  108   16 1089]
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# results_differo_suffix_BPI20RequestForPayment.csv
# [  56    8   15   76   23   42    4  108   16 1089]
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78
# 78

# %%
import glob
import os
import numpy as np
import pandas as pd
import scipy.stats as ss
from pathlib import Path


def make_model_column(row):
    if row['rank_loss'] == True:
        return 'rank_loss'
    if row['sdfa_ce'] == True and row['local']==False:
        return 'SDFA'
    if row['sdfa_ce'] == True:
        return 'SDFA_nonlocal'
    if row['model'] == 'SDFA_NAP_model' and row['local']== True:
        return 'DIFF-ERO_local'
    if row['model'] == 'SDFA_NAP_model':
        return 'DIFF-ERO_notlocal'
    else:
        return 'Base'

# -------------------------------------------------------
# 1. Load all CSVs into one big DataFrame
# -------------------------------------------------------
data_dir = Path(".")          # <-- change this
csv_paths = sorted(data_dir.glob("*.csv"))

dfs = []
for p in csv_paths:
    if 'suffix' in str(p):
        df = pd.read_csv(p)
        # Keep the source dataset name (file stem)
        df["dataset"] = p.stem
        dfs.append(df)

df_all = pd.concat(dfs, ignore_index=True)
# df_all = df_all[df_all['local'] == False]
df_all['model'] = df_all.apply(lambda x: make_model_column(x), axis=1)
df_all = df_all.drop(['quantile', 'rank_loss', 'sdfa_ce', 'no_epochs', 'er_loss'], axis=1)

df_all
# Out:
#       seed  local      model  lambda  d_model  batch_size  \
# 0       56  False       Base     0.1       16         128
# 1       56   True       Base     0.1       16          32
# 2       56   True       Base     0.1       16          64
# 3       56   True       Base     0.1       16         128
# 4       56  False       SDFA     0.1       16         128
# ...    ...    ...        ...     ...      ...         ...
# 2335  1089  False       Base     0.0       16         128
# 2336  1089  False  rank_loss     0.0       32         128
# 2337  1089  False       Base     0.0       32         128
# 2338  1089  False  rank_loss     0.0       64         128
# 2339  1089  False       Base     0.0       64         128
#
#       avg_beam_dl_distance  avg_dl_distance       time  er_pred  er_target  \
# 0                 0.509671         0.588193   7.384923        0          0
# 1                 0.472376         0.575425  18.187784        0          0
# 2                 0.493251         0.580537  12.198710        0          0
# 3                 0.502390         0.606196   9.224283        0          0
# 4                 0.505078         0.598690   7.296565        0          0
# ...                    ...              ...        ...      ...        ...
# 2335              0.241431         0.321516   2.900931        0          0
# 2336              0.270522         0.327480   3.207055        0          0
# 2337              0.224150         0.308092   2.895128        0          0
# 2338              0.255860         0.318534   3.197353        0          0
# 2339              0.214682         0.308087   2.894646        0          0
#
#                                             dataset
# 0                      results_differo_suffix_BPI12
# 1                      results_differo_suffix_BPI12
# 2                      results_differo_suffix_BPI12
# 3                      results_differo_suffix_BPI12
# 4                      results_differo_suffix_BPI12
# ...                                             ...
# 2335  results_differo_suffix_BPI20RequestForPayment
# 2336  results_differo_suffix_BPI20RequestForPayment
# 2337  results_differo_suffix_BPI20RequestForPayment
# 2338  results_differo_suffix_BPI20RequestForPayment
# 2339  results_differo_suffix_BPI20RequestForPayment
#
# [2340 rows x 12 columns]

# %%
# df_local = df_all[df_all['local'] == True]
df_local = df_all
df_local['dataset'] = df_local['dataset'].apply(lambda x: x.replace('results_differo_suffix_', ''))
# df_local = df_local[df_local['d_model'] > 16]
pivot_table = pd.pivot_table(df_local, 
                             values=['avg_dl_distance'], 
                             columns = ['dataset'],
                             index=[ 'local', 'batch_size',  'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_max, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_27742/1071267196.py:5: FutureWarning: The provided callable <function mean at 0x104dda2a0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df_local,
# <style type="text/css">
# #T_06ce6_row0_col0, #T_06ce6_row0_col1, #T_06ce6_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-decoration: underline;
# }
# #T_06ce6_row1_col0 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_06ce6_row1_col1, #T_06ce6_row5_col1, #T_06ce6_row12_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_06ce6_row1_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_06ce6_row2_col0, #T_06ce6_row7_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_06ce6_row2_col1, #T_06ce6_row6_col1, #T_06ce6_row10_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_06ce6_row2_col2, #T_06ce6_row11_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_06ce6_row3_col0, #T_06ce6_row12_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_06ce6_row3_col1, #T_06ce6_row6_col0, #T_06ce6_row11_col2, #T_06ce6_row12_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_06ce6_row3_col2, #T_06ce6_row8_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_06ce6_row4_col0, #T_06ce6_row11_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_06ce6_row4_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_06ce6_row4_col2 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_06ce6_row5_col0, #T_06ce6_row9_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_06ce6_row5_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_06ce6_row6_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_06ce6_row7_col1, #T_06ce6_row9_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_06ce6_row7_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_06ce6_row8_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_06ce6_row8_col2 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_06ce6_row9_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_06ce6_row10_col0 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_06ce6_row10_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# </style>
# <table id="T_06ce6">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06ce6_level0_col0" class="col_heading level0 col0" colspan="3">avg_dl_distance</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >dataset</th>
#       <th id="T_06ce6_level1_col0" class="col_heading level1 col0" >BPI12</th>
#       <th id="T_06ce6_level1_col1" class="col_heading level1 col1" >BPI20PrepaidTravelCosts</th>
#       <th id="T_06ce6_level1_col2" class="col_heading level1 col2" >BPI20RequestForPayment</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >local</th>
#       <th class="index_name level1" >batch_size</th>
#       <th class="index_name level2" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06ce6_level0_row0" class="row_heading level0 row0" rowspan="4">False</th>
#       <th id="T_06ce6_level1_row0" class="row_heading level1 row0" rowspan="4">128</th>
#       <th id="T_06ce6_level2_row0" class="row_heading level2 row0" >0.000000</th>
#       <td id="T_06ce6_row0_col0" class="data row0 col0" >0.711309</td>
#       <td id="T_06ce6_row0_col1" class="data row0 col1" >0.496191</td>
#       <td id="T_06ce6_row0_col2" class="data row0 col2" >0.331779</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level2_row1" class="row_heading level2 row1" >0.100000</th>
#       <td id="T_06ce6_row1_col0" class="data row1 col0" >0.564425</td>
#       <td id="T_06ce6_row1_col1" class="data row1 col1" >0.386923</td>
#       <td id="T_06ce6_row1_col2" class="data row1 col2" >0.314158</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level2_row2" class="row_heading level2 row2" >0.200000</th>
#       <td id="T_06ce6_row2_col0" class="data row2 col0" >0.554053</td>
#       <td id="T_06ce6_row2_col1" class="data row2 col1" >0.385338</td>
#       <td id="T_06ce6_row2_col2" class="data row2 col2" >0.310259</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level2_row3" class="row_heading level2 row3" >0.500000</th>
#       <td id="T_06ce6_row3_col0" class="data row3 col0" >0.546353</td>
#       <td id="T_06ce6_row3_col1" class="data row3 col1" >0.383648</td>
#       <td id="T_06ce6_row3_col2" class="data row3 col2" >0.310483</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level0_row4" class="row_heading level0 row4" rowspan="9">True</th>
#       <th id="T_06ce6_level1_row4" class="row_heading level1 row4" rowspan="3">32</th>
#       <th id="T_06ce6_level2_row4" class="row_heading level2 row4" >0.100000</th>
#       <td id="T_06ce6_row4_col0" class="data row4 col0" >0.553135</td>
#       <td id="T_06ce6_row4_col1" class="data row4 col1" >0.388331</td>
#       <td id="T_06ce6_row4_col2" class="data row4 col2" >0.313436</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level2_row5" class="row_heading level2 row5" >0.200000</th>
#       <td id="T_06ce6_row5_col0" class="data row5 col0" >0.537431</td>
#       <td id="T_06ce6_row5_col1" class="data row5 col1" >0.387223</td>
#       <td id="T_06ce6_row5_col2" class="data row5 col2" >0.310878</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level2_row6" class="row_heading level2 row6" >0.500000</th>
#       <td id="T_06ce6_row6_col0" class="data row6 col0" >0.532230</td>
#       <td id="T_06ce6_row6_col1" class="data row6 col1" >0.385208</td>
#       <td id="T_06ce6_row6_col2" class="data row6 col2" >0.312384</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level1_row7" class="row_heading level1 row7" rowspan="3">64</th>
#       <th id="T_06ce6_level2_row7" class="row_heading level2 row7" >0.100000</th>
#       <td id="T_06ce6_row7_col0" class="data row7 col0" >0.554311</td>
#       <td id="T_06ce6_row7_col1" class="data row7 col1" >0.386220</td>
#       <td id="T_06ce6_row7_col2" class="data row7 col2" >0.312018</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level2_row8" class="row_heading level2 row8" >0.200000</th>
#       <td id="T_06ce6_row8_col0" class="data row8 col0" >0.543961</td>
#       <td id="T_06ce6_row8_col1" class="data row8 col1" >0.385905</td>
#       <td id="T_06ce6_row8_col2" class="data row8 col2" >0.310202</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level2_row9" class="row_heading level2 row9" >0.500000</th>
#       <td id="T_06ce6_row9_col0" class="data row9 col0" >0.537774</td>
#       <td id="T_06ce6_row9_col1" class="data row9 col1" >0.384032</td>
#       <td id="T_06ce6_row9_col2" class="data row9 col2" >0.310485</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level1_row10" class="row_heading level1 row10" rowspan="3">128</th>
#       <th id="T_06ce6_level2_row10" class="row_heading level2 row10" >0.100000</th>
#       <td id="T_06ce6_row10_col0" class="data row10 col0" >0.558990</td>
#       <td id="T_06ce6_row10_col1" class="data row10 col1" >0.385425</td>
#       <td id="T_06ce6_row10_col2" class="data row10 col2" >0.312902</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level2_row11" class="row_heading level2 row11" >0.200000</th>
#       <td id="T_06ce6_row11_col0" class="data row11 col0" >0.552724</td>
#       <td id="T_06ce6_row11_col1" class="data row11 col1" >0.384842</td>
#       <td id="T_06ce6_row11_col2" class="data row11 col2" >0.309973</td>
#     </tr>
#     <tr>
#       <th id="T_06ce6_level2_row12" class="row_heading level2 row12" >0.500000</th>
#       <td id="T_06ce6_row12_col0" class="data row12 col0" >0.546758</td>
#       <td id="T_06ce6_row12_col1" class="data row12 col1" >0.383350</td>
#       <td id="T_06ce6_row12_col2" class="data row12 col2" >0.310673</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scikit_posthocs as sp
import scikit_posthocs as sp
from scipy.stats import rankdata
from scipy.stats import friedmanchisquare

metric = "avg_dl_distance"
# df_all = df_all[df_all["lambda"] < 0.5]
# df_all = df_all[df_all['local'] == True]

df_seed_avg = (
    df_all.groupby([
        "dataset",
        "model",
        "lambda",
        "d_model",
        "batch_size",
    ])[metric]
    .mean()
    .reset_index()
)
df_seed_avg
best_configs = (
    df_seed_avg
    .sort_values(metric, ascending=False)
    .groupby(["dataset", "model"])
    .head(1)
)
pivot = best_configs.pivot(
    index="dataset",
    columns="model",
    values=metric
)
pivot

friedmanchisquare(*[pivot[col] for col in pivot.columns])

nemenyi = sp.posthoc_nemenyi_friedman(pivot)
print(nemenyi)


ranks = pivot.apply(
    lambda row: pd.Series(
        rankdata(-row.values, method="average"),
        index=row.index
    ),
    axis=1
)

avg_ranks = ranks.mean().sort_values()
print(avg_ranks)

sp.critical_difference_diagram(avg_ranks, nemenyi)
plt.show()
# Out:
#                    Base      SDFA  SDFA_nonlocal  rank_loss
# Base           1.000000  0.921603       0.989058   0.389401
# SDFA           0.921603  1.000000       0.989058   0.119495
# SDFA_nonlocal  0.989058  0.989058       1.000000   0.229104
# rank_loss      0.389401  0.119495       0.229104   1.000000
# model
# rank_loss        1.000000
# Base             2.666667
# SDFA_nonlocal    3.000000
# SDFA             3.333333
# dtype: float64

# %%
import glob
import os
import pandas as pd
import scipy.stats as ss
from pathlib import Path

# -------------------------------------------------------
# 1. Load all CSVs into one big DataFrame
# -------------------------------------------------------
data_dir = Path(".")          # <-- change this
csv_paths = sorted(data_dir.glob("*.csv"))

dfs = []
for p in csv_paths:
    if 'suffix' in str(p):
        df = pd.read_csv(p)
        # Keep the source dataset name (file stem)
        df["dataset"] = p.stem
        dfs.append(df)

df_all = pd.concat(dfs, ignore_index=True)

# -------------------------------------------------------
# 2. Basic filtering
# -------------------------------------------------------
# df_all = df_all[df_all["lambda"] < 0.5]
# df_all = df_all[df_all['local'] == False]

# -------------------------------------------------------
# 3. Keep only the metrics we care about
# -------------------------------------------------------
cols_needed = ["dataset", "seed", "model", "d_model", 'sdfa_ce', 'rank_loss', "lambda", "avg_dl_distance"]
df_all = df_all[cols_needed]

# -------------------------------------------------------
# 4. Find the best parameter setting per seed–model–dataset
# -------------------------------------------------------
best = (
    df_all
    .sort_values("avg_dl_distance", ascending=False)          # highest f1 first
    .drop_duplicates(subset=["dataset", "seed", "model", 'sdfa_ce', 'rank_loss',], keep="first")
    .reset_index(drop=True)
)

# -------------------------------------------------------
# 5. Average metrics over seeds, grouped by dataset & model
# -------------------------------------------------------
summary = (
    best
    .groupby(["dataset", "model", 'sdfa_ce', 'rank_loss',], as_index=False)
    .agg(
        f1_mean=("avg_dl_distance", "mean")
    )
)

# -------------------------------------------------------
# 6. Pivot so that each model becomes a column
# -------------------------------------------------------
pivot_f1 = summary.pivot(index="dataset", columns=["model", 'sdfa_ce', 'rank_loss'], values=["f1_mean"])
# pivot_prec = summary.pivot(index="dataset", columns="model", values="precision_mean")
pd.set_option("display.precision", 3)
pivot_f1

# -------------------------------------------------------
# 7. Statistical test per dataset
# -------------------------------------------------------
# 7a. Build a DataFrame with the two model columns side‑by‑side
# model_a, model_b = sorted(df_all["model"].unique())  # ensure consistent order
# tests = []

# for ds in df_all["dataset"].unique():
#     sub = best[best["dataset"] == ds]
# #     if len(shared_seeds) < 3:   # Wilcoxon needs at least 3 pairs
# #         continue
#     vals_a = sub[sub["model"] == model_a].sort_values("seed")["f1"].values
#     vals_b = sub[sub["model"] == model_b].sort_values("seed")["f1"].values
#     stat, p = ss.wilcoxon(vals_a - vals_b)   # difference a – b
#     tests.append({"dataset": ds,
#                   "stat": stat,
#                   "p": p,
#                   f"{model_a}_mean": vals_a.mean(),
#                   f"{model_b}_mean": vals_b.mean()})

# tests_df = pd.DataFrame(tests)
# pd.set_option("display.precision", 3)

# # a) Merge the metric pivots with the test results
# final_table = pivot_f1.copy()
# print(final_table)
# final_table.columns = [f"{c}_f1" for c in final_table.columns]
# final_table = final_table.merge(
#     pivot_prec.rename(columns={c: f"{c}_prec" for c in pivot_prec.columns}),
#     left_index=True, right_index=True
# )
# print(final_table)
# # final_table = final_table.merge(tests_df[["dataset", "p"]], left_index=True, right_index=True)
# final_table
# # print(final_table)
# Out:
#                                                          f1_mean         \
# model                                          SDFA_suffix_model
# sdfa_ce                                                    False  True
# rank_loss                                                  False  False
# dataset
# results_differo_suffix_BPI12                               0.601  0.599
# results_differo_suffix_BPI20PrepaidTravelCosts             0.406  0.406
# results_differo_suffix_BPI20RequestForPayment              0.329  0.334
#
#
# model                                          suffix_model
# sdfa_ce                                               False
# rank_loss                                             False  True
# dataset
# results_differo_suffix_BPI12                          0.567  0.897
# results_differo_suffix_BPI20PrepaidTravelCosts        0.382  0.745
# results_differo_suffix_BPI20RequestForPayment         0.321  0.389

# %%
df_all
# Out:
#       seed  local  quantile              model  lambda  d_model  er_loss  \
# 0       56  False       0.8  SDFA_suffix_model     0.1       16     True
# 1       56   True       0.8  SDFA_suffix_model     0.1       16     True
# 2       56   True       0.8  SDFA_suffix_model     0.1       16     True
# 3       56   True       0.8  SDFA_suffix_model     0.1       16     True
# 4       56  False       0.8  SDFA_suffix_model     0.1       16     True
# ...    ...    ...       ...                ...     ...      ...      ...
# 2335  1089  False       0.8       suffix_model     0.0       16    False
# 2336  1089  False       0.8       suffix_model     0.0       32    False
# 2337  1089  False       0.8       suffix_model     0.0       32    False
# 2338  1089  False       0.8       suffix_model     0.0       64    False
# 2339  1089  False       0.8       suffix_model     0.0       64    False
#
#       batch_size  no_epochs  rank_loss  sdfa_ce  avg_beam_dl_distance  \
# 0            128         50      False    False              0.509671
# 1             32         50      False    False              0.472376
# 2             64         50      False    False              0.493251
# 3            128         50      False    False              0.502390
# 4            128         50      False     True              0.505078
# ...          ...        ...        ...      ...                   ...
# 2335         128         50      False    False              0.241431
# 2336         128         50       True    False              0.270522
# 2337         128         50      False    False              0.224150
# 2338         128         50       True    False              0.255860
# 2339         128         50      False    False              0.214682
#
#       avg_dl_distance       time  er_pred  er_target  \
# 0            0.588193   7.384923        0          0
# 1            0.575425  18.187784        0          0
# 2            0.580537  12.198710        0          0
# 3            0.606196   9.224283        0          0
# 4            0.598690   7.296565        0          0
# ...               ...        ...      ...        ...
# 2335         0.321516   2.900931        0          0
# 2336         0.327480   3.207055        0          0
# 2337         0.308092   2.895128        0          0
# 2338         0.318534   3.197353        0          0
# 2339         0.308087   2.894646        0          0
#
#                                             dataset
# 0                      results_differo_suffix_BPI12
# 1                      results_differo_suffix_BPI12
# 2                      results_differo_suffix_BPI12
# 3                      results_differo_suffix_BPI12
# 4                      results_differo_suffix_BPI12
# ...                                             ...
# 2335  results_differo_suffix_BPI20RequestForPayment
# 2336  results_differo_suffix_BPI20RequestForPayment
# 2337  results_differo_suffix_BPI20RequestForPayment
# 2338  results_differo_suffix_BPI20RequestForPayment
# 2339  results_differo_suffix_BPI20RequestForPayment
#
# [2340 rows x 17 columns]

# %%
for p in csv_paths:
    if 'suffix' in str(p) and 'ns' not in str(p):
        print(p)
        
        df = pd.read_csv(p)
        # df = df[df['lambda']<0.5]
        df = df[df['local'] == False]

        df_test = df[['seed', 'model', 'd_model', 'avg_dl_distance']]

        df_test = (
            df_test
            .groupby(['seed', 'model'])
            .agg(f1_mean=('avg_dl_distance', 'max'))
            .reset_index()
        )

        sub = df_test
        pivot = sub.pivot(index='seed', columns='model', values='f1_mean')
        print(pivot)
        stat, p = ss.wilcoxon(pivot['SDFA_suffix_model']-pivot['suffix_model'])
        print(stat)
        print(p)
# Out:
# results_differo_suffix_BPI12.csv
# model  SDFA_suffix_model  suffix_model
# seed
# 4               0.614765      0.901262
# 8               0.601490      0.902883
# 15              0.594530      0.883673
# 16              0.580610      0.903627
# 23              0.600693      0.887067
# 42              0.649569      0.903538
# 56              0.610568      0.898292
# 76              0.582416      0.898292
# 108             0.575667      0.901262
# 1089            0.599551      0.894605
# 0.0
# 0.001953125
# results_differo_suffix_BPI20PrepaidTravelCosts.csv
# model  SDFA_suffix_model  suffix_model
# seed
# 4               0.411561      0.734104
# 8               0.398190      0.613729
# 15              0.424164      0.809205
# 16              0.390264      0.676042
# 23              0.402346      0.899661
# 42              0.404708      0.899223
# 56              0.418189      0.707394
# 76              0.406528      0.648984
# 108             0.404711      0.620676
# 1089            0.393403      0.845730
# 0.0
# 0.001953125
# results_differo_suffix_BPI20RequestForPayment.csv
# model  SDFA_suffix_model  suffix_model
# seed
# 4               0.329956      0.351499
# 8               0.334258      0.364794
# 15              0.321366      0.327400
# 16              0.321211      0.366217
# 23              0.347931      0.432483
# 42              0.334620      0.373450
# 56              0.321341      0.351690
# 76              0.321366      0.460135
# 108             0.321211      0.443679
# 1089            0.347725      0.416422
# 0.0
# 0.001953125

# %%
import glob
import os
import pandas as pd
import scipy.stats as ss
from pathlib import Path

# -------------------------------------------------------
# 1. Load all CSVs into one big DataFrame
# -------------------------------------------------------
data_dir = Path(".")          # <-- change this
csv_paths = sorted(data_dir.glob("*.csv"))

dfs = []
for p in csv_paths:
    if 'suffix' in str(p) and 'not_local' in str(p):
        df = pd.read_csv(p)
        # Keep the source dataset name (file stem)
        df["dataset"] = p.stem
        df['er_diff'] = (df['er_pred'] - df['er_target']) / (df['er_pred'])
        dfs.append(df)

df_all = pd.concat(dfs, ignore_index=True)

# -------------------------------------------------------
# 2. Basic filtering
# -------------------------------------------------------
# df_all = df_all[df_all["lambda"] < 0.5]
df_all = df_all[df_all['local'] == False]

# -------------------------------------------------------
# 3. Keep only the metrics we care about
# -------------------------------------------------------
cols_needed = ["dataset", "seed", "model", "d_model", "lambda", "avg_dl_distance", "er_diff"]
df_all = df_all[cols_needed]

# -------------------------------------------------------
# 4. Find the best parameter setting per seed–model–dataset
# -------------------------------------------------------
best = (
    df_all
    .sort_values("avg_dl_distance", ascending=False)          # highest f1 first
    .drop_duplicates(subset=["dataset", "seed", "model"], keep="first")
    .reset_index(drop=True)
)

# -------------------------------------------------------
# 5. Average metrics over seeds, grouped by dataset & model
# -------------------------------------------------------
summary = (
    best
    .groupby(["dataset", "model"], as_index=False)
    .agg(
        f1_mean=("avg_dl_distance", "mean"),
        precision_mean=("er_diff", "mean")
    )
)

# -------------------------------------------------------
# 6. Pivot so that each model becomes a column
# -------------------------------------------------------
pivot_f1 = summary.pivot(index="dataset", columns="model", values="f1_mean")
pivot_prec = summary.pivot(index="dataset", columns="model", values="precision_mean")

print(pivot_f1)

# -------------------------------------------------------
# 7. Statistical test per dataset
# -------------------------------------------------------
# 7a. Build a DataFrame with the two model columns side‑by‑side
model_a, model_b = sorted(df_all["model"].unique())  # ensure consistent order
tests = []

for ds in df_all["dataset"].unique():
    sub = best[best["dataset"] == ds]
#     if len(shared_seeds) < 3:   # Wilcoxon needs at least 3 pairs
#         continue
    vals_a = sub[sub["model"] == model_a].sort_values("seed")["avg_dl_distance"].values
    vals_b = sub[sub["model"] == model_b].sort_values("seed")["avg_dl_distance"].values
    stat, p = ss.wilcoxon(vals_a - vals_b)   # difference a – b
    tests.append({"dataset": ds,
                  "stat": stat,
                  "p": p,
                  f"{model_a}_mean": vals_a.mean(),
                  f"{model_b}_mean": vals_b.mean()})

tests_df = pd.DataFrame(tests)
pd.set_option("display.precision", 3)

# a) Merge the metric pivots with the test results
final_table = pivot_f1.copy()
print(final_table)
final_table.columns = [f"{c}_dl" for c in final_table.columns]
final_table = final_table.merge(
    pivot_prec.rename(columns={c: f"{c}_er" for c in pivot_prec.columns}),
    left_index=True, right_index=True
)
print(final_table)
# final_table = final_table.merge(tests_df[["dataset", "p"]], left_index=True, right_index=True)
final_table
# print(final_table)
# Out:
# model                                               SDFA_suffix_model  \
# dataset
# results_suffix_prediction_not_local_BPI12                       0.692
# results_suffix_prediction_not_local_BPI17                       0.620
# results_suffix_prediction_not_local_BPI19                       0.435
# results_suffix_prediction_not_local_BPI20Prepai...              0.470
# results_suffix_prediction_not_local_BPI20Reques...              0.357
# results_suffix_prediction_not_local_BPI20Travel...              0.516
#
# model                                               suffix_model
# dataset
# results_suffix_prediction_not_local_BPI12                  0.669
# results_suffix_prediction_not_local_BPI17                  0.599
# results_suffix_prediction_not_local_BPI19                  0.431
# results_suffix_prediction_not_local_BPI20Prepai...         0.403
# results_suffix_prediction_not_local_BPI20Reques...         0.329
# results_suffix_prediction_not_local_BPI20Travel...         0.497
# model                                               SDFA_suffix_model  \
# dataset
# results_suffix_prediction_not_local_BPI12                       0.692
# results_suffix_prediction_not_local_BPI17                       0.620
# results_suffix_prediction_not_local_BPI19                       0.435
# results_suffix_prediction_not_local_BPI20Prepai...              0.470
# results_suffix_prediction_not_local_BPI20Reques...              0.357
# results_suffix_prediction_not_local_BPI20Travel...              0.516
#
# model                                               suffix_model
# dataset
# results_suffix_prediction_not_local_BPI12                  0.669
# results_suffix_prediction_not_local_BPI17                  0.599
# results_suffix_prediction_not_local_BPI19                  0.431
# results_suffix_prediction_not_local_BPI20Prepai...         0.403
# results_suffix_prediction_not_local_BPI20Reques...         0.329
# results_suffix_prediction_not_local_BPI20Travel...         0.497
#                                                     SDFA_suffix_model_dl  \
# dataset
# results_suffix_prediction_not_local_BPI12                          0.692
# results_suffix_prediction_not_local_BPI17                          0.620
# results_suffix_prediction_not_local_BPI19                          0.435
# results_suffix_prediction_not_local_BPI20Prepai...                 0.470
# results_suffix_prediction_not_local_BPI20Reques...                 0.357
# results_suffix_prediction_not_local_BPI20Travel...                 0.516
#
#                                                     suffix_model_dl  \
# dataset
# results_suffix_prediction_not_local_BPI12                     0.669
# results_suffix_prediction_not_local_BPI17                     0.599
# results_suffix_prediction_not_local_BPI19                     0.431
# results_suffix_prediction_not_local_BPI20Prepai...            0.403
# results_suffix_prediction_not_local_BPI20Reques...            0.329
# results_suffix_prediction_not_local_BPI20Travel...            0.497
#
#                                                     SDFA_suffix_model_er  \
# dataset
# results_suffix_prediction_not_local_BPI12                      4.797e-03
# results_suffix_prediction_not_local_BPI17                      2.212e-03
# results_suffix_prediction_not_local_BPI19                      4.465e-02
# results_suffix_prediction_not_local_BPI20Prepai...             5.302e-06
# results_suffix_prediction_not_local_BPI20Reques...             1.559e-02
# results_suffix_prediction_not_local_BPI20Travel...             2.147e-02
#
#                                                     suffix_model_er
# dataset
# results_suffix_prediction_not_local_BPI12                       NaN
# results_suffix_prediction_not_local_BPI17                       NaN
# results_suffix_prediction_not_local_BPI19                       NaN
# results_suffix_prediction_not_local_BPI20Prepai...              NaN
# results_suffix_prediction_not_local_BPI20Reques...              NaN
# results_suffix_prediction_not_local_BPI20Travel...              NaN
#                                                     SDFA_suffix_model_dl  \
# dataset
# results_suffix_prediction_not_local_BPI12                          0.692
# results_suffix_prediction_not_local_BPI17                          0.620
# results_suffix_prediction_not_local_BPI19                          0.435
# results_suffix_prediction_not_local_BPI20Prepai...                 0.470
# results_suffix_prediction_not_local_BPI20Reques...                 0.357
# results_suffix_prediction_not_local_BPI20Travel...                 0.516
#
#                                                     suffix_model_dl  \
# dataset
# results_suffix_prediction_not_local_BPI12                     0.669
# results_suffix_prediction_not_local_BPI17                     0.599
# results_suffix_prediction_not_local_BPI19                     0.431
# results_suffix_prediction_not_local_BPI20Prepai...            0.403
# results_suffix_prediction_not_local_BPI20Reques...            0.329
# results_suffix_prediction_not_local_BPI20Travel...            0.497
#
#                                                     SDFA_suffix_model_er  \
# dataset
# results_suffix_prediction_not_local_BPI12                      4.797e-03
# results_suffix_prediction_not_local_BPI17                      2.212e-03
# results_suffix_prediction_not_local_BPI19                      4.465e-02
# results_suffix_prediction_not_local_BPI20Prepai...             5.302e-06
# results_suffix_prediction_not_local_BPI20Reques...             1.559e-02
# results_suffix_prediction_not_local_BPI20Travel...             2.147e-02
#
#                                                     suffix_model_er
# dataset
# results_suffix_prediction_not_local_BPI12                       NaN
# results_suffix_prediction_not_local_BPI17                       NaN
# results_suffix_prediction_not_local_BPI19                       NaN
# results_suffix_prediction_not_local_BPI20Prepai...              NaN
# results_suffix_prediction_not_local_BPI20Reques...              NaN
# results_suffix_prediction_not_local_BPI20Travel...              NaN

# %%
import glob
import os
import pandas as pd
import scipy.stats as ss
from pathlib import Path

# -------------------------------------------------------
# 1. Load all CSVs into one big DataFrame
# -------------------------------------------------------
data_dir = Path(".")          # <-- change this
csv_paths = sorted(data_dir.glob("*.csv"))

dfs = []
for p in csv_paths:
    if 'suffix' in str(p):# and 'ND' in str(p):
        df = pd.read_csv(p)
        # Keep the source dataset name (file stem)
        df["dataset"] = p.stem
#         df['er_diff'] = (df['er_pred'] - df['er_target']) / (df['er_pred'])
        dfs.append(df)

df_all = pd.concat(dfs, ignore_index=True)

# -------------------------------------------------------
# 2. Basic filtering
# -------------------------------------------------------
# df_all = df_all[df_all["lambda"] < 0.5]
# df_all = df_all[df_all['local'] == False]

# -------------------------------------------------------
# 3. Keep only the metrics we care about
# -------------------------------------------------------
cols_needed = ["dataset", "seed", "model", "d_model", "lambda", 'sdfa_ce', 'rank_loss', "avg_dl_distance"]
df_all = df_all[cols_needed]

# -------------------------------------------------------
# 4. Find the best parameter setting per seed–model–dataset
# -------------------------------------------------------
best = (
    df_all
    .sort_values("avg_dl_distance", ascending=False)          # highest f1 first
    .drop_duplicates(subset=["dataset", "seed", "model", 'sdfa_ce', 'rank_loss'], keep="first")
    .reset_index(drop=True)
)

# -------------------------------------------------------
# 5. Average metrics over seeds, grouped by dataset & model
# -------------------------------------------------------
summary = (
    best
    .groupby(["dataset", "model", 'sdfa_ce', 'rank_loss'], as_index=False)
    .agg(
        f1_mean=("avg_dl_distance", "min"),
    )
)

# -------------------------------------------------------
# 6. Pivot so that each model becomes a column
# -------------------------------------------------------
pivot_f1 = summary.pivot(index="dataset", columns=["model", 'sdfa_ce', 'rank_loss'], values="f1_mean")


pivot_f1

# # -------------------------------------------------------
# # 7. Statistical test per dataset
# # -------------------------------------------------------
# # 7a. Build a DataFrame with the two model columns side‑by‑side
# model_a, model_b = sorted(df_all["model"].unique())  # ensure consistent order
# tests = []

# for ds in df_all["dataset"].unique():
#     sub = best[best["dataset"] == ds]
# #     if len(shared_seeds) < 3:   # Wilcoxon needs at least 3 pairs
# #         continue
#     vals_a = sub[sub["model"] == model_a].sort_values("seed")["avg_dl_distance"].values
#     vals_b = sub[sub["model"] == model_b].sort_values("seed")["avg_dl_distance"].values
#     stat, p = ss.wilcoxon(vals_a - vals_b)   # difference a – b
#     tests.append({"dataset": ds,
#                   "stat": stat,
#                   "p": p,
#                   f"{model_a}_mean": vals_a.mean(),
#                   f"{model_b}_mean": vals_b.mean()})

# tests_df = pd.DataFrame(tests)
# pd.set_option("display.precision", 3)

# # a) Merge the metric pivots with the test results
# final_table = pivot_f1.copy()
# print(final_table)
# final_table.columns = [f"{c}_dl" for c in final_table.columns]
# final_table = final_table.merge(
#     pivot_prec.rename(columns={c: f"{c}_er" for c in pivot_prec.columns}),
#     left_index=True, right_index=True
# )
# print(final_table)
# # final_table = final_table.merge(tests_df[["dataset", "p"]], left_index=True, right_index=True)
# final_table
# # print(final_table)
# Out:
# model                                          SDFA_suffix_model            \
# sdfa_ce                                                    False     True
# rank_loss                                                  False     False
# dataset
# results_differo_suffix_BPI12                            0.577229  0.570488
# results_differo_suffix_BPI20PrepaidTravelCosts          0.392825  0.393403
# results_differo_suffix_BPI20RequestForPayment           0.309011  0.312390
#
# model                                          suffix_model
# sdfa_ce                                               False
# rank_loss                                             False     True
# dataset
# results_differo_suffix_BPI12                       0.543531  0.883673
# results_differo_suffix_BPI20PrepaidTravelCosts     0.376239  0.613729
# results_differo_suffix_BPI20RequestForPayment      0.308299  0.327400

# %%
import pandas as pd
import numpy as np
from matplotlib import cm, colors

df = pd.read_csv('results_differo_suffix_BPI20PrepaidTravelCosts.csv')
df = df[df['local']==False]
pivot_table = pd.pivot_table(df, 
                             values=['avg_dl_distance'], 
                             
                             index=['local', 'batch_size', 'sdfa_ce', 'rank_loss', 'model', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_min, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_3539/860991831.py:7: FutureWarning: The provided callable <function mean at 0x106ada2a0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_483fe_row0_col0, #T_483fe_row40_col0 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_483fe_row1_col0, #T_483fe_row16_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_483fe_row2_col0, #T_483fe_row15_col0, #T_483fe_row17_col0, #T_483fe_row39_col0, #T_483fe_row41_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_483fe_row3_col0, #T_483fe_row29_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_483fe_row4_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_483fe_row5_col0, #T_483fe_row18_col0, #T_483fe_row20_col0, #T_483fe_row21_col0, #T_483fe_row27_col0, #T_483fe_row42_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_483fe_row6_col0, #T_483fe_row28_col0, #T_483fe_row30_col0, #T_483fe_row43_col0, #T_483fe_row44_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_483fe_row7_col0, #T_483fe_row10_col0, #T_483fe_row22_col0, #T_483fe_row23_col0, #T_483fe_row46_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_483fe_row8_col0, #T_483fe_row9_col0, #T_483fe_row31_col0, #T_483fe_row45_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_483fe_row11_col0 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-decoration: underline;
# }
# #T_483fe_row12_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_483fe_row13_col0 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_483fe_row14_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_483fe_row19_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_483fe_row24_col0, #T_483fe_row25_col0, #T_483fe_row26_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_483fe_row32_col0, #T_483fe_row47_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_483fe_row33_col0, #T_483fe_row35_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_483fe_row34_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_483fe_row36_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_483fe_row37_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_483fe_row38_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_483fe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_483fe_level0_col0" class="col_heading level0 col0" >avg_dl_distance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >local</th>
#       <th class="index_name level1" >batch_size</th>
#       <th class="index_name level2" >sdfa_ce</th>
#       <th class="index_name level3" >rank_loss</th>
#       <th class="index_name level4" >model</th>
#       <th class="index_name level5" >d_model</th>
#       <th class="index_name level6" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_483fe_level0_row0" class="row_heading level0 row0" rowspan="48">False</th>
#       <th id="T_483fe_level1_row0" class="row_heading level1 row0" rowspan="24">32</th>
#       <th id="T_483fe_level2_row0" class="row_heading level2 row0" rowspan="15">False</th>
#       <th id="T_483fe_level3_row0" class="row_heading level3 row0" rowspan="12">False</th>
#       <th id="T_483fe_level4_row0" class="row_heading level4 row0" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_483fe_level5_row0" class="row_heading level5 row0" rowspan="3">16</th>
#       <th id="T_483fe_level6_row0" class="row_heading level6 row0" >0.100000</th>
#       <td id="T_483fe_row0_col0" class="data row0 col0" >0.396536</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level6_row1" class="row_heading level6 row1" >0.200000</th>
#       <td id="T_483fe_row1_col0" class="data row1 col0" >0.394613</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level6_row2" class="row_heading level6 row2" >0.500000</th>
#       <td id="T_483fe_row2_col0" class="data row2 col0" >0.394392</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level5_row3" class="row_heading level5 row3" rowspan="3">32</th>
#       <th id="T_483fe_level6_row3" class="row_heading level6 row3" >0.100000</th>
#       <td id="T_483fe_row3_col0" class="data row3 col0" >0.383988</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level6_row4" class="row_heading level6 row4" >0.200000</th>
#       <td id="T_483fe_row4_col0" class="data row4 col0" >0.387013</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level6_row5" class="row_heading level6 row5" >0.500000</th>
#       <td id="T_483fe_row5_col0" class="data row5 col0" >0.385123</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level5_row6" class="row_heading level5 row6" rowspan="3">64</th>
#       <th id="T_483fe_level6_row6" class="row_heading level6 row6" >0.100000</th>
#       <td id="T_483fe_row6_col0" class="data row6 col0" >0.381922</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level6_row7" class="row_heading level6 row7" >0.200000</th>
#       <td id="T_483fe_row7_col0" class="data row7 col0" >0.377784</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level6_row8" class="row_heading level6 row8" >0.500000</th>
#       <td id="T_483fe_row8_col0" class="data row8 col0" >0.380527</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level4_row9" class="row_heading level4 row9" rowspan="3">suffix_model</th>
#       <th id="T_483fe_level5_row9" class="row_heading level5 row9" >16</th>
#       <th id="T_483fe_level6_row9" class="row_heading level6 row9" >0.000000</th>
#       <td id="T_483fe_row9_col0" class="data row9 col0" >0.381402</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level5_row10" class="row_heading level5 row10" >32</th>
#       <th id="T_483fe_level6_row10" class="row_heading level6 row10" >0.000000</th>
#       <td id="T_483fe_row10_col0" class="data row10 col0" >0.378857</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level5_row11" class="row_heading level5 row11" >64</th>
#       <th id="T_483fe_level6_row11" class="row_heading level6 row11" >0.000000</th>
#       <td id="T_483fe_row11_col0" class="data row11 col0" >0.374840</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level3_row12" class="row_heading level3 row12" rowspan="3">True</th>
#       <th id="T_483fe_level4_row12" class="row_heading level4 row12" rowspan="3">suffix_model</th>
#       <th id="T_483fe_level5_row12" class="row_heading level5 row12" >16</th>
#       <th id="T_483fe_level6_row12" class="row_heading level6 row12" >0.000000</th>
#       <td id="T_483fe_row12_col0" class="data row12 col0" >0.603191</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level5_row13" class="row_heading level5 row13" >32</th>
#       <th id="T_483fe_level6_row13" class="row_heading level6 row13" >0.000000</th>
#       <td id="T_483fe_row13_col0" class="data row13 col0" >0.699845</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level5_row14" class="row_heading level5 row14" >64</th>
#       <th id="T_483fe_level6_row14" class="row_heading level6 row14" >0.000000</th>
#       <td id="T_483fe_row14_col0" class="data row14 col0" >0.734533</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level2_row15" class="row_heading level2 row15" rowspan="9">True</th>
#       <th id="T_483fe_level3_row15" class="row_heading level3 row15" rowspan="9">False</th>
#       <th id="T_483fe_level4_row15" class="row_heading level4 row15" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_483fe_level5_row15" class="row_heading level5 row15" rowspan="3">16</th>
#       <th id="T_483fe_level6_row15" class="row_heading level6 row15" >0.100000</th>
#       <td id="T_483fe_row15_col0" class="data row15 col0" >0.394086</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level6_row16" class="row_heading level6 row16" >0.200000</th>
#       <td id="T_483fe_row16_col0" class="data row16 col0" >0.395099</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level6_row17" class="row_heading level6 row17" >0.500000</th>
#       <td id="T_483fe_row17_col0" class="data row17 col0" >0.393478</td>
#     </tr>
#     <tr>
#       <th id="T_483fe_level5_row18" class="row_heading level5

# %%
import pandas as pd
import numpy as np
from matplotlib import cm, colors

df = pd.read_csv('results_suffix_prediction_ND_BPI20PrepaidTravelCosts.csv')
df = df[df['local']==False]
pivot_table = pd.pivot_table(df, 
                             values=['avg_dl_distance'], 
                             
                             index=['local', 'batch_size', 'sdfa_ce', 'rank_loss', 'model', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_min, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_73600/1006701482.py:7: FutureWarning: The provided callable <function mean at 0x107fda200> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_e572d_row0_col0, #T_e572d_row12_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_e572d_row1_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_e572d_row2_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_e572d_row3_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_e572d_row4_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_e572d_row5_col0 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_e572d_row6_col0 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_e572d_row7_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_e572d_row8_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_e572d_row9_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_e572d_row10_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_e572d_row11_col0 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-decoration: underline;
# }
# #T_e572d_row13_col0 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_e572d_row14_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e572d_row15_col0, #T_e572d_row16_col0 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_e572d_row17_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_e572d_row18_col0 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_e572d_row19_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_e572d_row20_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_e572d_row21_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_e572d_row22_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_e572d_row23_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# </style>
# <table id="T_e572d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e572d_level0_col0" class="col_heading level0 col0" >avg_dl_distance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >local</th>
#       <th class="index_name level1" >batch_size</th>
#       <th class="index_name level2" >sdfa_ce</th>
#       <th class="index_name level3" >rank_loss</th>
#       <th class="index_name level4" >model</th>
#       <th class="index_name level5" >d_model</th>
#       <th class="index_name level6" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e572d_level0_row0" class="row_heading level0 row0" rowspan="24">False</th>
#       <th id="T_e572d_level1_row0" class="row_heading level1 row0" rowspan="12">32</th>
#       <th id="T_e572d_level2_row0" class="row_heading level2 row0" rowspan="12">False</th>
#       <th id="T_e572d_level3_row0" class="row_heading level3 row0" rowspan="12">False</th>
#       <th id="T_e572d_level4_row0" class="row_heading level4 row0" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_e572d_level5_row0" class="row_heading level5 row0" rowspan="3">16</th>
#       <th id="T_e572d_level6_row0" class="row_heading level6 row0" >0.100000</th>
#       <td id="T_e572d_row0_col0" class="data row0 col0" >0.433058</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level6_row1" class="row_heading level6 row1" >0.200000</th>
#       <td id="T_e572d_row1_col0" class="data row1 col0" >0.439202</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level6_row2" class="row_heading level6 row2" >0.500000</th>
#       <td id="T_e572d_row2_col0" class="data row2 col0" >0.436794</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level5_row3" class="row_heading level5 row3" rowspan="3">32</th>
#       <th id="T_e572d_level6_row3" class="row_heading level6 row3" >0.100000</th>
#       <td id="T_e572d_row3_col0" class="data row3 col0" >0.406154</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level6_row4" class="row_heading level6 row4" >0.200000</th>
#       <td id="T_e572d_row4_col0" class="data row4 col0" >0.414793</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level6_row5" class="row_heading level6 row5" >0.500000</th>
#       <td id="T_e572d_row5_col0" class="data row5 col0" >0.430941</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level5_row6" class="row_heading level5 row6" rowspan="3">64</th>
#       <th id="T_e572d_level6_row6" class="row_heading level6 row6" >0.100000</th>
#       <td id="T_e572d_row6_col0" class="data row6 col0" >0.402511</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level6_row7" class="row_heading level6 row7" >0.200000</th>
#       <td id="T_e572d_row7_col0" class="data row7 col0" >0.412101</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level6_row8" class="row_heading level6 row8" >0.500000</th>
#       <td id="T_e572d_row8_col0" class="data row8 col0" >0.411435</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level4_row9" class="row_heading level4 row9" rowspan="3">suffix_model</th>
#       <th id="T_e572d_level5_row9" class="row_heading level5 row9" >16</th>
#       <th id="T_e572d_level6_row9" class="row_heading level6 row9" >0.000000</th>
#       <td id="T_e572d_row9_col0" class="data row9 col0" >0.399863</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level5_row10" class="row_heading level5 row10" >32</th>
#       <th id="T_e572d_level6_row10" class="row_heading level6 row10" >0.000000</th>
#       <td id="T_e572d_row10_col0" class="data row10 col0" >0.394010</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level5_row11" class="row_heading level5 row11" >64</th>
#       <th id="T_e572d_level6_row11" class="row_heading level6 row11" >0.000000</th>
#       <td id="T_e572d_row11_col0" class="data row11 col0" >0.392937</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level1_row12" class="row_heading level1 row12" rowspan="12">128</th>
#       <th id="T_e572d_level2_row12" class="row_heading level2 row12" rowspan="3">False</th>
#       <th id="T_e572d_level3_row12" class="row_heading level3 row12" rowspan="3">True</th>
#       <th id="T_e572d_level4_row12" class="row_heading level4 row12" rowspan="3">suffix_model</th>
#       <th id="T_e572d_level5_row12" class="row_heading level5 row12" >16</th>
#       <th id="T_e572d_level6_row12" class="row_heading level6 row12" >0.000000</th>
#       <td id="T_e572d_row12_col0" class="data row12 col0" >0.433059</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level5_row13" class="row_heading level5 row13" >32</th>
#       <th id="T_e572d_level6_row13" class="row_heading level6 row13" >0.000000</th>
#       <td id="T_e572d_row13_col0" class="data row13 col0" >0.540774</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level5_row14" class="row_heading level5 row14" >64</th>
#       <th id="T_e572d_level6_row14" class="row_heading level6 row14" >0.000000</th>
#       <td id="T_e572d_row14_col0" class="data row14 col0" >0.551261</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level2_row15" class="row_heading level2 row15" rowspan="9">True</th>
#       <th id="T_e572d_level3_row15" class="row_heading level3 row15" rowspan="9">False</th>
#       <th id="T_e572d_level4_row15" class="row_heading level4 row15" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_e572d_level5_row15" class="row_heading level5 row15" rowspan="3">16</th>
#       <th id="T_e572d_level6_row15" class="row_heading level6 row15" >0.100000</th>
#       <td id="T_e572d_row15_col0" class="data row15 col0" >0.413084</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level6_row16" class="row_heading level6 row16" >0.200000</th>
#       <td id="T_e572d_row16_col0" class="data row16 col0" >0.413068</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level6_row17" class="row_heading level6 row17" >0.500000</th>
#       <td id="T_e572d_row17_col0" class="data row17 col0" >0.412726</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level5_row18" class="row_heading level5 row18" rowspan="3">32</th>
#       <th id="T_e572d_level6_row18" class="row_heading level6 row18" >0.100000</th>
#       <td id="T_e572d_row18_col0" class="data row18 col0" >0.417037</td>
#     </tr>
#     <tr>
#       <th id="T_e572d_level6_row19" class="row_heading level6 row19"

# %%
import pandas as pd
import numpy as np
from matplotlib import cm, colors

df = pd.read_csv('results_suffix_prediction_BPI20RequestForPayment.csv')

df = df[df['batch_size']<30]
pivot_table = pd.pivot_table(df, 
                             values=['avg_dl_distance'], 
                             
                             index=['local', 'batch_size', 'model', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_min, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_67180/948701201.py:8: FutureWarning: The provided callable <function mean at 0x1107c65c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_cf9e3_row0_col0 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_cf9e3_row1_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_cf9e3_row2_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_cf9e3_row3_col0, #T_cf9e3_row13_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_cf9e3_row4_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_cf9e3_row5_col0 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_cf9e3_row6_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_cf9e3_row7_col0 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_cf9e3_row8_col0 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_cf9e3_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-decoration: underline;
# }
# #T_cf9e3_row10_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_cf9e3_row11_col0 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_cf9e3_row12_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_cf9e3_row14_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cf9e3_row15_col0 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_cf9e3_row16_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_cf9e3_row17_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_cf9e3_row18_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_cf9e3_row19_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_cf9e3_row20_col0 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# </style>
# <table id="T_cf9e3">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf9e3_level0_col0" class="col_heading level0 col0" >avg_dl_distance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >local</th>
#       <th class="index_name level1" >batch_size</th>
#       <th class="index_name level2" >model</th>
#       <th class="index_name level3" >d_model</th>
#       <th class="index_name level4" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf9e3_level0_row0" class="row_heading level0 row0" rowspan="12">False</th>
#       <th id="T_cf9e3_level1_row0" class="row_heading level1 row0" rowspan="12">16</th>
#       <th id="T_cf9e3_level2_row0" class="row_heading level2 row0" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_cf9e3_level3_row0" class="row_heading level3 row0" rowspan="3">16</th>
#       <th id="T_cf9e3_level4_row0" class="row_heading level4 row0" >0.100000</th>
#       <td id="T_cf9e3_row0_col0" class="data row0 col0" >0.349451</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row1" class="row_heading level4 row1" >0.200000</th>
#       <td id="T_cf9e3_row1_col0" class="data row1 col0" >0.359201</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row2" class="row_heading level4 row2" >0.500000</th>
#       <td id="T_cf9e3_row2_col0" class="data row2 col0" >0.359661</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level3_row3" class="row_heading level3 row3" rowspan="3">32</th>
#       <th id="T_cf9e3_level4_row3" class="row_heading level4 row3" >0.100000</th>
#       <td id="T_cf9e3_row3_col0" class="data row3 col0" >0.338936</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row4" class="row_heading level4 row4" >0.200000</th>
#       <td id="T_cf9e3_row4_col0" class="data row4 col0" >0.331906</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row5" class="row_heading level4 row5" >0.500000</th>
#       <td id="T_cf9e3_row5_col0" class="data row5 col0" >0.330702</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level3_row6" class="row_heading level3 row6" rowspan="3">64</th>
#       <th id="T_cf9e3_level4_row6" class="row_heading level4 row6" >0.100000</th>
#       <td id="T_cf9e3_row6_col0" class="data row6 col0" >0.327243</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row7" class="row_heading level4 row7" >0.200000</th>
#       <td id="T_cf9e3_row7_col0" class="data row7 col0" >0.340527</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row8" class="row_heading level4 row8" >0.500000</th>
#       <td id="T_cf9e3_row8_col0" class="data row8 col0" >0.333266</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level2_row9" class="row_heading level2 row9" rowspan="3">suffix_model</th>
#       <th id="T_cf9e3_level3_row9" class="row_heading level3 row9" >16</th>
#       <th id="T_cf9e3_level4_row9" class="row_heading level4 row9" >0.000000</th>
#       <td id="T_cf9e3_row9_col0" class="data row9 col0" >0.325727</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level3_row10" class="row_heading level3 row10" >32</th>
#       <th id="T_cf9e3_level4_row10" class="row_heading level4 row10" >0.000000</th>
#       <td id="T_cf9e3_row10_col0" class="data row10 col0" >0.326599</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level3_row11" class="row_heading level3 row11" >64</th>
#       <th id="T_cf9e3_level4_row11" class="row_heading level4 row11" >0.000000</th>
#       <td id="T_cf9e3_row11_col0" class="data row11 col0" >0.328099</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level0_row12" class="row_heading level0 row12" rowspan="9">True</th>
#       <th id="T_cf9e3_level1_row12" class="row_heading level1 row12" rowspan="9">16</th>
#       <th id="T_cf9e3_level2_row12" class="row_heading level2 row12" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_cf9e3_level3_row12" class="row_heading level3 row12" rowspan="3">16</th>
#       <th id="T_cf9e3_level4_row12" class="row_heading level4 row12" >0.100000</th>
#       <td id="T_cf9e3_row12_col0" class="data row12 col0" >0.342493</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row13" class="row_heading level4 row13" >0.200000</th>
#       <td id="T_cf9e3_row13_col0" class="data row13 col0" >0.338827</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row14" class="row_heading level4 row14" >0.500000</th>
#       <td id="T_cf9e3_row14_col0" class="data row14 col0" >0.363795</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level3_row15" class="row_heading level3 row15" rowspan="3">32</th>
#       <th id="T_cf9e3_level4_row15" class="row_heading level4 row15" >0.100000</th>
#       <td id="T_cf9e3_row15_col0" class="data row15 col0" >0.335220</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row16" class="row_heading level4 row16" >0.200000</th>
#       <td id="T_cf9e3_row16_col0" class="data row16 col0" >0.335664</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row17" class="row_heading level4 row17" >0.500000</th>
#       <td id="T_cf9e3_row17_col0" class="data row17 col0" >0.348534</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level3_row18" class="row_heading level3 row18" rowspan="3">64</th>
#       <th id="T_cf9e3_level4_row18" class="row_heading level4 row18" >0.100000</th>
#       <td id="T_cf9e3_row18_col0" class="data row18 col0" >0.332002</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row19" class="row_heading level4 row19" >0.200000</th>
#       <td id="T_cf9e3_row19_col0" class="data row19 col0" >0.327945</td>
#     </tr>
#     <tr>
#       <th id="T_cf9e3_level4_row20" class="row_heading level4 row20" >0.500000</th>
#       <td id="T_cf9e3_row20_col0" class="data row20 col0" >0.331194</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
import numpy as np
from matplotlib import cm, colors

df = pd.read_csv('results_suffix_prediction_BPI12.csv')

df = df[df['batch_size']<30]
pivot_table = pd.pivot_table(df, 
                             values=['avg_dl_distance'], 
                             
                             index=['local', 'batch_size', 'model', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_min, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_67180/4148795791.py:8: FutureWarning: The provided callable <function mean at 0x1107c65c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_21430_row0_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_21430_row1_col0 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_21430_row2_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_21430_row3_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_21430_row4_col0 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_21430_row5_col0 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_21430_row6_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_21430_row7_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_21430_row8_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_21430_row9_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_21430_row10_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_21430_row11_col0 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-decoration: underline;
# }
# #T_21430_row12_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_21430_row13_col0, #T_21430_row19_col0 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_21430_row14_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_21430_row15_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_21430_row16_col0 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_21430_row17_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_21430_row18_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_21430_row20_col0 {
#   background-color: #87bddc;
#   color: #000000;
# }
# </style>
# <table id="T_21430">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21430_level0_col0" class="col_heading level0 col0" >avg_dl_distance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >local</th>
#       <th class="index_name level1" >batch_size</th>
#       <th class="index_name level2" >model</th>
#       <th class="index_name level3" >d_model</th>
#       <th class="index_name level4" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21430_level0_row0" class="row_heading level0 row0" rowspan="12">False</th>
#       <th id="T_21430_level1_row0" class="row_heading level1 row0" rowspan="12">16</th>
#       <th id="T_21430_level2_row0" class="row_heading level2 row0" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_21430_level3_row0" class="row_heading level3 row0" rowspan="3">16</th>
#       <th id="T_21430_level4_row0" class="row_heading level4 row0" >0.100000</th>
#       <td id="T_21430_row0_col0" class="data row0 col0" >0.770775</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row1" class="row_heading level4 row1" >0.200000</th>
#       <td id="T_21430_row1_col0" class="data row1 col0" >0.770037</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row2" class="row_heading level4 row2" >0.500000</th>
#       <td id="T_21430_row2_col0" class="data row2 col0" >0.769400</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level3_row3" class="row_heading level3 row3" rowspan="3">32</th>
#       <th id="T_21430_level4_row3" class="row_heading level4 row3" >0.100000</th>
#       <td id="T_21430_row3_col0" class="data row3 col0" >0.765019</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row4" class="row_heading level4 row4" >0.200000</th>
#       <td id="T_21430_row4_col0" class="data row4 col0" >0.765801</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row5" class="row_heading level4 row5" >0.500000</th>
#       <td id="T_21430_row5_col0" class="data row5 col0" >0.763430</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level3_row6" class="row_heading level3 row6" rowspan="3">64</th>
#       <th id="T_21430_level4_row6" class="row_heading level4 row6" >0.100000</th>
#       <td id="T_21430_row6_col0" class="data row6 col0" >0.755094</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row7" class="row_heading level4 row7" >0.200000</th>
#       <td id="T_21430_row7_col0" class="data row7 col0" >0.761939</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row8" class="row_heading level4 row8" >0.500000</th>
#       <td id="T_21430_row8_col0" class="data row8 col0" >0.759096</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level2_row9" class="row_heading level2 row9" rowspan="3">suffix_model</th>
#       <th id="T_21430_level3_row9" class="row_heading level3 row9" >16</th>
#       <th id="T_21430_level4_row9" class="row_heading level4 row9" >0.000000</th>
#       <td id="T_21430_row9_col0" class="data row9 col0" >0.760718</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level3_row10" class="row_heading level3 row10" >32</th>
#       <th id="T_21430_level4_row10" class="row_heading level4 row10" >0.000000</th>
#       <td id="T_21430_row10_col0" class="data row10 col0" >0.757172</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level3_row11" class="row_heading level3 row11" >64</th>
#       <th id="T_21430_level4_row11" class="row_heading level4 row11" >0.000000</th>
#       <td id="T_21430_row11_col0" class="data row11 col0" >0.753051</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level0_row12" class="row_heading level0 row12" rowspan="9">True</th>
#       <th id="T_21430_level1_row12" class="row_heading level1 row12" rowspan="9">16</th>
#       <th id="T_21430_level2_row12" class="row_heading level2 row12" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_21430_level3_row12" class="row_heading level3 row12" rowspan="3">16</th>
#       <th id="T_21430_level4_row12" class="row_heading level4 row12" >0.100000</th>
#       <td id="T_21430_row12_col0" class="data row12 col0" >0.771302</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row13" class="row_heading level4 row13" >0.200000</th>
#       <td id="T_21430_row13_col0" class="data row13 col0" >0.769664</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row14" class="row_heading level4 row14" >0.500000</th>
#       <td id="T_21430_row14_col0" class="data row14 col0" >0.765411</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level3_row15" class="row_heading level3 row15" rowspan="3">32</th>
#       <th id="T_21430_level4_row15" class="row_heading level4 row15" >0.100000</th>
#       <td id="T_21430_row15_col0" class="data row15 col0" >0.763988</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row16" class="row_heading level4 row16" >0.200000</th>
#       <td id="T_21430_row16_col0" class="data row16 col0" >0.757980</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row17" class="row_heading level4 row17" >0.500000</th>
#       <td id="T_21430_row17_col0" class="data row17 col0" >0.757925</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level3_row18" class="row_heading level3 row18" rowspan="3">64</th>
#       <th id="T_21430_level4_row18" class="row_heading level4 row18" >0.100000</th>
#       <td id="T_21430_row18_col0" class="data row18 col0" >0.759723</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row19" class="row_heading level4 row19" >0.200000</th>
#       <td id="T_21430_row19_col0" class="data row19 col0" >0.769663</td>
#     </tr>
#     <tr>
#       <th id="T_21430_level4_row20" class="row_heading level4 row20" >0.500000</th>
#       <td id="T_21430_row20_col0" class="data row20 col0" >0.760954</td>
#     </tr>
#   </tbody>
# </table>
