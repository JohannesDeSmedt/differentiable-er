# %%
def underline_max(series):
    """Underline the maximum value(s) in a column."""
    is_max = series == series.max()        # Boolean Series
    return ['text-decoration: underline' if v else '' for v in is_max]

def underline_min(series):
    """Underline the maximum value(s) in a column."""
    is_min = series == series.min()        # Boolean Series
    return ['text-decoration: underline' if v else '' for v in is_min]

def print_pivot_to_latex(pivot_table):
    vmins = pivot_table.min()
    vmaxs = pivot_table.max()

    # --- Lighten the colormap (avoid overly dark greens)
    cmap = cm.get_cmap('Greens')
    def lighten_color_map(val):
        r, g, b, _ = val
        return (0.3 + 0.7 * r, 0.3 + 0.7 * g, 0.3 + 0.7 * b, 1)  # move toward lighter shades

    # --- Find max indices per column for underlining
    max_indices = pivot_table.idxmax()

    def color_cell(val, col):
        # normalize within column
        norm = colors.Normalize(vmin=vmins[col], vmax=vmaxs[col])
        r, g, b, _ = lighten_color_map(cmap(norm(val)))
        cell = f"\\cellcolor[rgb]{{{r:.3f},{g:.3f},{b:.3f}}}{val:.3f}"
        # underline max value per column
        if pivot_table.loc[:, col].idxmax() == idx:
            cell = f"\\underline{{{cell}}}"
        return cell

    # --- Build LaTeX table manually
    rows = []
    for idx, row in pivot_table.iterrows():
        colored = [color_cell(row[col], col) for col in pivot_table.columns]
        rows.append(f"{idx} & " + " & ".join(colored) + " \\\\")

    latex_table = (
        "\\begin{tabular}{l" + "r" * len(pivot_table.columns) + "}\n"
        + "Constraint & " + " & ".join(pivot_table.columns) + " \\\\\n"
        + "\\hline\n"
        + "\n".join(rows)
        + "\n\\end{tabular}"
    )

    print(latex_table)

# %%
import pandas as pd
import numpy as np
from matplotlib import cm, colors

df = pd.read_csv('results_suffix_prediction_BPI20PrepaidTravelCosts.csv')

# df = df[df['d_model'] > 15]
# df = df[df['max_len'] > 9]
pivot_table = pd.pivot_table(df, 
                             values=['avg_dl_distance'], 
                             
                             index=['local', 'model', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_min, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_92826/2623119239.py:9: FutureWarning: The provided callable <function mean at 0x10b58a5c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_d4cba_row0_col0 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_d4cba_row1_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_d4cba_row2_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_d4cba_row3_col0 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_d4cba_row4_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_d4cba_row5_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_d4cba_row6_col0 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_d4cba_row7_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_d4cba_row8_col0 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_d4cba_row9_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_d4cba_row10_col0 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-decoration: underline;
# }
# #T_d4cba_row11_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d4cba_row12_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_d4cba_row13_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_d4cba_row14_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d4cba_row15_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_d4cba_row16_col0 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_d4cba_row17_col0 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_d4cba_row18_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_d4cba_row19_col0 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_d4cba_row20_col0 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d4cba">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4cba_level0_col0" class="col_heading level0 col0" >avg_dl_distance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >local</th>
#       <th class="index_name level1" >model</th>
#       <th class="index_name level2" >d_model</th>
#       <th class="index_name level3" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4cba_level0_row0" class="row_heading level0 row0" rowspan="12">False</th>
#       <th id="T_d4cba_level1_row0" class="row_heading level1 row0" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_d4cba_level2_row0" class="row_heading level2 row0" rowspan="3">16</th>
#       <th id="T_d4cba_level3_row0" class="row_heading level3 row0" >0.100000</th>
#       <td id="T_d4cba_row0_col0" class="data row0 col0" >0.438904</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row1" class="row_heading level3 row1" >0.200000</th>
#       <td id="T_d4cba_row1_col0" class="data row1 col0" >0.454720</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row2" class="row_heading level3 row2" >0.500000</th>
#       <td id="T_d4cba_row2_col0" class="data row2 col0" >0.473814</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level2_row3" class="row_heading level2 row3" rowspan="3">32</th>
#       <th id="T_d4cba_level3_row3" class="row_heading level3 row3" >0.100000</th>
#       <td id="T_d4cba_row3_col0" class="data row3 col0" >0.428319</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row4" class="row_heading level3 row4" >0.200000</th>
#       <td id="T_d4cba_row4_col0" class="data row4 col0" >0.437384</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row5" class="row_heading level3 row5" >0.500000</th>
#       <td id="T_d4cba_row5_col0" class="data row5 col0" >0.445719</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level2_row6" class="row_heading level2 row6" rowspan="3">64</th>
#       <th id="T_d4cba_level3_row6" class="row_heading level3 row6" >0.100000</th>
#       <td id="T_d4cba_row6_col0" class="data row6 col0" >0.423230</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row7" class="row_heading level3 row7" >0.200000</th>
#       <td id="T_d4cba_row7_col0" class="data row7 col0" >0.436018</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row8" class="row_heading level3 row8" >0.500000</th>
#       <td id="T_d4cba_row8_col0" class="data row8 col0" >0.444452</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level1_row9" class="row_heading level1 row9" rowspan="3">suffix_model</th>
#       <th id="T_d4cba_level2_row9" class="row_heading level2 row9" >16</th>
#       <th id="T_d4cba_level3_row9" class="row_heading level3 row9" >0.000000</th>
#       <td id="T_d4cba_row9_col0" class="data row9 col0" >0.414363</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level2_row10" class="row_heading level2 row10" >32</th>
#       <th id="T_d4cba_level3_row10" class="row_heading level3 row10" >0.000000</th>
#       <td id="T_d4cba_row10_col0" class="data row10 col0" >0.405834</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level2_row11" class="row_heading level2 row11" >64</th>
#       <th id="T_d4cba_level3_row11" class="row_heading level3 row11" >0.000000</th>
#       <td id="T_d4cba_row11_col0" class="data row11 col0" >0.406094</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level0_row12" class="row_heading level0 row12" rowspan="9">True</th>
#       <th id="T_d4cba_level1_row12" class="row_heading level1 row12" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_d4cba_level2_row12" class="row_heading level2 row12" rowspan="3">16</th>
#       <th id="T_d4cba_level3_row12" class="row_heading level3 row12" >0.100000</th>
#       <td id="T_d4cba_row12_col0" class="data row12 col0" >0.460254</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row13" class="row_heading level3 row13" >0.200000</th>
#       <td id="T_d4cba_row13_col0" class="data row13 col0" >0.452117</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row14" class="row_heading level3 row14" >0.500000</th>
#       <td id="T_d4cba_row14_col0" class="data row14 col0" >0.488866</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level2_row15" class="row_heading level2 row15" rowspan="3">32</th>
#       <th id="T_d4cba_level3_row15" class="row_heading level3 row15" >0.100000</th>
#       <td id="T_d4cba_row15_col0" class="data row15 col0" >0.429129</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row16" class="row_heading level3 row16" >0.200000</th>
#       <td id="T_d4cba_row16_col0" class="data row16 col0" >0.450326</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row17" class="row_heading level3 row17" >0.500000</th>
#       <td id="T_d4cba_row17_col0" class="data row17 col0" >0.459608</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level2_row18" class="row_heading level2 row18" rowspan="3">64</th>
#       <th id="T_d4cba_level3_row18" class="row_heading level3 row18" >0.100000</th>
#       <td id="T_d4cba_row18_col0" class="data row18 col0" >0.415712</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row19" class="row_heading level3 row19" >0.200000</th>
#       <td id="T_d4cba_row19_col0" class="data row19 col0" >0.424661</td>
#     </tr>
#     <tr>
#       <th id="T_d4cba_level3_row20" class="row_heading level3 row20" >0.500000</th>
#       <td id="T_d4cba_row20_col0" class="data row20 col0" >0.467535</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
import numpy as np
from matplotlib import cm, colors

df = pd.read_csv('results_suffix_prediction_BPI20RequestForPayment.csv')

# df = df[df['d_model'] > 15]
# df = df[df['max_len'] > 9]
pivot_table = pd.pivot_table(df, 
                             values=['avg_dl_distance'], 
                             
                             index=['local', 'model', 'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Blues').apply(underline_min, axis=0)
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_92826/1546848440.py:9: FutureWarning: The provided callable <function mean at 0x10b58a5c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_68bf4_row0_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_68bf4_row1_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_68bf4_row2_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_68bf4_row3_col0 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_68bf4_row4_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_68bf4_row5_col0, #T_68bf4_row16_col0 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_68bf4_row6_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_68bf4_row7_col0, #T_68bf4_row19_col0 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_68bf4_row8_col0 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_68bf4_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-decoration: underline;
# }
# #T_68bf4_row10_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_68bf4_row11_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_68bf4_row12_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_68bf4_row13_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_68bf4_row14_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_68bf4_row15_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_68bf4_row17_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_68bf4_row18_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_68bf4_row20_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# </style>
# <table id="T_68bf4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68bf4_level0_col0" class="col_heading level0 col0" >avg_dl_distance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >local</th>
#       <th class="index_name level1" >model</th>
#       <th class="index_name level2" >d_model</th>
#       <th class="index_name level3" >lambda</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68bf4_level0_row0" class="row_heading level0 row0" rowspan="12">False</th>
#       <th id="T_68bf4_level1_row0" class="row_heading level1 row0" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_68bf4_level2_row0" class="row_heading level2 row0" rowspan="3">16</th>
#       <th id="T_68bf4_level3_row0" class="row_heading level3 row0" >0.100000</th>
#       <td id="T_68bf4_row0_col0" class="data row0 col0" >0.350188</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row1" class="row_heading level3 row1" >0.200000</th>
#       <td id="T_68bf4_row1_col0" class="data row1 col0" >0.353010</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row2" class="row_heading level3 row2" >0.500000</th>
#       <td id="T_68bf4_row2_col0" class="data row2 col0" >0.365721</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level2_row3" class="row_heading level2 row3" rowspan="3">32</th>
#       <th id="T_68bf4_level3_row3" class="row_heading level3 row3" >0.100000</th>
#       <td id="T_68bf4_row3_col0" class="data row3 col0" >0.346911</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row4" class="row_heading level3 row4" >0.200000</th>
#       <td id="T_68bf4_row4_col0" class="data row4 col0" >0.343302</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row5" class="row_heading level3 row5" >0.500000</th>
#       <td id="T_68bf4_row5_col0" class="data row5 col0" >0.346563</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level2_row6" class="row_heading level2 row6" rowspan="3">64</th>
#       <th id="T_68bf4_level3_row6" class="row_heading level3 row6" >0.100000</th>
#       <td id="T_68bf4_row6_col0" class="data row6 col0" >0.330060</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row7" class="row_heading level3 row7" >0.200000</th>
#       <td id="T_68bf4_row7_col0" class="data row7 col0" >0.338378</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row8" class="row_heading level3 row8" >0.500000</th>
#       <td id="T_68bf4_row8_col0" class="data row8 col0" >0.337368</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level1_row9" class="row_heading level1 row9" rowspan="3">suffix_model</th>
#       <th id="T_68bf4_level2_row9" class="row_heading level2 row9" >16</th>
#       <th id="T_68bf4_level3_row9" class="row_heading level3 row9" >0.000000</th>
#       <td id="T_68bf4_row9_col0" class="data row9 col0" >0.327186</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level2_row10" class="row_heading level2 row10" >32</th>
#       <th id="T_68bf4_level3_row10" class="row_heading level3 row10" >0.000000</th>
#       <td id="T_68bf4_row10_col0" class="data row10 col0" >0.327844</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level2_row11" class="row_heading level2 row11" >64</th>
#       <th id="T_68bf4_level3_row11" class="row_heading level3 row11" >0.000000</th>
#       <td id="T_68bf4_row11_col0" class="data row11 col0" >0.329077</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level0_row12" class="row_heading level0 row12" rowspan="9">True</th>
#       <th id="T_68bf4_level1_row12" class="row_heading level1 row12" rowspan="9">SDFA_suffix_model</th>
#       <th id="T_68bf4_level2_row12" class="row_heading level2 row12" rowspan="3">16</th>
#       <th id="T_68bf4_level3_row12" class="row_heading level3 row12" >0.100000</th>
#       <td id="T_68bf4_row12_col0" class="data row12 col0" >0.337054</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row13" class="row_heading level3 row13" >0.200000</th>
#       <td id="T_68bf4_row13_col0" class="data row13 col0" >0.345631</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row14" class="row_heading level3 row14" >0.500000</th>
#       <td id="T_68bf4_row14_col0" class="data row14 col0" >0.406473</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level2_row15" class="row_heading level2 row15" rowspan="3">32</th>
#       <th id="T_68bf4_level3_row15" class="row_heading level3 row15" >0.100000</th>
#       <td id="T_68bf4_row15_col0" class="data row15 col0" >0.340332</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row16" class="row_heading level3 row16" >0.200000</th>
#       <td id="T_68bf4_row16_col0" class="data row16 col0" >0.346458</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row17" class="row_heading level3 row17" >0.500000</th>
#       <td id="T_68bf4_row17_col0" class="data row17 col0" >0.338848</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level2_row18" class="row_heading level2 row18" rowspan="3">64</th>
#       <th id="T_68bf4_level3_row18" class="row_heading level3 row18" >0.100000</th>
#       <td id="T_68bf4_row18_col0" class="data row18 col0" >0.335351</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row19" class="row_heading level3 row19" >0.200000</th>
#       <td id="T_68bf4_row19_col0" class="data row19 col0" >0.338471</td>
#     </tr>
#     <tr>
#       <th id="T_68bf4_level3_row20" class="row_heading level3 row20" >0.500000</th>
#       <td id="T_68bf4_row20_col0" class="data row20 col0" >0.332901</td>
#     </tr>
#   </tbody>
# </table>
