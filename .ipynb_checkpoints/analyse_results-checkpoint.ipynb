# %%
import pandas as pd
import numpy as np

df = pd.read_csv('results_nap_prediction_new.csv')
df.tail()
# Out:
#      seed      model  lambda  d_model  er_loss  no_epochs  max_len    recall  \
# 151    23  NAP_model     0.5       16    False         10       10  0.791684
# 152    23  NAP_model     0.5       16    False         10       20  0.682107
# 153    23  NAP_model     0.5       32    False         10        5  0.826457
# 154    23  NAP_model     0.5       32    False         10       10  0.726599
# 155    23  NAP_model     0.5       32    False         10       20  0.660910
#
#      precision        f1  accuracy
# 151   0.883018  0.826736  0.791684
# 152   0.805764  0.727827  0.682107
# 153   0.904794  0.857505  0.826457
# 154   0.882003  0.781579  0.726599
# 155   0.746237  0.686530  0.660910

# %%
df = df[df['seed'] != 56]
pivot_table = pd.pivot_table(df, 
                             values=['f1', 'precision', 'accuracy'], 
                             
                             index=['model',  'd_model', 'lambda'], 
                             aggfunc=np.mean)
styled_table = pivot_table.style.background_gradient(cmap='Greens')
styled_table
# Out:
# /var/folders/rz/s0r_wmmx54b8t4zd9_r9xqbr0000gn/T/ipykernel_82794/4286818556.py:2: FutureWarning: The provided callable <function mean at 0x11051bf60> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table = pd.pivot_table(df,
# <style type="text/css">
# #T_43d49_row0_col0, #T_43d49_row0_col1, #T_43d49_row0_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_43d49_row1_col0 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_43d49_row1_col1, #T_43d49_row1_col2 {
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_43d49_row2_col0 {
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_43d49_row2_col1 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_43d49_row2_col2, #T_43d49_row10_col2 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_43d49_row3_col0 {
#   background-color: #f1faee;
# ...
